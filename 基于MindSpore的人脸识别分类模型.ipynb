# %% [markdown]
# # **基于MindSpore下的人脸识别分类**

# %% [markdown]
# ## 1 模型介绍
# #### 1.1 模型简介
#
# 在大数据时代，图像数据激增，计算机视觉技术的重要性日益凸显。深度学习作为一种端到端的学习范式，能够自动从大量数据中学习到丰富的特征表示，在视觉识别任务中展现出了强大的性能。从早期简单的模板匹配、手工设计特征的方法，到如今基于深度神经网络的端到端学习框架，视觉识别技术经历了巨大的变革。
#
# 在深度学习兴起之前，视觉识别主要依赖手工提取特征，如SIFT、HOG等，然后利用传统机器学习算法如SVM进行分类。这种方法在计算资源有限的时代取得了一定成果，但存在明显缺陷：特征提取依赖专家知识，泛化能力差，且难以应对图像的复杂变化如光照、姿态、遮挡等。随着图像数据量爆炸式增长，对更高效、更智能的识别方法的需求愈发迫切。
#
# 2012 年，Hinton 和他的学生 Alex 在论文《ImageNet Classification with Deep Convolutional Neural Networks》中提出的 AlexNet，成为了视觉识别领域的重要转折点。它在当年的 ILSVRC 竞赛中一举夺冠，top-5 识别错误率比第二名低近 10%，引发业界轰动。AlexNet 的成功并非偶然，而是多种创新技术的结合：它采用多 GPU 训练，突破计算资源限制；引入 ReLU 激活函数，加速训练且缓解梯度消失；应用 Dropout 技术，有效防止过拟合；使用局部响应归一化（LRN），增强特征表达能力。这些技术使 AlexNet 在复杂图像分类任务中展现出前所未有的性能，开启了深度学习在视觉识别领域的统治地位。

# %% [markdown]
# #### 1.2 模型详解
#
# <img src="./image/Alexnet.png">
#
# AlexNet 有 8 层权重层，包括 5 层卷积层和 3 层全连接层（FC 层），并引入了一些重要的创新，包括激活函数、Dropout 正则化和重叠池化。它通过增加网络的深度和宽度，结合 GPU 加速，极大提升了 CNN 的能力。
#
# 1. **卷积+池化层（前五层）**
# AlexNet共有五个卷积层，每个卷积层都包含卷积核、偏置项、ReLU激活函数和局部响应归一化（LRN）模块。
#
# 卷积层C1：使用96个核对224 × 224 × 3的输入图像进行滤波，卷积核大小为11 × 11 × 3，步长为4。将一对55×55×48的特征图分别放入ReLU激活函数，生成激活图。激活后的图像进行最大池化，size为3×3，stride为2，池化后的特征图size为27×27×48（一对）。池化后进行LRN处理。
#
# 卷积层C2：使用卷积层C1的输出（响应归一化和池化）作为输入，并使用256个卷积核进行滤波，核大小为5 × 5 × 48。
#
# 卷积层C3：有384个核，核大小为3 × 3 × 256，与卷积层C2的输出（归一化的，池化的）相连。
#
# 卷积层C4：有384个核，核大小为3 × 3 × 192。
#
# 卷积层C5：有256个核，核大小为3 × 3 × 192。卷积层C5与C3、C4层相比多了个池化，池化核size同样为3×3，stride为2。
#
# 其中，卷积层C3、C4、C5互相连接，中间没有接入池化层或归一化层。
#
# 2. **全连接层（后三层）**
# 全连接层F6：因为是全连接层，卷积核size为6×6×256，4096个卷积核生成4096个特征图，尺寸为1×1。然后放入ReLU函数、Dropout处理。值得注意的是AlexNet使用了Dropout层，以减少过拟合现象的发生。
#
# 全连接层F7：同F6层。
#
# 全连接层F8：最后一层全连接层的输出是1000维softmax的输入，softmax会产生1000个类别预测的值。

# %% [markdown]
# #### 1.3 AlexNet主要创新点
#
# 1. **ReLU激活函数的引入**
#
# 采用修正线性单元(ReLU)的深度卷积神经网络训练时间比等价的tanh单元要快几倍。而时间开销是进行模型训练过程中很重要的考量因素之一。同时，ReLU有效防止了过拟合现象的出现。由于ReLU激活函数的高效性与实用性，使得它在深度学习框架中占有重要地位。
#
# 2. **层叠池化操作**
#
# 以往池化的大小PoolingSize与步长stride一般是相等的，例如：图像大小为256*256，PoolingSize=2×2，stride=2，这样可以使图像或是FeatureMap大小缩小一倍变为128，此时池化过程没有发生层叠。但是AlexNet采用了层叠池化操作，即PoolingSize > stride。这种操作非常像卷积操作，可以使相邻像素间产生信息交互和保留必要的联系。论文中也证明，此操作可以有效防止过拟合的发生。
#
# 3. **Dropout操作**
#
# Dropout操作会将概率小于0.5的每个隐层神经元的输出设为0，即去掉了一些神经节点，达到防止过拟合。那些“失活的”神经元不再进行前向传播并且不参与反向传播。这个技术减少了复杂的神经元之间的相互影响。在论文中，也验证了此方法的有效性。

# %% [markdown]
# #### **1.4 模型特点**
#
# ##### a) 非线性激活函数 ReLU:
#
# 标准的L-P神经元的输出一般使用$f(x) = tanh(x)$或$f(x) = (1+e^{-x})^{-1}$作为激活函数，而在训练阶段梯度衰减快慢方面，AlexNet所使用的ReLU函数，即$f(x) = max(0, x)$,比上述两个非线性饱和函数要快许多。效果详见下图：
#
#
# ##### b) 多GPU训练:
#
# 在当时，单个GPU的内存限制了网络的训练规模，而采用多GPU训练可解决上述问题，提高AlexNet的训练速度。
#
# 但随着技术的发展，在绝大多数情况下，单个GPU的内存已经足以支持整个模型的训练，而多GPU训练也成为了AlexNet这个项目中最复杂的技术细节。此外，作者在此处提出的双GPU训练的可复现性差，所以在未来的几年内并没有被重视。
#
# 然而近些年随着体量更大的模型的出现，GPU瓶颈再次产生，这使得模型并行、分布训练（多GPU训练）又成为了大家解决GPU瓶颈的重要技术。
#
# ##### c) 局部响应归一化：
#
# 采用局部响应归一化(local response normalization，LRN)可将数据分布调整到合理的范围内，便于计算处理，从而提高泛化能力，避免过饱和。
#
# 具体公式如下：
#
# $${b}_{x,y}^{i}={a}_{x,y}^{i}/({{k}+{α}{\sum_{j=max(0,i-n/2)}^{min(N-1,i+n/2)}}({a}_{x,y}^{i})^2})^{β}$$
#
# 但从现在的角度来看，LRN技术的作用并不大，而且在之后的训练中也并未得到广泛的使用。
#
# ##### d) 重叠池化层：
#
# 一般来说两个pooling是不重叠的，但是这里采用了一种对传统的pooling改进的方式，不仅可以提升预测精度，同时一定程度上可以减缓过拟合。
#
#
# #### **1.5 降低过拟合**
#
# ##### a) 数据增强：
#
# 减少图像数据过度拟合的最简单也是最常见的方法是使用保留标签的变换人为地放大数据集。这里用了两种方式来实现数据增强：
#
# i）随机区域提取：该方法在256×256的图片上随机提取一个224×224的区域用以训练，这使得数据集的大小变为原来的2048倍。
#
# ii）RGB通道改变：该方法采用PCA的方式对RGB图像的channel进行了一些改变，使图像发生了一些变化，从而扩大了数据集。
#
# ##### b) dropout:
#
# Dropout通过设置好的概率（50%），随机将某个隐藏层神经元的输出设置为0，因此这个神经元将不参与前向传播和反向传播，在下一次迭代中会根据概率重新将某个神经元的输出置0。简单来说就是在全连接层中去掉了一些神经节点，达到了防止过拟合的目的。但dropout的使用也让AlexNet的训练速度慢了一倍。Dropout相当于一个L2的正则化，只不过用了这种方式实现了L2正则化的功能。
#
# #### **1.6 模型参数**
#
# 超参数：使用随机梯度下降法（SGD）训练模型，batch size = 128，momentum = 0.9，权重衰减 = 0.0005，学习率=0.01.
#
# 初始化：首先用均值为0，方差为0.01的高斯随机变量初始化权重参数，再将第2、4、5个卷积层和全连接起来的隐藏层的神经元偏置初始化为常数1，最后将剩余层的神经元偏置初始化为常数0.
#
# 学习率：在所有层上均使用0.01的学习率，验证集的错误率不再随当前学习率提高时，将学习率除以10.

# %% [markdown]
# ### **2 案例实现**
#
# #### **2.1 数据集**
#
# 本文采用CASIA-WebFace中的人脸识别数据集作为训练集，CASIA-WebFace是一款免费开源的用于人脸识别的数据集，它是从IMDb网站上进行数据爬取，网站中具有非常多人脸特征，并且数据集里不会有重复特征，目前共有一万五千个名人数据集和四十九万张照片。
#
# 采用LFW数据集作为训练集， LFW (Labled Faces in the Wild)人脸数据集：是目前人脸识别的常用测试集，其中提供的人脸图片均来源于生活中的自然场景，因此识别难度会增大，尤其由于多姿态、光照、表情、年龄、遮挡等因素影响导致即使同一人的照片差别也很大。并且有些照片中可能不止一个人脸出现，对这些多人脸图像仅选择中心坐标的人脸作为目标，其他区域的视为背景干扰。LFW数据集共有13233张人脸图像，每张图像均给出对应的人名，共有5749人，且绝大部分人仅有一张图片。每张图片的尺寸为250X250，绝大部分为彩色图像，但也存在少许黑白人脸图片。
# 下载地址：<a>http://vis-www.cs.umass.edu/lfw/lfw.tgz</a>

# %% [markdown]
# #### **2.2 环境准备与数据读取**
#
# 本案例基于MindSpore-CPU版本实现，在CPU上完成模型训练。
#
# 环境需要mindspore和mindvision。

# %%
import mindspore
import mindspore.nn as nn

from mindspore import ops
from mindvision import dataset
from mindspore.dataset import vision

# %% [markdown]
# 在CASIA-WebFace中它的数据集里还会对爬下来的照片进行裁剪，忽略掉哪些杂项背景，只保留人脸区域，同时每张照片会保留两份，来加强数据集的数据重复度以便增强可信度。并且它的尺寸都被统一缩减为96x96，在图像识别方面将图像缩减到96x96对图像的像素损失最低同时尺寸大小也会变小，并且数据量也会减少，这对后续的卷积与池化会更快。
#
# 数据集图像示例：
# <img src="./image/图片.png">
#
# 本案例通过CASIA-WebFace下载训练数据和通过LFW下载测试数据，下载后的数据集会保存在设定好的路径。

# %%
# 从dataset下载训练数据
training_data = dataset.Cifar10(
    path="./datatests",
    split="train",
    download=True,
)

# 从dataset下载测试数据
test_data = dataset.Cifar10(
    path="./lfw",
    split="test",
    download=True,
)

# 数据下载完成后，获取数据集对象
train_dataset = training_data.dataset
test_dataset = test_data.dataset

# 查看数据集中包含的数据列名，用于dataset的预处理
train_dataset.column_names
# Out:
# ['image', 'label']

# %% [markdown]
# #### 2.3 **规范数据集格式**
#
# 为了确保数据的一致性和可用性，需要对数据集进行格式规范处理。

# %%
import os
import shutil
import re

def reorganize_dataset(source_dir, target_dir):
    os.makedirs(target_dir, exist_ok=True)
    
    # 获取并排序子文件夹
    subfolders = [d for d in os.listdir(source_dir) if os.path.isdir(os.path.join(source_dir, d))]
    try:
        subfolders.sort(key=lambda x: int(x))  # 按数字排序
    except ValueError:
        subfolders = sorted(subfolders)  # 备用字母排序
    
    for folder_idx, folder in enumerate(subfolders):
        old_folder = os.path.join(source_dir, folder)
        new_folder = os.path.join(target_dir, f"people{folder_idx}")
        os.makedirs(new_folder, exist_ok=True)
        
        # 获取并排序图片文件
        files = [f for f in os.listdir(old_folder) if f.lower().endswith(('.jpg', '.jpeg', '.png'))]
        # 提取数字并排序
        files.sort(key=lambda f: int(re.search(r'(\d+)', f).group()))
        
        # 复制并重命名
        for img_idx, filename in enumerate(files, 1):
            old_path = os.path.join(old_folder, filename)
            new_name = f"{img_idx:03d}{os.path.splitext(filename)[1]}"  # 保持原扩展名
            new_path = os.path.join(new_folder, new_name)
            
            shutil.copy2(old_path, new_path)
        
        print(f"转换完成: {folder} → people{folder_idx} ({len(files)}张图片)")

if __name__ == "__main__":
    source = "lfw"
    target = "./datatests"
    reorganize_dataset(source, target)
# Out:
# 转换完成: AJ_Cook → people0 (1张图片)
# 转换完成: AJ_Lamas → people1 (1张图片)
# 转换完成: Aaron_Eckhart → people2 (1张图片)
# 转换完成: Aaron_Guiel → people3 (1张图片)
# 转换完成: Aaron_Patterson → people4 (1张图片)
# 转换完成: Aaron_Peirsol → people5 (4张图片)
# 转换完成: Aaron_Pena → people6 (1张图片)
# 转换完成: Aaron_Sorkin → people7 (2张图片)
# 转换完成: Aaron_Tippin → people8 (1张图片)
# 转换完成: Abba_Eban → people9 (1张图片)
# 转换完成: Abbas_Kiarostami → people10 (1张图片)
# 转换完成: Abdel_Aziz_Al-Hakim → people11 (1张图片)
# 转换完成: Abdel_Madi_Shabneh → people12 (1张图片)
# 转换完成: Abdel_Nasser_Assidi → people13 (2张图片)
# 转换完成: Abdoulaye_Wade → people14 (4张图片)
# 转换完成: Abdul_Majeed_Shobokshi → people15 (1张图片)
# 转换完成: Abdul_Rahman → people16 (1张图片)
# 转换完成: Abdulaziz_Kamilov → people17 (1张图片)
# 转换完成: Abdullah → people18 (4张图片)
# 转换完成: Abdullah_Ahmad_Badawi → people19 (1张图片)
# 转换完成: Abdullah_Gul → people20 (19张图片)
# 转换完成: Abdullah_Nasseef → people21 (1张图片)
# 转换完成: Abdullah_al-Attiyah → people22 (3张图片)
# 转换完成: Abdullatif_Sener → people23 (2张图片)
# 转换完成: Abel_Aguilar → people24 (1张图片)
# 转换完成: Abel_Pacheco → people25 (4张图片)
# 转换完成: Abid_Hamid_Mahmud_Al-Tikriti → people26 (3张图片)
# 转换完成: Abner_Martinez → people27 (1张图片)
# 转换完成: Abraham_Foxman → people28 (1张图片)
# 转换完成: Aby_Har-Even → people29 (1张图片)
# 转换完成: Adam_Ant → people30 (1张图片)
# 转换完成: Adam_Freier → people31 (1张图片)
# 转换完成: Adam_Herbert → people32 (1张图片)
# 转换完成: Adam_Kennedy → people33 (1张图片)
# 转换完成: Adam_Mair → people34 (1张图片)
# 转换完成: Adam_Rich → people35 (1张图片)
# 转换完成: Adam_Sandler → people36 (4张图片)
# 转换完成: Adam_Scott → people37 (2张图片)
# 转换完成: Adel_Al-Jubeir → people38 (3张图片)
# 转换完成: Adelina_Avila → people39 (1张图片)
# 转换完成: Adisai_Bodharamik → people40 (1张图片)
# 转换完成: Adolfo_Aguilar_Zinser → people41 (3张图片)
# 转换完成: Adolfo_Rodriguez_Saa → people42 (2张图片)
# 转换完成: Adoor_Gopalakarishnan → people43 (1张图片)
# 转换完成: Adrian_Annus → people44 (1张图片)
# 转换完成: Adrian_Fernandez → people45 (1张图片)
# 转换完成: Adrian_McPherson → people46 (2张图片)
# 转换完成: Adrian_Murrell → people47 (1张图片)
# 转换完成: Adrian_Nastase → people48 (2张图片)
# 转换完成: Adriana_Lima → people49 (1张图片)
# 转换完成: Adriana_Perez_Navarro → people50 (1张图片)
# 转换完成: Adrianna_Zuzic → people51 (1张图片)
# 转换完成: Adrien_Brody → people52 (12张图片)
# 转换完成: Afton_Smith → people53 (1张图片)
# 转换完成: Agbani_Darego → people54 (1张图片)
# 转换完成: Agnelo_Queiroz → people55 (1张图片)
# 转换完成: Agnes_Bruckner → people56 (1张图片)
# 转换完成: Ahmad_Jbarah → people57 (1张图片)
# 转换完成: Ahmad_Masood → people58 (2张图片)
# 转换完成: Ahmed_Ahmed → people59 (1张图片)
# 转换完成: Ahmed_Chalabi → people60 (5张图片)
# 转换完成: Ahmed_Ghazi → people61 (1张图片)
# 转换完成: Ahmed_Ibrahim_Bilal → people62 (1张图片)
# 转换完成: Ahmed_Lopez → people63 (1张图片)
# 转换完成: Ahmed_Qureia → people64 (1张图片)
# 转换完成: Ahmet_Demir → people65 (1张图片)
# 转换完成: Ahmet_Necdet_Sezer → people66 (2张图片)
# 转换完成: Ai_Sugiyama → people67 (5张图片)
# 转换完成: Aicha_El_Ouafi → people68 (3张图片)
# 转换完成: Aidan_Quinn → people69 (1张图片)
# 转换完成: Aileen_Riggin_Soule → people70 (1张图片)
# 转换完成: Ain_Seppik → people71 (1张图片)
# 转换完成: Ainsworth_Dyer → people72 (1张图片)
# 转换完成: Aishwarya_Rai → people73 (1张图片)
# 转换完成: Aitor_Gonzalez → people74 (2张图片)
# 转换完成: Aiysha_Smith → people75 (1张图片)
# 转换完成: Ajit_Agarkar → people76 (1张图片)
# 转换完成: Akbar_Al_Baker → people77 (1张图片)
# 转换完成: Akbar_Hashemi_Rafsanjani → people78 (3张图片)
# 转换完成: Akhmed_Zakayev → people79 (3张图片)
# 转换完成: Akiko_Morigami → people80 (1张图片)
# 转换完成: Akmal_Taher → people81 (1张图片)
# 转换完成: Al_Cardenas → people82 (1张图片)
# 转换完成: Al_Davis → people83 (2张图片)
# 转换完成: Al_Gore → people84 (8张图片)
# 转换完成: Al_Leiter → people85 (1张图片)
# 转换完成: Al_Pacino → people86 (3张图片)
# 转换完成: Al_Sharpton → people87 (7张图片)
# 转换完成: Alain_Cervantes → people88 (1张图片)
# 转换完成: Alain_Ducasse → people89 (1张图片)
# 转换完成: Alan_Ball → people90 (2张图片)
# 转换完成: Alan_Dershowitz → people91 (1张图片)
# 转换完成: Alan_Dreher → people92 (1张图片)
# 转换完成: Alan_Greenspan → people93 (5张图片)
# 转换完成: Alan_Greer → people94 (1张图片)
# 转换完成: Alan_Jackson → people95 (1张图片)
# 转换完成: Alan_Mulally → people96 (2张图片)
# 转换完成: Alan_Stonecipher → people97 (1张图片)
# 转换完成: Alan_Tang_Kwong-wing → people98 (1张图片)
# 转换完成: Alan_Trammell → people99 (1张图片)
# 转换完成: Alan_Zemaitis → people100 (1张图片)
# 转换完成: Alanis_Morissette → people101 (1张图片)
# 转换完成: Alanna_Ubach → people102 (1张图片)
# 转换完成: Alastair_Campbell → people103 (5张图片)
# 转换完成: Alastair_Johnston → people104 (1张图片)
# 转换完成: Albaro_Recoba → people105 (1张图片)
# 转换完成: Albert_Brooks → people106 (1张图片)
# 转换完成: Albert_Costa → people107 (6张图片)
# 转换完成: Albert_Montanes → people108 (1张图片)
# 转换完成: Albert_Pujols → people109 (1张图片)
# 转换完成: Alberta_Lee → people110 (1张图片)
# 转换完成: Alberto_Acosta → people111 (1张图片)
# 转换完成: Alberto_Fujimori → people112 (2张图片)
# 转换完成: Alberto_Gonzales → people113 (1张图片)
# 转换完成: Alberto_Ruiz_Gallardon → people114 (2张图片)
# 转换完成: Alberto_Sordi → people115 (1张图片)
# 转换完成: Albrecht_Mentz → people116 (2张图片)
# 转换完成: Aldo_Paredes → people117 (2张图片)
# 转换完成: Alec_Baldwin → people118 (4张图片)
# 转换完成: Alecos_Markides → people119 (1张图片)
# 转换完成: Alejandro_Atchugarry → people120 (2张图片)
# 转换完成: Alejandro_Avila → people121 (3张图片)
# 转换完成: Alejandro_Fernandez → people122 (1张图片)
# 转换完成: Alejandro_Gonzalez_Inarritu → people123 (1张图片)
# 转换完成: Alejandro_Lembo → people124 (1张图片)
# 转换完成: Alejandro_Lerner → people125 (1张图片)
# 转换完成: Alejandro_Lopez → people126 (1张图片)
# 转换完成: Alejandro_Toledo → people127 (39张图片)
# 转换完成: Alek_Wek → people128 (1张图片)
# 转换完成: Aleksander_Kwasniewski → people129 (4张图片)
# 转换完成: Aleksander_Voloshin → people130 (1张图片)
# 转换完成: Alessandra_Cerna → people131 (1张图片)
# 转换完成: Alessandro_Nesta → people132 (1张图片)
# 转换完成: Alex_Barros → people133 (2张图片)
# 转换完成: Alex_Cabrera → people134 (1张图片)
# 转换完成: Alex_Cejka → people135 (1张图片)
# 转换完成: Alex_Corretja → people136 (1张图片)
# 转换完成: Alex_Ferguson → people137 (1张图片)
# 转换完成: Alex_Gonzalez → people138 (1张图片)
# 转换完成: Alex_Holmes → people139 (1张图片)
# 转换完成: Alex_King → people140 (1张图片)
# 转换完成: Alex_Penelas → people141 (2张图片)
# 转换完成: Alex_Popov → people142 (1张图片)
# 转换完成: Alex_Sink → people143 (3张图片)
# 转换完成: Alex_Wallau → people144 (1张图片)
# 转换完成: Alex_Zanardi → people145 (1张图片)
# 转换完成: Alexa_Loren → people146 (1张图片)
# 转换完成: Alexa_Vega → people147 (1张图片)
# 转换完成: Alexander_Downer → people148 (4张图片)
# 转换完成: Alexander_Losyukov → people149 (4张图片)
# 转换完成: Alexander_Lukashenko → people150 (1张图片)
# 转换完成: Alexander_Payne → people151 (1张图片)
# 转换完成: Alexander_Rumyantsev → people152 (2张图片)
# 转换完成: Alexandra_Jackson → people153 (1张图片)
# 转换完成: Alexandra_Pelosi → people154 (1张图片)
# 转换完成: Alexandra_Rozovskaya → people155 (1张图片)
# 转换完成: Alexandra_Spann → people156 (1张图片)
# 转换完成: Alexandra_Stevenson → people157 (3张图片)
# 转换完成: Alexandra_Vodjanikova → people158 (2张图片)
# 转换完成: Alexandre_Daigle → people159 (1张图片)
# 转换完成: Alexandre_Despatie → people160 (1张图片)
# 转换完成: Alexandre_Herchcovitch → people161 (1张图片)
# 转换完成: Alexandre_Vinokourov → people162 (1张图片)
# 转换完成: Alexis_Bledel → people163 (1张图片)
# 转换完成: Alexis_Dennisoff → people164 (1张图片)
# 转换完成: Alfonso_Cuaron → people165 (1张图片)
# 转换完成: Alfonso_Portillo → people166 (1张图片)
# 转换完成: Alfonso_Soriano → people167 (1张图片)
# 转换完成: Alfred_Ford → people168 (1张图片)
# 转换完成: Alfred_Sant → people169 (1张图片)
# 转换完成: Alfredo_Moreno → people170 (1张图片)
# 转换完成: Alfredo_Pena → people171 (1张图片)
# 转换完成: Alfredo_di_Stefano → people172 (1张图片)
# 转换完成: Ali_Abbas → people173 (2张图片)
# 转换完成: Ali_Abdullah_Saleh → people174 (1张图片)
# 转换完成: Ali_Adbul_Karim_Madani → people175 (1张图片)
# 转换完成: Ali_Ahmeti → people176 (1张图片)
# 转换完成: Ali_Bin_Hussein → people177 (1张图片)
# 转换完成: Ali_Fallahian → people178 (1张图片)
# 转换完成: Ali_Hammoud → people179 (1张图片)
# 转换完成: Ali_Khamenei → people180 (3张图片)
# 转换完成: Ali_Mohammed_Maher → people181 (1张图片)
# 转换完成: Ali_Naimi → people182 (8张图片)
# 转换完成: Alice_Fisher → people183 (2张图片)
# 转换完成: Alicia_Hollowell → people184 (1张图片)
# 转换完成: Alicia_Keys → people185 (1张图片)
# 转换完成: Alicia_Molik → people186 (1张图片)
# 转换完成: Alicia_Silverstone → people187 (2张图片)
# 转换完成: Alicia_Witt → people188 (1张图片)
# 转换完成: Alimzhan_Tokhtakhounov → people189 (2张图片)
# 转换完成: Alina_Kabaeva → people190 (1张图片)
# 转换完成: Aline_Chretien → people191 (1张图片)
# 转换完成: Alisha_Richman → people192 (1张图片)
# 转换完成: Alison_Krauss → people193 (1张图片)
# 转换完成: Alison_Lohman → people194 (2张图片)
# 转换完成: Alistair_MacDonald → people195 (1张图片)
# 转换完成: Allan_Houston → people196 (1张图片)
# 转换完成: Allan_Kemakeza → people197 (1张图片)
# 转换完成: Allan_Wagner → people198 (1张图片)
# 转换完成: Allen_Iverson → people199 (2张图片)
# 转换完成: Allen_Rock → people200 (1张图片)
# 转换完成: Allison_Janney → people201 (2张图片)
# 转换完成: Allison_Searing → people202 (1张图片)
# 转换完成: Ally_Sheedy → people203 (1张图片)
# 转换完成: Allyson_Felix → people204 (5张图片)
# 转换完成: Alma_Powell → people205 (1张图片)
# 转换完成: Almeida_Baptista → people206 (1张图片)
# 转换完成: Alonzo_Mourning → people207 (1张图片)
# 转换完成: Alvaro_Noboa → people208 (3张图片)
# 转换完成: Alvaro_Silva_Calderon → people209 (4张图片)
# 转换完成: Alvaro_Uribe → people210 (35张图片)
# 转换完成: Aly_Wagner → people211 (1张图片)
# 转换完成: Alyse_Beaupre → people212 (1张图片)
# 转换完成: Alyson_Hannigan → people213 (1张图片)
# 转换完成: Amanda_Beard → people214 (2张图片)
# 转换完成: Amanda_Bynes → people215 (4张图片)
# 转换完成: Amanda_Coetzer → people216 (2张图片)
# 转换完成: Amanda_Marsh → people217 (1张图片)
# 转换完成: Amanda_Plumer → people218 (1张图片)
# 转换完成: Amber_Frey → people219 (1张图片)
# 转换完成: Amber_Tamblyn → people220 (2张图片)
# 转换完成: Ambrose_Lee → people221 (1张图片)
# 转换完成: Amelia_Vega → people222 (7张图片)
# 转换完成: Amelie_Mauresmo → people223 (21张图片)
# 转换完成: Amer_al-Saadi → people224 (4张图片)
# 转换完成: Amporn_Falise → people225 (1张图片)
# 转换完成: Amr_Moussa → people226 (1张图片)
# 转换完成: Amram_Mitzna → people227 (2张图片)
# 转换完成: Amy_Brenneman → people228 (1张图片)
# 转换完成: Amy_Cotton → people229 (1张图片)
# 转换完成: Amy_Gale → people230 (1张图片)
# 转换完成: Amy_Pascal → people231 (1张图片)
# 转换完成: Amy_Redford → people232 (1张图片)
# 转换完成: Amy_Smart → people233 (1张图片)
# 转换完成: Amy_Yasbeck → people234 (1张图片)
# 转换完成: AnFernce_Negron → people235 (1张图片)
# 转换完成: Ana_Claudia_Talancon → people236 (1张图片)
# 转换完成: Ana_Guevara → people237 (7张图片)
# 转换完成: Ana_Isabel_Sanchez → people238 (1张图片)
# 转换完成: Ana_Palacio → people239 (8张图片)
# 转换完成: Ana_Paula_Gerard → people240 (1张图片)
# 转换完成: Ana_Sebastiao → people241 (1张图片)
# 转换完成: Anastasia_Kelesidou → people242 (1张图片)
# 转换完成: Anastasia_Myskina → people243 (3张图片)
# 转换完成: Anatoliy_Kinakh → people244 (1张图片)
# 转换完成: Anders_Ebbeson → people245 (3张图片)
# 转换完成: Anders_Fogh_Rasmussen → people246 (4张图片)
# 转换完成: Anderson_Varejao → people247 (1张图片)
# 转换完成: Andre_Agassi → people248 (36张图片)
# 转换完成: Andre_Bucher → people249 (1张图片)
# 转换完成: Andre_Lange → people250 (1张图片)
# 转换完成: Andre_Smith → people251 (1张图片)
# 转换完成: Andre_Techine → people252 (1张图片)
# 转换完成: Andrea_Bocelli → people253 (1张图片)
# 转换完成: Andrea_De_Cruz → people254 (1张图片)
# 转换完成: Andrea_Kiser → people255 (1张图片)
# 转换完成: Andrea_Yates → people256 (1张图片)
# 转换完成: Andreas_Vinciguerra → people257 (1张图片)
# 转换完成: Andrei_Konchalovsky → people258 (1张图片)
# 转换完成: Andrei_Mikhnevich → people259 (2张图片)
# 转换完成: Andrei_Nikolishin → people260 (1张图片)
# 转换完成: Andres_DAlessandro → people261 (1张图片)
# 转换完成: Andres_Manuel_Lopez_Obrador → people262 (1张图片)
# 转换完成: Andres_Pastrana → people263 (1张图片)
# 转换完成: Andrew_Bernard → people264 (1张图片)
# 转换完成: Andrew_Bunner → people265 (2张图片)
# 转换完成: Andrew_Caldecott → people266 (1张图片)
# 转换完成: Andrew_Cuomo → people267 (2张图片)
# 转换完成: Andrew_Fastow → people268 (1张图片)
# 转换完成: Andrew_Firestone → people269 (1张图片)
# 转换完成: Andrew_Gilligan → people270 (1张图片)
# 转换完成: Andrew_Jarecki → people271 (1张图片)
# 转换完成: Andrew_Luster → people272 (1张图片)
# 转换完成: Andrew_Niccol → people273 (2张图片)
# 转换完成: Andrew_Sabey → people274 (1张图片)
# 转换完成: Andrew_Shutley → people275 (1张图片)
# 转换完成: Andrew_Weissmann → people276 (3张图片)
# 转换完成: Andrew_Wetzler → people277 (1张图片)
# 转换完成: Andrzej_Tyszkiewicz → people278 (1张图片)
# 转换完成: Andy_Benes → people279 (1张图片)
# 转换完成: Andy_Bryant → people280 (1张图片)
# 转换完成: Andy_Dick → people281 (1张图片)
# 转换完成: Andy_Garcia → people282 (1张图片)
# 转换完成: Andy_Graves → people283 (1张图片)
# 转换完成: Andy_Griffith → people284 (1张图片)
# 转换完成: Andy_Griggs → people285 (1张图片)
# 转换完成: Andy_Hebb → people286 (2张图片)
# 转换完成: Andy_Lau → people287 (1张图片)
# 转换完成: Andy_Madikians → people288 (1张图片)
# 转换完成: Andy_North → people289 (1张图片)
# 转换完成: Andy_Perez → people290 (1张图片)
# 转换完成: Andy_Roddick → people291 (15张图片)
# 转换完成: Andy_Rooney → people292 (1张图片)
# 转换完成: Andy_Warhol → people293 (1张图片)
# 转换完成: Andy_Wisecarver → people294 (1张图片)
# 转换完成: Anette_Hosoi → people295 (1张图片)
# 转换完成: Angel_Lockward → people296 (1张图片)
# 转换完成: Angel_Maza → people297 (1张图片)
# 转换完成: Angela_Alvarado_Rosa → people298 (1张图片)
# 转换完成: Angela_Bassett → people299 (6张图片)
# 转换完成: Angela_Lansbury → people300 (2张图片)
# 转换完成: Angela_Mascia-Frye → people301 (1张图片)
# 转换完成: Angela_Merkel → people302 (5张图片)
# 转换完成: Angelica_Romero → people303 (1张图片)
# 转换完成: Angelina_Jolie → people304 (20张图片)
# 转换完成: Angelo_Genova → people305 (1张图片)
# 转换完成: Angelo_Reyes → people306 (4张图片)
# 转换完成: Angie_Arzola → people307 (1张图片)
# 转换完成: Angie_Martinez → people308 (1张图片)
# 转换完成: Anibal_Ibarra → people309 (3张图片)
# 转换完成: Anil_Ramsook → people310 (1张图片)
# 转换完成: Anita_DeFrantz → people311 (1张图片)
# 转换完成: Anja_Paerson → people312 (1张图片)
# 转换完成: Anjum_Hussain → people313 (1张图片)
# 转换完成: Ann_Godbehere → people314 (1张图片)
# 转换完成: Ann_Landers → people315 (1张图片)
# 转换完成: Ann_Morgan → people316 (1张图片)
# 转换完成: Ann_Veneman → people317 (11张图片)
# 转换完成: Anna_Chicherova → people318 (1张图片)
# 转换完成: Anna_Faris → people319 (1张图片)
# 转换完成: Anna_Jones → people320 (1张图片)
# 转换完成: Anna_Kournikova → people321 (12张图片)
# 转换完成: Anna_Nicole_Smith → people322 (2张图片)
# 转换完成: Anne_Cavers → people323 (1张图片)
# 转换完成: Anne_Donovan → people324 (1张图片)
# 转换完成: Anne_Heche → people325 (1张图片)
# 转换完成: Anne_Krueger → people326 (3张图片)
# 转换完成: Anne_McLellan → people327 (3张图片)
# 转换完成: Anne_ONeil → people328 (1张图片)
# 转换完成: Anneli_Jaatteenmaki → people329 (2张图片)
# 转换完成: Annette_Bening → people330 (2张图片)
# 转换完成: Annette_Lu → people331 (3张图片)
# 转换完成: Annie-Jeanne_Reynaud → people332 (1张图片)
# 转换完成: Annie_Chaplin → people333 (1张图片)
# 转换完成: Annie_Machon → people334 (1张图片)
# 转换完成: Annika_Sorenstam → people335 (1张图片)
# 转换完成: Antanas_Valionis → people336 (1张图片)
# 转换完成: Anthony_Carter → people337 (1张图片)
# 转换完成: Anthony_Corso → people338 (1张图片)
# 转换完成: Anthony_Ervin → people339 (1张图片)
# 转换完成: Anthony_Fauci → people340 (2张图片)
# 转换完成: Anthony_Garotinho → people341 (1张图片)
# 转换完成: Anthony_Hazen → people342 (1张图片)
# 转换完成: Anthony_Hopkins → people343 (2张图片)
# 转换完成: Anthony_LaPaglia → people344 (2张图片)
# 转换完成: Anthony_Lee_Johnson → people345 (1张图片)
# 转换完成: Anthony_Mazur → people346 (1张图片)
# 转换完成: Anthony_Pico → people347 (1张图片)
# 转换完成: Anthony_Pisciotti → people348 (1张图片)
# 转换完成: Anthony_Principi → people349 (1张图片)
# 转换完成: Anthony_Rackauckas → people350 (1张图片)
# 转换完成: Anthony_Scott_Miller → people351 (1张图片)
# 转换完成: Antje_Buschschulte → people352 (1张图片)
# 转换完成: Anton_Balasingham → people353 (1张图片)
# 转换完成: Antonio_Banderas → people354 (5张图片)
# 转换完成: Antonio_Bernardo → people355 (1张图片)
# 转换完成: Antonio_Cassano → people356 (1张图片)
# 转换完成: Antonio_Catania → people357 (1张图片)
# 转换完成: Antonio_Elias_Saca → people358 (1张图片)
# 转换完成: Antonio_Palocci → people359 (8张图片)
# 转换完成: Antonio_Trillanes → people360 (3张图片)
# 转换完成: Antony_Leung → people361 (4张图片)
# 转换完成: Antwun_Echols → people362 (1张图片)
# 转换完成: Anwar_Ibrahim → people363 (2张图片)
# 转换完成: Anzori_Kikalishvili → people364 (1张图片)
# 转换完成: Aparna_Pillai → people365 (1张图片)
# 转换完成: Aram_Adler → people366 (1张图片)
# 转换完成: Arantxa_Sanchez-Vicario → people367 (2张图片)
# 转换完成: Aretha_Franklin → people368 (1张图片)
# 转换完成: Ari_Bousbib → people369 (1张图片)
# 转换完成: Ari_Fleischer → people370 (13张图片)
# 转换完成: Arianna_Huffington → people371 (4张图片)
# 转换完成: Arie_Haan → people372 (1张图片)
# 转换完成: Ariel_Sharon → people373 (77张图片)
# 转换完成: Arif_Mardin → people374 (1张图片)
# 转换完成: Arlen_Specter → people375 (3张图片)
# 转换完成: Armand_Sargen → people376 (1张图片)
# 转换完成: Armando_Avila_Panchame → people377 (1张图片)
# 转换完成: Armando_Calderon_Sol → people378 (1张图片)
# 转换完成: Armando_Carrillo → people379 (1张图片)
# 转换完成: Arminio_Fraga → people380 (6张图片)
# 转换完成: Arnaud_Clement → people381 (2张图片)
# 转换完成: Arnaud_Lagardere → people382 (1张图片)
# 转换完成: Arnie_Boehm → people383 (1张图片)
# 转换完成: Arnold_Palmer → people384 (3张图片)
# 转换完成: Arnold_Schwarzenegger → people385 (42张图片)
# 转换完成: Arnold_Scott → people386 (1张图片)
# 转换完成: Arnoldo_Aleman → people387 (5张图片)
# 转换完成: Aron_Ralston → people388 (2张图片)
# 转换完成: Arsinee_Khanjian → people389 (2张图片)
# 转换完成: Art_Cooper → people390 (1张图片)
# 转换完成: Art_Hoffmann → people391 (2张图片)
# 转换完成: Art_Howe → people392 (4张图片)
# 转换完成: Art_Lopez → people393 (1张图片)
# 转换完成: Arthur_Johnson → people394 (1张图片)
# 转换完成: Arthur_Martinez → people395 (1张图片)
# 转换完成: Artieas_Shanks → people396 (1张图片)
# 转换完成: Arturo_Gatti → people397 (3张图片)
# 转换完成: Arye_Mekel → people398 (2张图片)
# 转换完成: Asa_Hutchinson → people399 (2张图片)
# 转换完成: Ascencion_Barajas → people400 (1张图片)
# 转换完成: Ashanti → people401 (5张图片)
# 转换完成: Ashlea_Talbot → people402 (1张图片)
# 转换完成: Ashley_Judd → people403 (1张图片)
# 转换完成: Ashley_Olsen → people404 (1张图片)
# 转换完成: Ashley_Postell → people405 (1张图片)
# 转换完成: Ashraf_Alasmar → people406 (1张图片)
# 转换完成: Ashraf_Ghani → people407 (1张图片)
# 转换完成: Ashton_Kutcher → people408 (3张图片)
# 转换完成: Asif_Ali_Zardari → people409 (1张图片)
# 转换完成: Asif_Hanif → people410 (1张图片)
# 转换完成: Askar_Akayev → people411 (1张图片)
# 转换完成: Asmaa_Assad → people412 (1张图片)
# 转换完成: Assad_Ahmadi → people413 (1张图片)
# 转换完成: Astou_Ndiaye-Diatta → people414 (1张图片)
# 转换完成: Astrid_Betancourt → people415 (1张图片)
# 转换完成: Astrid_Eyzaguirre → people416 (1张图片)
# 转换完成: Atal_Bihari_Vajpayee → people417 (24张图片)
# 转换完成: Ataollah_Mohajerani → people418 (1张图片)
# 转换完成: Atiabet_Ijan_Amabel → people419 (1张图片)
# 转换完成: Atom_Egoyan → people420 (1张图片)
# 转换完成: Atsushi_Sato → people421 (1张图片)
# 转换完成: Audrey_Lacroix → people422 (1张图片)
# 转换完成: Audrey_Sauret → people423 (1张图片)
# 转换完成: Augustin_Calleri → people424 (4张图片)
# 转换完成: Augusto_Pinochet → people425 (2张图片)
# 转换完成: Augusto_Roa_Bastos → people426 (2张图片)
# 转换完成: Aung_San_Suu_Kyi → people427 (2张图片)
# 转换完成: Austin_Kearns → people428 (1张图片)
# 转换完成: Avril_Lavigne → people429 (1张图片)
# 转换完成: Azmi_Bishara → people430 (1张图片)
# 转换完成: Azra_Akin → people431 (4张图片)
# 转换完成: BB_King → people432 (1张图片)
# 转换完成: BJ_Habibie → people433 (1张图片)
# 转换完成: Babe_Ruth → people434 (1张图片)
# 转换完成: Baburam_Bhattari → people435 (1张图片)
# 转换完成: Bak_Chang-Ryun → people436 (1张图片)
# 转换完成: Barbara_Bach → people437 (1张图片)
# 转换完成: Barbara_Becker → people438 (1张图片)
# 转换完成: Barbara_Bodine → people439 (1张图片)
# 转换完成: Barbara_Boxer → people440 (1张图片)
# 转换完成: Barbara_Brezigar → people441 (2张图片)
# 转换完成: Barbara_De_Brun → people442 (1张图片)
# 转换完成: Barbara_Esbin → people443 (1张图片)
# 转换完成: Barbara_Felt-Miller → people444 (1张图片)
# 转换完成: Barbara_Roberts → people445 (1张图片)
# 转换完成: Barbara_Walters → people446 (4张图片)
# 转换完成: Barbora_Strycova → people447 (1张图片)
# 转换完成: Barbra_Streisand → people448 (3张图片)
# 转换完成: Barrett_Jackman → people449 (2张图片)
# 转换完成: Barry_Alvarez → people450 (2张图片)
# 转换完成: Barry_Bonds → people451 (1张图片)
# 转换完成: Barry_Collier → people452 (1张图片)
# 转换完成: Barry_Diller → people453 (1张图片)
# 转换完成: Barry_Ford → people454 (1张图片)
# 转换完成: Barry_Hinson → people455 (1张图片)
# 转换完成: Barry_Nakell → people456 (1张图片)
# 转换完成: Barry_Switzer → people457 (1张图片)
# 转换完成: Barry_Williams → people458 (1张图片)
# 转换完成: Barry_Zito → people459 (2张图片)
# 转换完成: Bart_Freundlich → people460 (1张图片)
# 转换完成: Bart_Hendricks → people461 (1张图片)
# 转换完成: Bartosz_Kizierowski → people462 (1张图片)
# 转换完成: Barzan_al-Tikriti → people463 (1张图片)
# 转换完成: Basdeo_Panday → people464 (1张图片)
# 转换完成: Bashar_Assad → people465 (4张图片)
# 转换完成: Baz_Luhrmann → people466 (1张图片)
# 转换完成: Beatrice_Dalle → people467 (1张图片)
# 转换完成: Beatriz_Merino → people468 (1张图片)
# 转换完成: Beecher_Ray_Kirby → people469 (1张图片)
# 转换完成: Begum_Khaleda_Zia → people470 (2张图片)
# 转换完成: Bela_Karolyi → people471 (1张图片)
# 转换完成: Ben_Affleck → people472 (7张图片)
# 转换完成: Ben_Betts → people473 (1张图片)
# 转换完成: Ben_Braun → people474 (1张图片)
# 转换完成: Ben_Broussard → people475 (1张图片)
# 转换完成: Ben_Cahoon → people476 (1张图片)
# 转换完成: Ben_Chandler → people477 (1张图片)
# 转换完成: Ben_Cohen → people478 (1张图片)
# 转换完成: Ben_Curtis → people479 (3张图片)
# 转换完成: Ben_Davis → people480 (1张图片)
# 转换完成: Ben_Glisan → people481 (2张图片)
# 转换完成: Ben_Howland → people482 (4张图片)
# 转换完成: Ben_Kingsley → people483 (1张图片)
# 转换完成: Ben_Lee → people484 (1张图片)
# 转换完成: Ben_Stein → people485 (1张图片)
# 转换完成: Ben_Wallace → people486 (1张图片)
# 转换完成: Benazir_Bhutto → people487 (5张图片)
# 转换完成: Benedita_da_Silva → people488 (1张图片)
# 转换完成: Benicio_Del_Toro → people489 (1张图片)
# 转换完成: Benito_Santiago → people490 (1张图片)
# 转换完成: Benjamin_Bratt → people491 (1张图片)
# 转换完成: Benjamin_Franklin → people492 (1张图片)
# 转换完成: Benjamin_Martinez → people493 (1张图片)
# 转换完成: Benjamin_McKenzie → people494 (1张图片)
# 转换完成: Benjamin_Netanyahu → people495 (5张图片)
# 转换完成: Benjamin_Neulander → people496 (1张图片)
# 转换完成: Bernadette_Peters → people497 (1张图片)
# 转换完成: Bernard_Ebbers → people498 (1张图片)
# 转换完成: Bernard_Giraudeau → people499 (1张图片)
# 转换完成: Bernard_Kerik → people500 (1张图片)
# 转换完成: Bernard_Landry → people501 (4张图片)
# 转换完成: Bernard_Law → people502 (5张图片)
# 转换完成: Bernard_Lord → people503 (2张图片)
# 转换完成: Bernard_Siegel → people504 (1张图片)
# 转换完成: Bernardo_Segura → people505 (2张图片)
# 转换完成: Bernice_Wong → people506 (1张图片)
# 转换完成: Bertie_Ahern → people507 (5张图片)
# 转换完成: Bertrand_Bonello → people508 (2张图片)
# 转换完成: Bertrand_Delanoe → people509 (1张图片)
# 转换完成: Beth_Blough → people510 (1张图片)
# 转换完成: Beth_Jones → people511 (2张图片)
# 转换完成: Betsy_Coffin → people512 (1张图片)
# 转换完成: Betsy_Smith → people513 (2张图片)
# 转换完成: Bettina_Rheims → people514 (1张图片)
# 转换完成: Betty_Garrison → people515 (1张图片)
# 转换完成: Betty_Williams → people516 (1张图片)
# 转换完成: Beyonce_Knowles → people517 (1张图片)
# 转换完成: Bianca_Jagger → people518 (1张图片)
# 转换完成: Bijan_Darvish → people519 (3张图片)
# 转换完成: Bijan_Namdar_Zangeneh → people520 (2张图片)
# 转换完成: Bilal_Erdogan → people521 (1张图片)
# 转换完成: Biljana_Plavsic → people522 (3张图片)
# 转换完成: Bill_Belichick → people523 (2张图片)
# 转换完成: Bill_Bradley → people524 (1张图片)
# 转换完成: Bill_Butler → people525 (1张图片)
# 转换完成: Bill_Byrne → people526 (1张图片)
# 转换完成: Bill_Callahan → people527 (3张图片)
# 转换完成: Bill_Carmody → people528 (1张图片)
# 转换完成: Bill_Cartwright → people529 (1张图片)
# 转换完成: Bill_Clancy → people530 (1张图片)
# 转换完成: Bill_Clinton → people531 (29张图片)
# 转换完成: Bill_Curry → people532 (1张图片)
# 转换完成: Bill_Doba → people533 (1张图片)
# 转换完成: Bill_Duffey → people534 (1张图片)
# 转换完成: Bill_Elliott → people535 (1张图片)
# 转换完成: Bill_Fennelly → people536 (1张图片)
# 转换完成: Bill_Frist → people537 (9张图片)
# 转换完成: Bill_Gates → people538 (17张图片)
# 转换完成: Bill_Graham → people539 (9张图片)
# 转换完成: Bill_Guerin → people540 (1张图片)
# 转换完成: Bill_Herrion → people541 (1张图片)
# 转换完成: Bill_Hughes → people542 (1张图片)
# 转换完成: Bill_King → people543 (1张图片)
# 转换完成: Bill_Kollar → people544 (1张图片)
# 转换完成: Bill_Kong → people545 (1张图片)
# 转换完成: Bill_Lerach → people546 (1张图片)
# 转换完成: Bill_Maher → people547 (1张图片)
# 转换完成: Bill_Mauldin → people548 (1张图片)
# 转换完成: Bill_McBride → people549 (10张图片)
# 转换完成: Bill_Nelson → people550 (2张图片)
# 转换完成: Bill_OReilly → people551 (1张图片)
# 转换完成: Bill_Parcells → people552 (2张图片)
# 转换完成: Bill_Parsons → people553 (1张图片)
# 转换完成: Bill_Paxton → people554 (4张图片)
# 转换完成: Bill_Pryor → people555 (1张图片)
# 转换完成: Bill_Rainer → people556 (1张图片)
# 转换完成: Bill_Readdy → people557 (1张图片)
# 转换完成: Bill_Richardson → people558 (1张图片)
# 转换完成: Bill_Self → people559 (1张图片)
# 转换完成: Bill_Simon → people560 (15张图片)
# 转换完成: Bill_Sizemore → people561 (2张图片)
# 转换完成: Bill_Stapleton → people562 (1张图片)
# 转换完成: Bill_Stein → people563 (1张图片)
# 转换完成: Bill_Walton → people564 (1张图片)
# 转换完成: Billy_Andrade → people565 (1张图片)
# 转换完成: Billy_Beane → people566 (1张图片)
# 转换完成: Billy_Bob_Thornton → people567 (1张图片)
# 转换完成: Billy_Boyd → people568 (1张图片)
# 转换完成: Billy_Crawford → people569 (1张图片)
# 转换完成: Billy_Crystal → people570 (6张图片)
# 转换完成: Billy_Donovan → people571 (1张图片)
# 转换完成: Billy_Edelin → people572 (1张图片)
# 转换完成: Billy_Gilman → people573 (1张图片)
# 转换完成: Billy_Graham → people574 (2张图片)
# 转换完成: Billy_Joel → people575 (1张图片)
# 转换完成: Billy_Rork → people576 (1张图片)
# 转换完成: Billy_Sollie → people577 (2张图片)
# 转换完成: Billy_Tibbets → people578 (1张图片)
# 转换完成: Bing_Crosby → people579 (1张图片)
# 转换完成: Binyamin_Ben-Eliezer → people580 (7张图片)
# 转换完成: Bison_Dele → people581 (1张图片)
# 转换完成: Bixente_LIzarazu → people582 (1张图片)
# 转换完成: Blas_Ople → people583 (1张图片)
# 转换完成: Blythe_Danner → people584 (2张图片)
# 转换完成: Blythe_Hartley → people585 (2张图片)
# 转换完成: Bo_Pelini → people586 (2张图片)
# 转换完成: Bo_Ryan → people587 (2张图片)
# 转换完成: Bob_Alper → people588 (1张图片)
# 转换完成: Bob_Beauprez → people589 (2张图片)
# 转换完成: Bob_Bowlsby → people590 (1张图片)
# 转换完成: Bob_Cantrell → people591 (1张图片)
# 转换完成: Bob_Colvin → people592 (2张图片)
# 转换完成: Bob_Crippen → people593 (1张图片)
# 转换完成: Bob_Curtis → people594 (1张图片)
# 转换完成: Bob_Dole → people595 (3张图片)
# 转换完成: Bob_Eskridge → people596 (1张图片)
# 转换完成: Bob_Ferguson → people597 (1张图片)
# 转换完成: Bob_Geldof → people598 (2张图片)
# 转换完成: Bob_Goldman → people599 (1张图片)
# 转换完成: Bob_Graham → people600 (6张图片)
# 转换完成: Bob_Guccione → people601 (1张图片)
# 转换完成: Bob_Hartley → people602 (1张图片)
# 转换完成: Bob_Hayes → people603 (1张图片)
# 转换完成: Bob_Herz → people604 (1张图片)
# 转换完成: Bob_Holden → people605 (1张图片)
# 转换完成: Bob_Hope → people606 (8张图片)
# 转换完成: Bob_Huggins → people607 (4张图片)
# 转换完成: Bob_Iger → people608 (1张图片)
# 转换完成: Bob_Krueger → people609 (1张图片)
# 转换完成: Bob_Melvin → people610 (1张图片)
# 转换完成: Bob_Menendez → people611 (1张图片)
# 转换完成: Bob_Newhart → people612 (1张图片)
# 转换完成: Bob_Petrino → people613 (1张图片)
# 转换完成: Bob_Riley → people614 (1张图片)
# 转换完成: Bob_Stoops → people615 (7张图片)
# 转换完成: Bob_Sulkin → people616 (1张图片)
# 转换完成: Bob_Taft → people617 (1张图片)
# 转换完成: Bob_Wright → people618 (1张图片)
# 转换完成: Bobby_Bowden → people619 (1张图片)
# 转换完成: Bobby_Goldwater → people620 (2张图片)
# 转换完成: Bobby_Jackson → people621 (1张图片)
# 转换完成: Bobby_Kielty → people622 (1张图片)
# 转换完成: Bobby_Robson → people623 (2张图片)
# 转换完成: Bobo_Balde → people624 (1张图片)
# 转换完成: Bode_Miller → people625 (2张图片)
# 转换完成: Bonnie_Fuller → people626 (1张图片)
# 转换完成: Bonnie_Hunt → people627 (1张图片)
# 转换完成: Bono → people628 (3张图片)
# 转换完成: Boris_Becker → people629 (6张图片)
# 转换完成: Boris_Berezovsky → people630 (2张图片)
# 转换完成: Boris_Henry → people631 (1张图片)
# 转换完成: Boris_Jordan → people632 (1张图片)
# 转换完成: Boris_Trajkovski → people633 (1张图片)
# 转换完成: Boris_Yeltsin → people634 (2张图片)
# 转换完成: Boutros_Boutros_Ghali → people635 (1张图片)
# 转换完成: Brad_Alexander_Smith → people636 (1张图片)
# 转换完成: Brad_Banks → people637 (1张图片)
# 转换完成: Brad_Brownell → people638 (1张图片)
# 转换完成: Brad_Garrett → people639 (4张图片)
# 转换完成: Brad_Gushue → people640 (1张图片)
# 转换完成: Brad_Johnson → people641 (5张图片)
# 转换完成: Brad_Miller → people642 (1张图片)
# 转换完成: Brad_Pitt → people643 (1张图片)
# 转换完成: Brad_Russ → people644 (1张图片)
# 转换完成: Brad_Smith → people645 (1张图片)
# 转换完成: Brad_Wilk → people646 (1张图片)
# 转换完成: Brady_Rodgers → people647 (1张图片)
# 转换完成: Brajesh_Mishra → people648 (1张图片)
# 转换完成: Brandon_Boyd → people649 (1张图片)
# 转换完成: Brandon_Fails → people650 (1张图片)
# 转换完成: Brandon_Hammond → people651 (1张图片)
# 转换完成: Brandon_Inge → people652 (1张图片)
# 转换完成: Brandon_Jones → people653 (1张图片)
# 转换完成: Brandon_Knight → people654 (1张图片)
# 转换完成: Brandon_Larson → people655 (1张图片)
# 转换完成: Brandon_Lloyd → people656 (1张图片)
# 转换完成: Brandon_Robinson → people657 (1张图片)
# 转换完成: Brandon_Spann → people658 (1张图片)
# 转换完成: Brandon_Webb → people659 (1张图片)
# 转换完成: Branko_Crvenkovski → people660 (3张图片)
# 转换完成: Brawley_King → people661 (1张图片)
# 转换完成: Brenda_Magana → people662 (1张图片)
# 转换完成: Brenda_Wilson → people663 (1张图片)
# 转换完成: Brenda_van_Dam → people664 (1张图片)
# 转换完成: Brendan_Fraser → people665 (1张图片)
# 转换完成: Brendan_Gaughan → people666 (1张图片)
# 转换完成: Brendan_Hansen → people667 (2张图片)
# 转换完成: Brendan_Stai → people668 (1张图片)
# 转换完成: Brennon_Leighton → people669 (1张图片)
# 转换完成: Brent_Coles → people670 (1张图片)
# 转换完成: Brett_Boone → people671 (1张图片)
# 转换完成: Brett_Hawke → people672 (1张图片)
# 转换完成: Brett_Hull → people673 (1张图片)
# 转换完成: Brett_Perry → people674 (1张图片)
# 转换完成: Brian_Billick → people675 (1张图片)
# 转换完成: Brian_Campbell → people676 (1张图片)
# 转换完成: Brian_Cashman → people677 (1张图片)
# 转换完成: Brian_Clemens → people678 (1张图片)
# 转换完成: Brian_Cook → people679 (1张图片)
# 转换完成: Brian_Cowen → people680 (2张图片)
# 转换完成: Brian_De_Palma → people681 (1张图片)
# 转换完成: Brian_Florence → people682 (1张图片)
# 转换完成: Brian_Grazier → people683 (1张图片)
# 转换完成: Brian_Gregory → people684 (1张图片)
# 转换完成: Brian_Griese → people685 (2张图片)
# 转换完成: Brian_Heidik → people686 (2张图片)
# 转换完成: Brian_Henson → people687 (1张图片)
# 转换完成: Brian_Jordan → people688 (1张图片)
# 转换完成: Brian_Kerr → people689 (1张图片)
# 转换完成: Brian_Lara → people690 (1张图片)
# 转换完成: Brian_McIntyre → people691 (1张图片)
# 转换完成: Brian_Meadors → people692 (1张图片)
# 转换完成: Brian_Mulroney → people693 (2张图片)
# 转换完成: Brian_Olson → people694 (1张图片)
# 转换完成: Brian_Pavlich → people695 (1张图片)
# 转换完成: Brian_Scalabrine → people696 (1张图片)
# 转换完成: Brian_Schneider → people697 (1张图片)
# 转换完成: Brian_StPierre → people698 (1张图片)
# 转换完成: Brian_Van_Dusen → people699 (1张图片)
# 转换完成: Brian_Weaver → people700 (1张图片)
# 转换完成: Brian_Wells → people701 (2张图片)
# 转换完成: Brian_Williams → people702 (1张图片)
# 转换完成: Bridget_Fonda → people703 (3张图片)
# 转换完成: Bridgette_Wilson-Sampras → people704 (3张图片)
# 转换完成: Brigitte_Boisselier → people705 (2张图片)
# 转换完成: Britney_Spears → people706 (14张图片)
# 转换完成: Brittany_Snow → people707 (1张图片)
# 转换完成: Brock_Berlin → people708 (1张图片)
# 转换完成: Bronson_Arroyo → people709 (1张图片)
# 转换完成: Brook_Robinson → people710 (1张图片)
# 转换完成: Brooke_Adams → people711 (1张图片)
# 转换完成: Brooke_Gordon → people712 (1张图片)
# 转换完成: Brooke_Shields → people713 (2张图片)
# 转换完成: Bruce_Arena → people714 (1张图片)
# 转换完成: Bruce_Gebhardt → people715 (1张图片)
# 转换完成: Bruce_Lunsford → people716 (1张图片)
# 转换完成: Bruce_Paltrow → people717 (1张图片)
# 转换完成: Bruce_Springsteen → people718 (4张图片)
# 转换完成: Bruce_Van_De_Velde → people719 (2张图片)
# 转换完成: Bruce_Weber → people720 (2张图片)
# 转换完成: Bruce_Willis → people721 (1张图片)
# 转换完成: Bruna_Colosio → people722 (1张图片)
# 转换完成: Bruno_Junquiera → people723 (1张图片)
# 转换完成: Bryan_Adams → people724 (1张图片)
# 转换完成: Bryan_Chui → people725 (1张图片)
# 转换完成: Bryan_Cooley → people726 (1张图片)
# 转换完成: Bryan_Murray → people727 (1张图片)
# 转换完成: Bryan_Thomas → people728 (1张图片)
# 转换完成: Bryant_Young → people729 (1张图片)
# 转换完成: Bryce_Carmine → people730 (1张图片)
# 转换完成: Buck_Rodgers → people731 (1张图片)
# 转换完成: Bud_Selig → people732 (4张图片)
# 转换完成: Budd_Schulberg → people733 (1张图片)
# 转换完成: Buddy_Ryan → people734 (1张图片)
# 转换完成: Buford_Blount → people735 (1张图片)
# 转换完成: Bulent_Ecevit → people736 (6张图片)
# 转换完成: Bustam_A_Zedan_Aljanabi → people737 (1张图片)
# 转换完成: Butch_Davis → people738 (2张图片)
# 转换完成: Buzz_Hargrove → people739 (1张图片)
# 转换完成: Byron_Scott → people740 (2张图片)
# 转换完成: Cabas → people741 (1张图片)
# 转换完成: Caio_Blat → people742 (1张图片)
# 转换完成: Calbert_Cheaney → people743 (1张图片)
# 转换完成: Calista_Flockhart → people744 (6张图片)
# 转换完成: Calvin_Harrison → people745 (1张图片)
# 转换完成: Calvin_Joseph_Coleman → people746 (1张图片)
# 转换完成: Cameron_Diaz → people747 (6张图片)
# 转换完成: Camilla_Parker_Bowles → people748 (2张图片)
# 转换完成: Camille_Colvin → people749 (1张图片)
# 转换完成: Camille_Lewis → people750 (1张图片)
# 转换完成: Camryn_Manheim → people751 (1张图片)
# 转换完成: Candace_Sutton → people752 (1张图片)
# 转换完成: Candice_Beatty → people753 (1张图片)
# 转换完成: Candice_Bergen → people754 (3张图片)
# 转换完成: Candie_Kung → people755 (4张图片)
# 转换完成: Carey_Lowell → people756 (1张图片)
# 转换完成: Cari_Davis → people757 (1张图片)
# 转换完成: Carin_Koch → people758 (1张图片)
# 转换完成: Carina_Lau_Ka-ling → people759 (1张图片)
# 转换完成: Carl_Levin → people760 (1张图片)
# 转换完成: Carl_Pope → people761 (1张图片)
# 转换完成: Carl_Reiner → people762 (2张图片)
# 转换完成: Carla_Del_Ponte → people763 (5张图片)
# 转换完成: Carla_Gay_Balingit → people764 (1张图片)
# 转换完成: Carla_Gugino → people765 (1张图片)
# 转换完成: Carla_Moreno → people766 (1张图片)
# 转换完成: Carla_Myers → people767 (2张图片)
# 转换完成: Carla_Sullivan → people768 (1张图片)
# 转换完成: Carla_Tricoli → people769 (1张图片)
# 转换完成: Carlo_Ancelotti → people770 (3张图片)
# 转换完成: Carlo_Azeglio_Ciampi → people771 (1张图片)
# 转换完成: Carlos_Alberto → people772 (1张图片)
# 转换完成: Carlos_Alberto_Parreira → people773 (1张图片)
# 转换完成: Carlos_Arroyo → people774 (1张图片)
# 转换完成: Carlos_Barra → people775 (1张图片)
# 转换完成: Carlos_Barragan → people776 (1张图片)
# 转换完成: Carlos_Beltran → people777 (1张图片)
# 转换完成: Carlos_Bianchi → people778 (2张图片)
# 转换完成: Carlos_De_Abreu → people779 (1张图片)
# 转换完成: Carlos_Fasciolo → people780 (1张图片)
# 转换完成: Carlos_Ghosn → people781 (2张图片)
# 转换完成: Carlos_Iturgaitz → people782 (1张图片)
# 转换完成: Carlos_Juarez → people783 (1张图片)
# 转换完成: Carlos_Lordkipanitse → people784 (1张图片)
# 转换完成: Carlos_Manuel_Pruneda → people785 (3张图片)
# 转换完成: Carlos_Menem → people786 (21张图片)
# 转换完成: Carlos_Mesa → people787 (2张图片)
# 转换完成: Carlos_Moya → people788 (19张图片)
# 转换完成: Carlos_Ortega → people789 (3张图片)
# 转换完成: Carlos_Paternina → people790 (1张图片)
# 转换完成: Carlos_Queiroz → people791 (1张图片)
# 转换完成: Carlos_Quintanilla_Schmidt → people792 (2张图片)
# 转换完成: Carlos_Ruckauf → people793 (1张图片)
# 转换完成: Carlos_Ruiz → people794 (3张图片)
# 转换完成: Carlos_Salinas → people795 (1张图片)
# 转换完成: Carlos_Savedra → people796 (1张图片)
# 转换完成: Carlos_Vives → people797 (4张图片)
# 转换完成: Carlton_Baugh → people798 (1张图片)
# 转换完成: Carlton_Dotson → people799 (1张图片)
# 转换完成: Carly_Fiorina → people800 (3张图片)
# 转换完成: Carly_Gullickson → people801 (1张图片)
# 转换完成: Carmen_Electra → people802 (6张图片)
# 转换完成: Carol_Burnett → people803 (2张图片)
# 转换完成: Carol_Carmody → people804 (1张图片)
# 转换完成: Carol_Moseley_Braun → people805 (2张图片)
# 转换完成: Carol_Niedermayer → people806 (1张图片)
# 转换完成: Carol_Williams → people807 (1张图片)
# 转换完成: Carolina_Barco → people808 (1张图片)
# 转换完成: Carolina_Kluft → people809 (3张图片)
# 转换完成: Carolina_Moraes → people810 (2张图片)
# 转换完成: Caroline_Dhavernas → people811 (1张图片)
# 转换完成: Caroline_Kennedy → people812 (3张图片)
# 转换完成: Caroline_Link → people813 (1张图片)
# 转换完成: Carolyn_Dawn_Johnson → people814 (3张图片)
# 转换完成: Carolyn_Kuhl → people815 (1张图片)
# 转换完成: Carrie-Anne_Moss → people816 (5张图片)
# 转换完成: Carroll_Weimer → people817 (1张图片)
# 转换完成: Carson_Daly → people818 (2张图片)
# 转换完成: Carson_Palmer → people819 (4张图片)
# 转换完成: Casey_Crowder → people820 (1张图片)
# 转换完成: Casey_Mears → people821 (1张图片)
# 转换完成: Cass_Ballenger → people822 (1张图片)
# 转换完成: Cassandra_Heise → people823 (1张图片)
# 转换完成: Casy_Preslar → people824 (1张图片)
# 转换完成: Cate_Blanchett → people825 (4张图片)
# 转换完成: Catherine_Bell → people826 (1张图片)
# 转换完成: Catherine_Deneuve → people827 (5张图片)
# 转换完成: Catherine_Donkers → people828 (1张图片)
# 转换完成: Catherine_Ndereba → people829 (1张图片)
# 转换完成: Catherine_Woodard → people830 (1张图片)
# 转换完成: Catherine_Zeta-Jones → people831 (11张图片)
# 转换完成: Cathryn_Crawford → people832 (1张图片)
# 转换完成: Cathy_Chisholm → people833 (1张图片)
# 转换完成: Cathy_Cunningham → people834 (1张图片)
# 转换完成: Cathy_Freeman → people835 (2张图片)
# 转换完成: Catriona_Le_May_Doan → people836 (1张图片)
# 转换完成: Cecile_de_France → people837 (1张图片)
# 转换完成: Cecilia_Bolocco → people838 (3张图片)
# 转换完成: Cecilia_Chang → people839 (1张图片)
# 转换完成: Cecilia_Cheung → people840 (1张图片)
# 转换完成: Cedric_Benson → people841 (1张图片)
# 转换完成: Celia_Cruz → people842 (1张图片)
# 转换完成: Celine_Dion → people843 (8张图片)
# 转换完成: Celso_Amorim → people844 (2张图片)
# 转换完成: Celso_Lafer → people845 (1张图片)
# 转换完成: Cemil_Cicek → people846 (1张图片)
# 转换完成: Cesar_Gaviria → people847 (8张图片)
# 转换完成: Cesar_Maia → people848 (2张图片)
# 转换完成: Cha_Yung-gu → people849 (1张图片)
# 转换完成: Chadha_Gurinder → people850 (1张图片)
# 转换完成: Chakib_Khelil → people851 (2张图片)
# 转换完成: Chan_Choi → people852 (1张图片)
# 转换完成: Chan_Gailey → people853 (3张图片)
# 转换完成: Chan_Ho_Park → people854 (1张图片)
# 转换完成: Chance_Mock → people855 (1张图片)
# 转换完成: Chanda_Rubin → people856 (5张图片)
# 转换完成: Chandrika_Kumaratunga → people857 (1张图片)
# 转换完成: Chang_Dae-whan → people858 (2张图片)
# 转换完成: Chang_Jae_On → people859 (1张图片)
# 转换完成: Chang_Saio-yue → people860 (1张图片)
# 转换完成: Chang_Sang → people861 (1张图片)
# 转换完成: Chang_Tso → people862 (1张图片)
# 转换完成: Chante_Jawan_Mallard → people863 (1张图片)
# 转换完成: Charla_Moye → people864 (1张图片)
# 转换完成: Charlene_Barshefsky → people865 (1张图片)
# 转换完成: Charles_Bell → people866 (1张图片)
# 转换完成: Charles_Bronson → people867 (3张图片)
# 转换完成: Charles_Chandler_IV → people868 (1张图片)
# 转换完成: Charles_Cope → people869 (1张图片)
# 转换完成: Charles_Grassley → people870 (2张图片)
# 转换完成: Charles_Holzner → people871 (1张图片)
# 转换完成: Charles_Ingram → people872 (1张图片)
# 转换完成: Charles_Kartman → people873 (2张图片)
# 转换完成: Charles_Lebois → people874 (1张图片)
# 转换完成: Charles_Mathews → people875 (2张图片)
# 转换完成: Charles_Moose → people876 (13张图片)
# 转换完成: Charles_Pickering → people877 (1张图片)
# 转换完成: Charles_Pouty → people878 (1张图片)
# 转换完成: Charles_Richardson → people879 (1张图片)
# 转换完成: Charles_Rogers → people880 (1张图片)
# 转换完成: Charles_Schumer → people881 (2张图片)
# 转换完成: Charles_Tannok → people882 (1张图片)
# 转换完成: Charles_Taylor → people883 (9张图片)
# 转换完成: Charley_Armey → people884 (1张图片)
# 转换完成: Charlie_Coles → people885 (1张图片)
# 转换完成: Charlie_Deane → people886 (1张图片)
# 转换完成: Charlie_Garner → people887 (1张图片)
# 转换完成: Charlie_Hunnam → people888 (1张图片)
# 转换完成: Charlie_Sheen → people889 (1张图片)
# 转换完成: Charlie_Williams → people890 (1张图片)
# 转换完成: Charlie_Zaa → people891 (2张图片)
# 转换完成: Charlize_Theron → people892 (1张图片)
# 转换完成: Charlotte_Casiraghi → people893 (1张图片)
# 转换完成: Charlotte_Chambers → people894 (1张图片)
# 转换完成: Charlotte_Church → people895 (1张图片)
# 转换完成: Charlotte_Rampling → people896 (2张图片)
# 转换完成: Charlton_Heston → people897 (6张图片)
# 转换完成: Charmaine_Crooks → people898 (1张图片)
# 转换完成: Chawki_Armali → people899 (1张图片)
# 转换完成: Chea_Sophara → people900 (1张图片)
# 转换完成: Chelsea_Clinton → people901 (1张图片)
# 转换完成: Chen_Kaige → people902 (1张图片)
# 转换完成: Chen_Liang_Yu → people903 (2张图片)
# 转换完成: Chen_Shui-bian → people904 (5张图片)
# 转换完成: Chen_Tsai-chin → people905 (1张图片)
# 转换完成: Cherie_Blair → people906 (4张图片)
# 转换完成: Cherry_Jones → people907 (1张图片)
# 转换完成: Cheryl_Ford → people908 (1张图片)
# 转换完成: Cheryl_Hines → people909 (1张图片)
# 转换完成: Cheryl_James → people910 (1张图片)
# 转换完成: Cheryl_Little → people911 (1张图片)
# 转换完成: Cheryl_Tiegs → people912 (1张图片)
# 转换完成: Chhouk_Rin → people913 (1张图片)
# 转换完成: Chick_Hearn → people914 (3张图片)
# 转换完成: Chin-Feng_Chen → people915 (1张图片)
# 转换完成: Chin-Hui_Tsao → people916 (1张图片)
# 转换完成: Chip_Burrus → people917 (1张图片)
# 转换完成: Chip_Ganassi → people918 (1张图片)
# 转换完成: Chip_Knight → people919 (1张图片)
# 转换完成: Chistian_Stahl → people920 (1张图片)
# 转换完成: Chita_Rivera → people921 (2张图片)
# 转换完成: Chloe_Sevigny → people922 (1张图片)
# 转换完成: Cho_Myung-kyun → people923 (1张图片)
# 转换完成: Choi_Sung-hong → people924 (5张图片)
# 转换完成: Choi_Yun-yong → people925 (1张图片)
# 转换完成: Chok_Tong_Goh → people926 (2张图片)
# 转换完成: Chris_Andrews → people927 (1张图片)
# 转换完成: Chris_Bell → people928 (2张图片)
# 转换完成: Chris_Byrd → people929 (2张图片)
# 转换完成: Chris_Cirino → people930 (1张图片)
# 转换完成: Chris_Claiborne → people931 (1张图片)
# 转换完成: Chris_Columbus → people932 (1张图片)
# 转换完成: Chris_Cookson → people933 (1张图片)
# 转换完成: Chris_Cooper → people934 (2张图片)
# 转换完成: Chris_Cornell → people935 (1张图片)
# 转换完成: Chris_Crocker → people936 (1张图片)
# 转换完成: Chris_Dodd → people937 (1张图片)
# 转换完成: Chris_Forsyth → people938 (1张图片)
# 转换完成: Chris_Gratton → people939 (1张图片)
# 转换完成: Chris_Hernandez → people940 (1张图片)
# 转换完成: Chris_Klein → people941 (1张图片)
# 转换完成: Chris_Kolanas → people942 (1张图片)
# 转换完成: Chris_Matthews → people943 (1张图片)
# 转换完成: Chris_Moore → people944 (1张图片)
# 转换完成: Chris_Neil → people945 (1张图片)
# 转换完成: Chris_Noth → people946 (1张图片)
# 转换完成: Chris_Penn → people947 (1张图片)
# 转换完成: Chris_Pronger → people948 (1张图片)
# 转换完成: Chris_Reitsma → people949 (1张图片)
# 转换完成: Chris_Rock → people950 (2张图片)
# 转换完成: Chris_Simon → people951 (1张图片)
# 转换完成: Chris_Swecker → people952 (1张图片)
# 转换完成: Chris_Terry → people953 (1张图片)
# 转换完成: Chris_Thomas → people954 (1张图片)
# 转换完成: Chris_Tucker → people955 (2张图片)
# 转换完成: Chris_Whitney → people956 (1张图片)
# 转换完成: Christian_Bale → people957 (1张图片)
# 转换完成: Christian_Fittipaldi → people958 (2张图片)
# 转换完成: Christian_Gimenez → people959 (1张图片)
# 转换完成: Christian_Lacroix → people960 (1张图片)
# 转换完成: Christian_Lirette → people961 (1张图片)
# 转换完成: Christian_Longo → people962 (3张图片)
# 转换完成: Christian_Malcolm → people963 (1张图片)
# 转换完成: Christian_Olsson → people964 (1张图片)
# 转换完成: Christian_Patino → people965 (1张图片)
# 转换完成: Christian_Von_Wernich → people966 (1张图片)
# 转换完成: Christian_Wulff → people967 (2张图片)
# 转换完成: Christiane_Wulff → people968 (1张图片)
# 转换完成: Christina_Aguilera → people969 (4张图片)
# 转换完成: Christina_Sawaya → people970 (1张图片)
# 转换完成: Christine_Arron → people971 (1张图片)
# 转换完成: Christine_Baumgartner → people972 (5张图片)
# 转换完成: Christine_Ebersole → people973 (2张图片)
# 转换完成: Christine_Gregoire → people974 (4张图片)
# 转换完成: Christine_Rau → people975 (1张图片)
# 转换完成: Christine_Todd_Whitman → people976 (6张图片)
# 转换完成: Christoph_Daum → people977 (1张图片)
# 转换完成: Christopher_Amolsch → people978 (1张图片)
# 转换完成: Christopher_Conyers → people979 (1张图片)
# 转换完成: Christopher_Matero → people980 (1张图片)
# 转换完成: Christopher_Patten → people981 (2张图片)
# 转换完成: Christopher_Reeve → people982 (4张图片)
# 转换完成: Christopher_Russell → people983 (1张图片)
# 转换完成: Christopher_Speer → people984 (1张图片)
# 转换完成: Christopher_Walken → people985 (4张图片)
# 转换完成: Christopher_Whittle → people986 (1张图片)
# 转换完成: Christy_Ferer → people987 (1张图片)
# 转换完成: Christy_Turlington → people988 (1张图片)
# 转换完成: Chuanyun_Li → people989 (1张图片)
# 转换完成: Chuck_Amato → people990 (2张图片)
# 转换完成: Chuck_Bednarik → people991 (1张图片)
# 转换完成: Chuck_Eidson → people992 (1张图片)
# 转换完成: Chuck_Finley → people993 (1张图片)
# 转换完成: Chuck_Hagel → people994 (1张图片)
# 转换完成: Chuck_Woolery → people995 (1张图片)
# 转换完成: Chuck_Yeager → people996 (2张图片)
# 转换完成: Chung_Mong-hun → people997 (2张图片)
# 转换完成: Chung_Mong-joon → people998 (2张图片)
# 转换完成: Chyung_Dai-chul → people999 (1张图片)
# 转换完成: Ciaran_Hinds → people1000 (1张图片)
# 转换完成: Cindy_Crawford → people1001 (3张图片)
# 转换完成: Cindy_Klassen → people1002 (1张图片)
# 转换完成: Cindy_Margolis → people1003 (2张图片)
# 转换完成: Cindy_Moll → people1004 (1张图片)
# 转换完成: Cindy_Taylor → people1005 (1张图片)
# 转换完成: Cindy_Zagorski → people1006 (1张图片)
# 转换完成: Ciro_Gomes → people1007 (5张图片)
# 转换完成: Claire_Danes → people1008 (3张图片)
# 转换完成: Claire_De_Gryse → people1009 (1张图片)
# 转换完成: Claire_Hentzen → people1010 (2张图片)
# 转换完成: Claire_Leger → people1011 (2张图片)
# 转换完成: Claire_Tomalin → people1012 (1张图片)
# 转换完成: Clara_Harris → people1013 (5张图片)
# 转换完成: Clare_Latimer → people1014 (1张图片)
# 转换完成: Clare_Short → people1015 (4张图片)
# 转换完成: Clark_Randt → people1016 (1张图片)
# 转换完成: Claude_Jorda → people1017 (1张图片)
# 转换完成: Claudette_Robinson → people1018 (1张图片)
# 转换完成: Claudia_Cardinale → people1019 (1张图片)
# 转换完成: Claudia_Coslovich → people1020 (1张图片)
# 转换完成: Claudia_Pechstein → people1021 (5张图片)
# 转换完成: Claudia_Schiffer → people1022 (3张图片)
# 转换完成: Claudine_Farrell → people1023 (1张图片)
# 转换完成: Claudio_Abbado → people1024 (1张图片)
# 转换完成: Claudio_Lopez → people1025 (1张图片)
# 转换完成: Claudio_Ranieri → people1026 (1张图片)
# 转换完成: Clay_Aiken → people1027 (6张图片)
# 转换完成: Clay_Campbell → people1028 (1张图片)
# 转换完成: Clemente_de_la_Vega → people1029 (1张图片)
# 转换完成: Cliff_Ellis → people1030 (1张图片)
# 转换完成: Clifford_Etienne → people1031 (1张图片)
# 转换完成: Clifford_Robinson → people1032 (1张图片)
# 转换完成: Clint_Eastwood → people1033 (6张图片)
# 转换完成: Clint_Howard → people1034 (1张图片)
# 转换完成: Clint_Lamebear → people1035 (1张图片)
# 转换完成: Clive_Lloyd → people1036 (1张图片)
# 转换完成: Clive_Woodward → people1037 (1张图片)
# 转换完成: Coco_dEste → people1038 (1张图片)
# 转换完成: Cole_Chapman → people1039 (1张图片)
# 转换完成: Coleen_Rowley → people1040 (1张图片)
# 转换完成: Colin_Campbell → people1041 (1张图片)
# 转换完成: Colin_Cowie → people1042 (1张图片)
# 转换完成: Colin_Farrell → people1043 (9张图片)
# 转换完成: Colin_Jackson → people1044 (2张图片)
# 转换完成: Colin_Montgomerie → people1045 (5张图片)
# 转换完成: Colin_Phillips → people1046 (1张图片)
# 转换完成: Colin_Powell → people1047 (236张图片)
# 转换完成: Colin_Prescot → people1048 (1张图片)
# 转换完成: Colleen_Atwood → people1049 (1张图片)
# 转换完成: Colleen_Donovan → people1050 (1张图片)
# 转换完成: Colleen_Jones → people1051 (1张图片)
# 转换完成: Colleen_OClair → people1052 (1张图片)
# 转换完成: Colleen_Ryan → people1053 (1张图片)
# 转换完成: Collis_Temple_III → people1054 (1张图片)
# 转换完成: Columba_Bush → people1055 (1张图片)
# 转换完成: Compay_Segundo → people1056 (1张图片)
# 转换完成: Conan_OBrien → people1057 (4张图片)
# 转换完成: Conchita_Martinez → people1058 (3张图片)
# 转换完成: Condoleezza_Rice → people1059 (11张图片)
# 转换完成: Connie_Chung → people1060 (1张图片)
# 转换完成: Connie_Freydell → people1061 (1张图片)
# 转换完成: Conrad_Black → people1062 (1张图片)
# 转换完成: Constance_Marie → people1063 (3张图片)
# 转换完成: Cora_Cambell → people1064 (1张图片)
# 转换完成: Coretta_Scott_King → people1065 (3张图片)
# 转换完成: Corey_Maggette → people1066 (1张图片)
# 转换完成: Cori_Enghusen → people1067 (1张图片)
# 转换完成: Corinna_Harfouch → people1068 (1张图片)
# 转换完成: Corinne_Coman → people1069 (2张图片)
# 转换完成: Corliss_Williamson → people1070 (1张图片)
# 转换完成: Cosmo_Iacavazzi → people1071 (1张图片)
# 转换完成: Costas_Simitis → people1072 (6张图片)
# 转换完成: Courtney_Cox → people1073 (1张图片)
# 转换完成: Courtney_Love → people1074 (2张图片)
# 转换完成: Craig_Burley → people1075 (1张图片)
# 转换完成: Craig_David → people1076 (1张图片)
# 转换完成: Craig_Doblin → people1077 (1张图片)
# 转换完成: Craig_Fitzgibbon → people1078 (1张图片)
# 转换完成: Craig_MacTavish → people1079 (1张图片)
# 转换完成: Craig_Morgan → people1080 (1张图片)
# 转换完成: Craig_OClair → people1081 (1张图片)
# 转换完成: Craig_Wilson → people1082 (1张图片)
# 转换完成: Crandall_Bowles → people1083 (1张图片)
# 转换完成: Crispin_Glover → people1084 (1张图片)
# 转换完成: Cristian_Barros → people1085 (1张图片)
# 转换完成: Cristiano_da_Matta → people1086 (1张图片)
# 转换完成: Cristina_Fernandez → people1087 (2张图片)
# 转换完成: Cristina_Kirchner → people1088 (1张图片)
# 转换完成: Cristina_Saralegui → people1089 (2张图片)
# 转换完成: Cristina_Torrens_Valero → people1090 (1张图片)
# 转换完成: Cruz_Bustamante → people1091 (5张图片)
# 转换完成: Cuba_Gooding_Jr → people1092 (1张图片)
# 转换完成: Curt_Weldon → people1093 (1张图片)
# 转换完成: Curtis_Joseph → people1094 (1张图片)
# 转换完成: Curtis_Rodriguez → people1095 (1张图片)
# 转换完成: Curtis_Strange → people1096 (1张图片)
# 转换完成: Cyndi_Thompson → people1097 (2张图片)
# 转换完成: Cynthia_Nixon → people1098 (1张图片)
# 转换完成: Cynthia_Rowley → people1099 (1张图片)
# 转换完成: DAngelo_Jimenez → people1100 (1张图片)
# 转换完成: Dagmar_Dunlevy → people1101 (1张图片)
# 转换完成: Dai_Bachtiar → people1102 (2张图片)
# 转换完成: Dai_Chul_Chyung → people1103 (1张图片)
# 转换完成: Daisy_Fuentes → people1104 (4张图片)
# 转换完成: Daja_Bedanova → people1105 (1张图片)
# 转换完成: Dalai_Lama → people1106 (2张图片)
# 转换完成: Dale_Bosworth → people1107 (1张图片)
# 转换完成: Dale_Earnhardt → people1108 (1张图片)
# 转换完成: Dale_Earnhardt_Jr → people1109 (4张图片)
# 转换完成: Dalia_Rabin-Pelosoff → people1110 (1张图片)
# 转换完成: Damarius_Bilbo → people1111 (1张图片)
# 转换完成: Damon_Dash → people1112 (1张图片)
# 转换完成: Damon_Stoudamire → people1113 (1张图片)
# 转换完成: Damon_van_Dam → people1114 (2张图片)
# 转换完成: Dan_Ackroyd → people1115 (1张图片)
# 转换完成: Dan_Bartlett → people1116 (1张图片)
# 转换完成: Dan_Boyle → people1117 (1张图片)
# 转换完成: Dan_Bylsma → people1118 (1张图片)
# 转换完成: Dan_Dickau → people1119 (1张图片)
# 转换完成: Dan_Duquette → people1120 (1张图片)
# 转换完成: Dan_Guerrero → people1121 (1张图片)
# 转换完成: Dan_Kellner → people1122 (1张图片)
# 转换完成: Dan_LaCoutre → people1123 (1张图片)
# 转换完成: Dan_Monson → people1124 (1张图片)
# 转换完成: Dan_Morales → people1125 (3张图片)
# 转换完成: Dan_Prinster → people1126 (1张图片)
# 转换完成: Dan_Quayle → people1127 (1张图片)
# 转换完成: Dan_Reeves → people1128 (1张图片)
# 转换完成: Dan_Snyder → people1129 (1张图片)
# 转换完成: Dan_Wheldon → people1130 (2张图片)
# 转换完成: Dana_Vollmer → people1131 (1张图片)
# 转换完成: Daniel_Barenboim → people1132 (1张图片)
# 转换完成: Daniel_Bruehl → people1133 (1张图片)
# 转换完成: Daniel_Chin → people1134 (1张图片)
# 转换完成: Daniel_Coats → people1135 (1张图片)
# 转换完成: Daniel_Comisso_Urdaneta → people1136 (1张图片)
# 转换完成: Daniel_Darnell → people1137 (1张图片)
# 转换完成: Daniel_Day-Lewis → people1138 (3张图片)
# 转换完成: Daniel_Kurtzer → people1139 (1张图片)
# 转换完成: Daniel_Montenegro → people1140 (1张图片)
# 转换完成: Daniel_Montgomery → people1141 (1张图片)
# 转换完成: Daniel_Ortega → people1142 (1张图片)
# 转换完成: Daniel_Osorno → people1143 (1张图片)
# 转换完成: Daniel_Patrick_Moynihan → people1144 (1张图片)
# 转换完成: Daniel_Pearl → people1145 (1张图片)
# 转换完成: Daniel_Radcliffe → people1146 (4张图片)
# 转换完成: Daniel_Rouse → people1147 (1张图片)
# 转换完成: Daniel_Scioli → people1148 (1张图片)
# 转换完成: Daniel_Zelman → people1149 (1张图片)
# 转换完成: Daniela_Cicarelli → people1150 (1张图片)
# 转换完成: Daniela_Hantuchova → people1151 (2张图片)
# 转换完成: Daniele_Bergamin → people1152 (1张图片)
# 转换完成: Daniele_Hypolito → people1153 (1张图片)
# 转换完成: Daniele_Nardello → people1154 (1张图片)
# 转换完成: Daniell_Sunjata → people1155 (1张图片)
# 转换完成: Danielle_Spencer → people1156 (1张图片)
# 转换完成: Danis_Tanovic → people1157 (1张图片)
# 转换完成: Danny_Ainge → people1158 (1张图片)
# 转换完成: Danny_Avalon → people1159 (1张图片)
# 转换完成: Danny_Elfman → people1160 (1张图片)
# 转换完成: Danny_Glover → people1161 (1张图片)
# 转换完成: Danny_Green → people1162 (1张图片)
# 转换完成: Danny_Morgan → people1163 (1张图片)
# 转换完成: Dany_Heatley → people1164 (1张图片)
# 转换完成: Darcy_Regier → people1165 (1张图片)
# 转换完成: Darin_Erstad → people1166 (1张图片)
# 转换完成: Dario_Camuffo → people1167 (1张图片)
# 转换完成: Dario_Franchitti → people1168 (1张图片)
# 转换完成: Dariusz_Michalczewski → people1169 (1张图片)
# 转换完成: Darko_Milicic → people1170 (1张图片)
# 转换完成: Darla_Moore → people1171 (1张图片)
# 转换完成: Darlene_Garrettson → people1172 (1张图片)
# 转换完成: Darrell_Dickey → people1173 (1张图片)
# 转换完成: Darrell_Issa → people1174 (2张图片)
# 转换完成: Darrell_Porter → people1175 (2张图片)
# 转换完成: Darrell_Royal → people1176 (1张图片)
# 转换完成: Darren_Campel → people1177 (1张图片)
# 转换完成: Darren_Clarke → people1178 (2张图片)
# 转换完成: Darryl_McDaniels → people1179 (1张图片)
# 转换完成: Darryl_Stingley → people1180 (1张图片)
# 转换完成: Darvis_Patton → people1181 (1张图片)
# 转换完成: Daryl_Hannah → people1182 (2张图片)
# 转换完成: Daryl_Jones → people1183 (1张图片)
# 转换完成: Daryl_Parks → people1184 (1张图片)
# 转换完成: Daryl_Sabara → people1185 (1张图片)
# 转换完成: Daryl_Smith → people1186 (1张图片)
# 转换完成: Dave_Barr → people1187 (1张图片)
# 转换完成: Dave_Campo → people1188 (3张图片)
# 转换完成: Dave_Johnson → people1189 (1张图片)
# 转换完成: Dave_Lewis → people1190 (1张图片)
# 转换完成: Dave_Matthews → people1191 (1张图片)
# 转换完成: Dave_McGinnis → people1192 (1张图片)
# 转换完成: Dave_McNally → people1193 (1张图片)
# 转换完成: Dave_McNealey → people1194 (1张图片)
# 转换完成: Dave_Odom → people1195 (1张图片)
# 转换完成: Dave_Potter → people1196 (1张图片)
# 转换完成: Dave_Ragone → people1197 (1张图片)
# 转换完成: Dave_Robertson → people1198 (1张图片)
# 转换完成: Dave_Tucker → people1199 (1张图片)
# 转换完成: Dave_Wannstedt → people1200 (1张图片)
# 转换完成: Dave_Williams → people1201 (1张图片)
# 转换完成: Davey_Johnson → people1202 (1张图片)
# 转换完成: David_Alpay → people1203 (1张图片)
# 转换完成: David_Anderson → people1204 (5张图片)
# 转换完成: David_Arquette → people1205 (1张图片)
# 转换完成: David_Ballantyne → people1206 (1张图片)
# 转换完成: David_Beckham → people1207 (31张图片)
# 转换完成: David_Bell → people1208 (2张图片)
# 转换完成: David_Bisbal → people1209 (1张图片)
# ...
# 转换完成: Tia_Mowry → people5349 (1张图片)
# 转换完成: Tiago_Splitter → people5350 (1张图片)
# 转换完成: Tian_Liang → people5351 (1张图片)
# 转换完成: Tian_Zhuang_Zhuang → people5352 (1张图片)
# 转换完成: Tiffany_Limos → people5353 (1张图片)
# 转换完成: Tiger_Woods → people5354 (23张图片)
# 转换完成: Tim_Allen → people5355 (4张图片)
# 转换完成: Tim_Blake_Nelson → people5356 (1张图片)
# 转换完成: Tim_Chapman → people5357 (2张图片)
# 转换完成: Tim_Conway → people5358 (3张图片)
# 转换完成: Tim_Curley → people5359 (1张图片)
# 转换完成: Tim_Curry → people5360 (2张图片)
# 转换完成: Tim_Duncan → people5361 (4张图片)
# 转换完成: Tim_Floyd → people5362 (2张图片)
# 转换完成: Tim_Henman → people5363 (19张图片)
# 转换完成: Tim_Howard → people5364 (1张图片)
# 转换完成: Tim_Jones → people5365 (1张图片)
# 转换完成: Tim_Lobinger → people5366 (1张图片)
# 转换完成: Tim_Lopes → people5367 (1张图片)
# 转换完成: Tim_Matheson → people5368 (1张图片)
# 转换完成: Tim_Norbeck → people5369 (1张图片)
# 转换完成: Tim_Pawlenty → people5370 (1张图片)
# 转换完成: Tim_Robbins → people5371 (5张图片)
# 转换完成: Tim_Salmon → people5372 (1张图片)
# 转换完成: Tim_Welsh → people5373 (1张图片)
# 转换完成: Timbul_Silaen → people5374 (1张图片)
# 转换完成: Timothy_Coughlin → people5375 (1张图片)
# 转换完成: Timothy_Goebel → people5376 (1张图片)
# 转换完成: Timothy_McVeigh → people5377 (1张图片)
# 转换完成: Timothy_Rigas → people5378 (1张图片)
# 转换完成: Timothy_Wirth → people5379 (1张图片)
# 转换完成: Tina_Andrews → people5380 (1张图片)
# 转换完成: Tina_Brown → people5381 (1张图片)
# 转换完成: Tina_Conner → people5382 (1张图片)
# 转换完成: Tina_Fey → people5383 (1张图片)
# 转换完成: Tina_Pisnik → people5384 (1张图片)
# 转换完成: Tina_Sinatra → people5385 (1张图片)
# 转换完成: Tino_Martinez → people5386 (1张图片)
# 转换完成: Tippi_Hedren → people5387 (2张图片)
# 转换完成: Tirunesh_Dibaba → people5388 (1张图片)
# 转换完成: Toby_Keith → people5389 (1张图片)
# 转换完成: Tocker_Pudwill → people5390 (1张图片)
# 转换完成: Todd_Haynes → people5391 (4张图片)
# 转换完成: Todd_MacCulloch → people5392 (1张图片)
# 转换完成: Todd_Parrott → people5393 (1张图片)
# 转换完成: Todd_Petit → people5394 (1张图片)
# 转换完成: Todd_Reid → people5395 (1张图片)
# 转换完成: Todd_Robbins → people5396 (1张图片)
# 转换完成: Todd_Wike → people5397 (1张图片)
# 转换完成: Tom_Amstutz → people5398 (1张图片)
# 转换完成: Tom_Brady → people5399 (2张图片)
# 转换完成: Tom_Brennan → people5400 (1张图片)
# 转换完成: Tom_Christerson → people5401 (1张图片)
# 转换完成: Tom_Coughlin → people5402 (1张图片)
# 转换完成: Tom_Coverdale → people5403 (2张图片)
# 转换完成: Tom_Craddick → people5404 (4张图片)
# 转换完成: Tom_Crean → people5405 (5张图片)
# 转换完成: Tom_Cruise → people5406 (10张图片)
# 转换完成: Tom_Curley → people5407 (1张图片)
# 转换完成: Tom_Daschle → people5408 (25张图片)
# 转换完成: Tom_DeLay → people5409 (1张图片)
# 转换完成: Tom_Foy → people5410 (1张图片)
# 转换完成: Tom_Gamboa → people5411 (1张图片)
# 转换完成: Tom_Glavine → people5412 (2张图片)
# 转换完成: Tom_Hanks → people5413 (10张图片)
# 转换完成: Tom_Hanusik → people5414 (1张图片)
# 转换完成: Tom_Harkin → people5415 (5张图片)
# 转换完成: Tom_Izzo → people5416 (1张图片)
# 转换完成: Tom_Jones → people5417 (2张图片)
# 转换完成: Tom_Kelly → people5418 (1张图片)
# 转换完成: Tom_Koenigs → people5419 (1张图片)
# 转换完成: Tom_Lantos → people5420 (1张图片)
# 转换完成: Tom_McClintock → people5421 (1张图片)
# 转换完成: Tom_Miller → people5422 (1张图片)
# 转换完成: Tom_Moss → people5423 (1张图片)
# 转换完成: Tom_OBrien → people5424 (1张图片)
# 转换完成: Tom_Osborne → people5425 (1张图片)
# 转换完成: Tom_Poston → people5426 (1张图片)
# 转换完成: Tom_Reilly → people5427 (3张图片)
# 转换完成: Tom_Ridge → people5428 (33张图片)
# 转换完成: Tom_Rouen → people5429 (1张图片)
# 转换完成: Tom_Schnackenberg → people5430 (1张图片)
# 转换完成: Tom_Scully → people5431 (1张图片)
# 转换完成: Tom_Sizemore → people5432 (1张图片)
# 转换完成: Tom_Smothers → people5433 (1张图片)
# 转换完成: Tom_Tunney → people5434 (1张图片)
# 转换完成: Tom_Vilsack → people5435 (1张图片)
# 转换完成: Tom_Watson → people5436 (3张图片)
# 转换完成: Tom_Welch → people5437 (1张图片)
# 转换完成: Tomas_Enge → people5438 (1张图片)
# 转换完成: Tomas_Malik → people5439 (1张图片)
# 转换完成: Tommy_Amaker → people5440 (1张图片)
# 转换完成: Tommy_Franks → people5441 (16张图片)
# 转换完成: Tommy_Haas → people5442 (6张图片)
# 转换完成: Tommy_Lasorda → people5443 (1张图片)
# 转换完成: Tommy_Lewis → people5444 (1张图片)
# 转换完成: Tommy_Maddox → people5445 (1张图片)
# 转换完成: Tommy_Robredo → people5446 (3张图片)
# 转换完成: Tommy_Shane_Steiner → people5447 (1张图片)
# 转换完成: Tommy_Thompson → people5448 (10张图片)
# 转换完成: Tommy_Tubberville → people5449 (1张图片)
# 转换完成: Tomoko_Hagiwara → people5450 (2张图片)
# 转换完成: Tomomi_Morita → people5451 (1张图片)
# 转换完成: Tonga → people5452 (1张图片)
# 转换完成: Toni_Braxton → people5453 (3张图片)
# 转换完成: Toni_Jennings → people5454 (1张图片)
# 转换完成: Tonino_Guerra → people5455 (1张图片)
# 转换完成: Tono_Suratman → people5456 (1张图片)
# 转换完成: Tony_Bennett → people5457 (4张图片)
# 转换完成: Tony_Blair → people5458 (144张图片)
# 转换完成: Tony_Clement → people5459 (1张图片)
# 转换完成: Tony_Cummo → people5460 (1张图片)
# 转换完成: Tony_Curtis → people5461 (2张图片)
# 转换完成: Tony_Elias → people5462 (1张图片)
# 转换完成: Tony_Fernandes → people5463 (1张图片)
# 转换完成: Tony_LaRussa → people5464 (1张图片)
# 转换完成: Tony_Parker → people5465 (2张图片)
# 转换完成: Tony_Shalhoub → people5466 (4张图片)
# 转换完成: Tony_Stewart → people5467 (6张图片)
# 转换完成: Tonya_Payne → people5468 (1张图片)
# 转换完成: Tora_Takagi → people5469 (1张图片)
# 转换完成: Tori_Amos → people5470 (1张图片)
# 转换完成: Torri_Edwards → people5471 (2张图片)
# 转换完成: Toshi_Izawa → people5472 (1张图片)
# 转换完成: Toshihiko_Fukui → people5473 (3张图片)
# 转换完成: Toshimitsu_Motegi → people5474 (1张图片)
# 转换完成: Toutai_Kefu → people5475 (1张图片)
# 转换完成: Tracee_Ellis_Ross → people5476 (2张图片)
# 转换完成: Tracee_Treadwell → people5477 (1张图片)
# 转换完成: Tracy_McGrady → people5478 (2张图片)
# 转换完成: Tracy_Wyle → people5479 (1张图片)
# 转换完成: Travis_Rudolph → people5480 (1张图片)
# 转换完成: Trent_Lott → people5481 (16张图片)
# 转换完成: Trevor_McDonald → people5482 (1张图片)
# 转换完成: Trevor_Watson → people5483 (1张图片)
# 转换完成: Trisha_Meili → people5484 (1张图片)
# 转换完成: Trista_Rehn → people5485 (1张图片)
# 转换完成: Tristan_Gretzky → people5486 (1张图片)
# 转换完成: Troy_Aikman → people5487 (1张图片)
# 转换完成: Troy_Garity → people5488 (1张图片)
# 转换完成: Troy_Hudson → people5489 (1张图片)
# 转换完成: Troy_Jenkins → people5490 (1张图片)
# 转换完成: Troy_Polamalu → people5491 (1张图片)
# 转换完成: Trudi_Lacey → people5492 (1张图片)
# 转换完成: Tsutomu_Takebe → people5493 (2张图片)
# 转换完成: Tubby_Smith → people5494 (3张图片)
# 转换完成: Tuncay_Sanli → people5495 (1张图片)
# 转换完成: Tung_Chee-hwa → people5496 (9张图片)
# 转换完成: Turner_Gill → people5497 (1张图片)
# 转换完成: Turner_Stevenson → people5498 (1张图片)
# 转换完成: Ty_Votaw → people5499 (1张图片)
# 转换完成: Tyler_Grillo → people5500 (1张图片)
# 转换完成: Tyler_Hamilton → people5501 (2张图片)
# 转换完成: Tyra_Banks → people5502 (2张图片)
# 转换完成: Tyron_Garner → people5503 (2张图片)
# 转换完成: Tyrone_Medley → people5504 (1张图片)
# 转换完成: Tzipora_Obziler → people5505 (1张图片)
# 转换完成: Uday_Hussein → people5506 (1张图片)
# 转换完成: Ulrich_Kueperkoch → people5507 (1张图片)
# 转换完成: Uma_Thurman → people5508 (3张图片)
# 转换完成: Uri_Lopolianski → people5509 (1张图片)
# 转换完成: Urmila_Matondkar → people5510 (1张图片)
# 转换完成: Uthai_Pimchaichon → people5511 (1张图片)
# 转换完成: Uzi_Even → people5512 (1张图片)
# 转换完成: Uzi_Landau → people5513 (1张图片)
# 转换完成: Vaclav_Havel → people5514 (9张图片)
# 转换完成: Vaclav_Klaus → people5515 (2张图片)
# 转换完成: Vadim_Devyatovskiy → people5516 (1张图片)
# 转换完成: Vadim_Strogalev → people5517 (1张图片)
# 转换完成: Vagit_Alekperov → people5518 (1张图片)
# 转换完成: Val_Ackerman → people5519 (1张图片)
# 转换完成: Valdas_Adamkus → people5520 (2张图片)
# 转换完成: Valentina_Cervi → people5521 (1张图片)
# 转换完成: Valentina_Tereshkova → people5522 (1张图片)
# 转换完成: Valentino_Rossi → people5523 (6张图片)
# 转换完成: Valeri_Bure → people5524 (1张图片)
# 转换完成: Valerie_Harper → people5525 (2张图片)
# 转换完成: Valerie_Thwaites → people5526 (1张图片)
# 转换完成: Valery_Giscard_dEstaing → people5527 (6张图片)
# 转换完成: Valorie_Brabazon → people5528 (1张图片)
# 转换完成: Van_Hilley → people5529 (1张图片)
# 转换完成: Vanessa_Incontrada → people5530 (4张图片)
# 转换完成: Vanessa_Laine → people5531 (1张图片)
# 转换完成: Vanessa_Redgrave → people5532 (5张图片)
# 转换完成: Vanessa_Williams → people5533 (3张图片)
# 转换完成: Vassilis_Xiros → people5534 (1张图片)
# 转换完成: Vecdi_Gonul → people5535 (1张图片)
# 转换完成: Venus_Williams → people5536 (17张图片)
# 转换完成: Vernon_Forrest → people5537 (1张图片)
# 转换完成: Veronica_Lake → people5538 (1张图片)
# 转换完成: Viara_Vike-Freiberga → people5539 (1张图片)
# 转换完成: Vicente_Fernandez → people5540 (5张图片)
# 转换完成: Vicente_Fox → people5541 (32张图片)
# 转换完成: Vicente_Fox_de_la_Concha → people5542 (1张图片)
# 转换完成: Vicki_Zhao_Wei → people5543 (2张图片)
# 转换完成: Victor_Garber → people5544 (1张图片)
# 转换完成: Victor_Hanescu → people5545 (1张图片)
# 转换完成: Victor_Kraatz → people5546 (1张图片)
# 转换完成: Victoria_Beckham → people5547 (3张图片)
# 转换完成: Victoria_Clarke → people5548 (5张图片)
# 转换完成: Vidar_Helgesen → people5549 (2张图片)
# 转换完成: Vijay_Nambiar → people5550 (1张图片)
# 转换完成: Viktor_Yushchenko → people5551 (1张图片)
# 转换完成: Vin_Diesel → people5552 (2张图片)
# 转换完成: Vince_Carter → people5553 (4张图片)
# 转换完成: Vince_Dooley → people5554 (1张图片)
# 转换完成: Vince_Gill → people5555 (2张图片)
# 转换完成: Vince_Vaughan → people5556 (1张图片)
# 转换完成: Vincent_Brooks → people5557 (7张图片)
# 转换完成: Vincent_Cianci_Jr → people5558 (1张图片)
# 转换完成: Vincent_Gallo → people5559 (3张图片)
# 转换完成: Vincent_Sombrotto → people5560 (1张图片)
# 转换完成: Vincent_Spadea → people5561 (1张图片)
# 转换完成: Vinnie_Jones → people5562 (1张图片)
# 转换完成: Viola_Davis → people5563 (1张图片)
# 转换完成: Virgina_Ruano_Pascal → people5564 (1张图片)
# 转换完成: Vitali_Klitschko → people5565 (4张图片)
# 转换完成: Vivica_Fox → people5566 (2张图片)
# 转换完成: Vladimir_Golovlyov → people5567 (1张图片)
# 转换完成: Vladimir_Meciar → people5568 (1张图片)
# 转换完成: Vladimir_Putin → people5569 (49张图片)
# 转换完成: Vladimir_Spidla → people5570 (3张图片)
# 转换完成: Vladimir_Ustinov → people5571 (1张图片)
# 转换完成: Vladimir_Voltchkov → people5572 (2张图片)
# 转换完成: Vladimiro_Montesinos → people5573 (3张图片)
# 转换完成: Vojislav_Kostunica → people5574 (7张图片)
# 转换完成: Vojislav_Seselj → people5575 (1张图片)
# 转换完成: Vyacheslav_Fetisov → people5576 (1张图片)
# 转换完成: Vytas_Danelius → people5577 (1张图片)
# 转换完成: Walid_Al-Awadi → people5578 (1张图片)
# 转换完成: Wallace_Capel → people5579 (1张图片)
# 转换完成: Wally_Szczerbiak → people5580 (1张图片)
# 转换完成: Walt_Harris → people5581 (1张图片)
# 转换完成: Walter_Annenberg → people5582 (1张图片)
# 转换完成: Walter_Mondale → people5583 (10张图片)
# 转换完成: Walter_Woods → people5584 (1张图片)
# 转换完成: Wan_Yanhai → people5585 (1张图片)
# 转换完成: Wanda_Ilene_Barzee → people5586 (1张图片)
# 转换完成: Wanda_de_la_Jesus → people5587 (1张图片)
# 转换完成: Wang_Fei → people5588 (1张图片)
# 转换完成: Wang_Hailan → people5589 (1张图片)
# 转换完成: Wang_Nan → people5590 (1张图片)
# 转换完成: Wang_Yi → people5591 (2张图片)
# 转换完成: Wang_Yingfan → people5592 (3张图片)
# 转换完成: Ward_Cuff → people5593 (1张图片)
# 转换完成: Warren_Beatty → people5594 (2张图片)
# 转换完成: Warren_Buffett → people5595 (3张图片)
# 转换完成: Warren_Granados → people5596 (1张图片)
# 转换完成: Warren_Truss → people5597 (1张图片)
# 转换完成: Wayne_Allard → people5598 (1张图片)
# 转换完成: Wayne_Brady → people5599 (1张图片)
# 转换完成: Wayne_Ferreira → people5600 (5张图片)
# 转换完成: Wayne_Gretzky → people5601 (4张图片)
# 转换完成: Wayne_Newton → people5602 (1张图片)
# 转换完成: Wei_Wu → people5603 (1张图片)
# 转换完成: Wen_Ho_Lee → people5604 (1张图片)
# 转换完成: Wen_Jiabao → people5605 (13张图片)
# 转换完成: Wendell_Bryant → people5606 (1张图片)
# 转换完成: Wendy_Kennedy → people5607 (1张图片)
# 转换完成: Wendy_Selig → people5608 (1张图片)
# 转换完成: Werner_Schlager → people5609 (1张图片)
# 转换完成: Wes_Craven → people5610 (1张图片)
# 转换完成: Wesley_Clark → people5611 (2张图片)
# 转换完成: Whoopi_Goldberg → people5612 (1张图片)
# 转换完成: Wilbert_Elki_Meza_Majino → people5613 (1张图片)
# 转换完成: Wilbert_Foy → people5614 (1张图片)
# 转换完成: Wilfredo_Moreno → people5615 (1张图片)
# 转换完成: Will_Ferrell → people5616 (1张图片)
# 转换完成: Will_Ofenheusle → people5617 (1张图片)
# 转换完成: Will_Self → people5618 (1张图片)
# 转换完成: Will_Smith → people5619 (2张图片)
# 转换完成: Will_Young → people5620 (1张图片)
# 转换完成: William_Bratton → people5621 (3张图片)
# 转换完成: William_Bulger → people5622 (4张图片)
# 转换完成: William_Burns → people5623 (2张图片)
# 转换完成: William_Cocksedge → people5624 (1张图片)
# 转换完成: William_Delahunt → people5625 (1张图片)
# 转换完成: William_Donaldson → people5626 (7张图片)
# 转换完成: William_Ford_Jr → people5627 (7张图片)
# 转换完成: William_Genego → people5628 (1张图片)
# 转换完成: William_Harrison → people5629 (1张图片)
# 转换完成: William_Hochul → people5630 (2张图片)
# 转换完成: William_Hurt → people5631 (1张图片)
# 转换完成: William_Hyde → people5632 (1张图片)
# 转换完成: William_Jackson → people5633 (1张图片)
# 转换完成: William_Joppy → people5634 (1张图片)
# 转换完成: William_Macy → people5635 (5张图片)
# 转换完成: William_Martin → people5636 (2张图片)
# 转换完成: William_McDonough → people5637 (1张图片)
# 转换完成: William_Morrow → people5638 (1张图片)
# 转换完成: William_Murabito → people5639 (1张图片)
# 转换完成: William_Nessen → people5640 (1张图片)
# 转换完成: William_Overlin → people5641 (1张图片)
# 转换完成: William_Perry → people5642 (1张图片)
# 转换完成: William_Pryor_Jr → people5643 (1张图片)
# 转换完成: William_Ragland → people5644 (1张图片)
# 转换完成: William_Rehnquist → people5645 (2张图片)
# 转换完成: William_Rosenberg → people5646 (1张图片)
# 转换完成: William_Shatner → people5647 (1张图片)
# 转换完成: William_Swor → people5648 (1张图片)
# 转换完成: William_Umbach → people5649 (1张图片)
# 转换完成: William_Webster → people5650 (1张图片)
# 转换完成: Willie_Nelson → people5651 (1张图片)
# 转换完成: Willie_Wilson → people5652 (1张图片)
# 转换完成: Willis_Roberts → people5653 (1张图片)
# 转换完成: Wilma_McNabb → people5654 (1张图片)
# 转换完成: Wilson_Alvarez → people5655 (1张图片)
# 转换完成: Wilton_Gregory → people5656 (1张图片)
# 转换完成: Wim_Duisenberg → people5657 (1张图片)
# 转换完成: Win_Aung → people5658 (4张图片)
# 转换完成: Winona_Ryder → people5659 (24张图片)
# 转换完成: Winston_Churchill → people5660 (1张图片)
# 转换完成: Wolfgang_Becker → people5661 (1张图片)
# 转换完成: Wolfgang_Clement → people5662 (1张图片)
# 转换完成: Wolfgang_Schneiderhan → people5663 (1张图片)
# 转换完成: Wolfgang_Schuessel → people5664 (4张图片)
# 转换完成: Wolfgang_Schwarz → people5665 (1张图片)
# 转换完成: Woodrow_Stanley → people5666 (1张图片)
# 转换完成: Woody_Allen → people5667 (5张图片)
# 转换完成: Wu_Peng → people5668 (1张图片)
# 转换完成: Wu_Yi → people5669 (3张图片)
# 转换完成: Wycliffe_Grousbeck → people5670 (1张图片)
# 转换完成: Xanana_Gusmao → people5671 (5张图片)
# 转换完成: Xavier_Malisse → people5672 (5张图片)
# 转换完成: Xiang_Huaicheng → people5673 (1张图片)
# 转换完成: Xiang_Liu → people5674 (1张图片)
# 转换完成: Xiang_Xu → people5675 (1张图片)
# 转换完成: Ximena_Bohorquez → people5676 (1张图片)
# 转换完成: Yale_Kamisar → people5677 (1张图片)
# 转换完成: Yana_Klochkova → people5678 (1张图片)
# 转换完成: Yang_Hee_Kim → people5679 (1张图片)
# 转换完成: Yang_Jianli → people5680 (1张图片)
# 转换完成: Yang_Pao-yu → people5681 (1张图片)
# 转换完成: Yann_Martel → people5682 (2张图片)
# 转换完成: Yannos_Papantoniou → people5683 (1张图片)
# 转换完成: Yao_Ming → people5684 (8张图片)
# 转换完成: Yasar_Yakis → people5685 (4张图片)
# 转换完成: Yasein_Taher → people5686 (1张图片)
# 转换完成: Yashwant_Sinha → people5687 (7张图片)
# 转换完成: Yasser_Arafat → people5688 (8张图片)
# 转换完成: Yasushi_Akashi → people5689 (1张图片)
# 转换完成: Yasushi_Chimura → people5690 (1张图片)
# 转换完成: Yekaterina_Guseva → people5691 (1张图片)
# 转换完成: Yevgeny_Kafelnikov → people5692 (4张图片)
# 转换完成: Yingfan_Wang → people5693 (1张图片)
# 转换完成: Yishan_Zhang → people5694 (1张图片)
# 转换完成: Yoelbi_Quesada → people5695 (1张图片)
# 转换完成: Yogi_Berra → people5696 (1张图片)
# 转换完成: Yoko_Ono → people5697 (6张图片)
# 转换完成: Yolanda_King → people5698 (1张图片)
# 转换完成: Yoo_Jay-Kun → people5699 (1张图片)
# 转换完成: Yoon_Jeong_Cho → people5700 (1张图片)
# 转换完成: Yoon_Jin-Sik → people5701 (1张图片)
# 转换完成: Yoon_Won-Sik → people5702 (1张图片)
# 转换完成: Yoon_Young-kwan → people5703 (1张图片)
# 转换完成: Yoriko_Kawaguchi → people5704 (14张图片)
# 转换完成: Yory_Boy_Campas → people5705 (1张图片)
# 转换完成: Yoshiyuki_Kamei → people5706 (1张图片)
# 转换完成: Yossi_Beilin → people5707 (2张图片)
# 转换完成: Young_Kim → people5708 (1张图片)
# 转换完成: Yu_Shyi-kun → people5709 (4张图片)
# 转换完成: Yukiko_Okudo → people5710 (2张图片)
# 转换完成: Yukio_Hatoyama → people5711 (1张图片)
# 转换完成: Yuri_Fedotov → people5712 (2张图片)
# 转换完成: Yuri_Luzhkov → people5713 (1张图片)
# 转换完成: Yuri_Malenchenko → people5714 (2张图片)
# 转换完成: Yusaku_Miyazato → people5715 (1张图片)
# 转换完成: Yusuf_Misbac → people5716 (1张图片)
# 转换完成: Yuvraj_Singh → people5717 (1张图片)
# 转换完成: Yves_Brodeur → people5718 (1张图片)
# 转换完成: Zach_Parise → people5719 (1张图片)
# 转换完成: Zach_Pillar → people5720 (1张图片)
# 转换完成: Zach_Safrin → people5721 (1张图片)
# 转换完成: Zafarullah_Khan_Jamali → people5722 (2张图片)
# 转换完成: Zahir_Shah → people5723 (1张图片)
# 转换完成: Zaini_Abdullah → people5724 (1张图片)
# 转换完成: Zakia_Hakki → people5725 (1张图片)
# 转换完成: Zalmay_Khalilzad → people5726 (1张图片)
# 转换完成: Zara_Akhmadova → people5727 (1张图片)
# 转换完成: Zarai_Toledo → people5728 (2张图片)
# 转换完成: Zavad_Zarif → people5729 (1张图片)
# 转换完成: Zdravko_Mucic → people5730 (1张图片)
# 转换完成: Zeljko_Rebraca → people5731 (1张图片)
# 转换完成: Zelma_Novelo → people5732 (1张图片)
# 转换完成: Zeng_Qinghong → people5733 (1张图片)
# 转换完成: Zhang_Wenkang → people5734 (2张图片)
# 转换完成: Zhang_Yimou → people5735 (1张图片)
# 转换完成: Zhang_Ziyi → people5736 (4张图片)
# 转换完成: Zhong_Nanshan → people5737 (1张图片)
# 转换完成: Zhu_Rongji → people5738 (9张图片)
# 转换完成: Zico → people5739 (3张图片)
# 转换完成: Zinedine_Zidane → people5740 (6张图片)
# 转换完成: Ziwang_Xu → people5741 (1张图片)
# 转换完成: Zoe_Ball → people5742 (1张图片)
# 转换完成: Zoran_Djindjic → people5743 (4张图片)
# 转换完成: Zorica_Radovic → people5744 (1张图片)
# 转换完成: Zulfiqar_Ahmed → people5745 (1张图片)
# 转换完成: Zumrati_Juma → people5746 (1张图片)
# 转换完成: Zurab_Tsereteli → people5747 (1张图片)
# 转换完成: Zydrunas_Ilgauskas → people5748 (1张图片)
# 转换完成: cifar-10-batches-py → people5749 (0张图片)

# %% [markdown]
# 通过上述代码，可以将原始数据集的文件夹和文件进行规范化处理，确保数据集的格式统一，便于后续的模型训练和评估。处理后的数据集结构如下：
#
# ```
#     datatests/
#         people0/
#             001.jpg
#             002.jpg
#             ...
#         people1/
#             001.jpg
#             002.jpg
#             ...
#         ...
# ```
#
# 这种规范化的数据格式有助于提高数据加载和预处理的效率，为模型训练提供高质量的数据支持。

# %% [markdown]
# #### **2.4 数据集处理**
#
# 我们对数据集进行转换，统一数据格式，并拆分成多个batch，通过创建数据集迭代器并打印部分数据的形状和类型，确保图像和标签的格式符合模型的输入要求。

# %%
# 这里我们设置batch大小，并定义图像所需要做的数据变换，包括‘Resize’、‘Rescale’、‘HWC2CHW’。
batch_size = 128

transforms = [
    vision.Resize((224, 224)),
    vision.Rescale(1.0 / 255.0, 0),
    vision.HWC2CHW()
]

# 创建训练集和测试集，并拆分成多个batch
train_dataset = train_dataset.map(transforms, 'image').batch(batch_size)
test_dataset = test_dataset.map(transforms, 'image').batch(batch_size)

for image, label in test_dataset.create_tuple_iterator():
    print(f"Shape of image [N, C, H, W]: {image.shape} {image.dtype}")
    print(f"Shape of label: {label.shape} {label.dtype}")
    break
# Out:
# Shape of image [N, C, H, W]: (128, 3, 224, 224) Float32
# Shape of label: (128,) Int32

# %% [markdown]
# #### **2.5 模型构建**
#
# 在本案例中，我们基于MindSpore框架对AlexNet模型进行了重新构建和优化。模型结构在遵循原论文《ImageNet Classification with Deep Convolutional Neural Networks》的基础上，针对单GPU训练环境对通道数进行了适当调整。具体来说，除第一个卷积层保持原通道数外，第二到第四个卷积层的通道数进行了合并，以适应计算资源的限制。
#
# 在模型定义方面，我们沿用了MindSpore框架的标准流程。首先，定义了conv函数和fc_with_initialize函数，用于自定义nn.Conv2d卷积层和nn.Dense全连接层的初始化。然后，在AlexNet类中重写了__init__和construct方法。在__init__方法中，我们依次定义了模型的各个层，包括五个卷积层、ReLU激活函数、最大池化层、Flatten层、三个全连接层以及Dropout层。其中，新增了两个卷积层（conv6和conv7）和一个全连接层（fc3），以进一步提升模型的特征提取和分类能力。
#
# 在construct方法中，我们构建了模型的前向传播过程。输入数据依次经过卷积层、激活函数、池化层等操作，逐步提取高级特征；然后通过Flatten层将特征图展平，输入到全连接层进行分类预测。新增的卷积层和全连接层融入到前向传播流程中，增强了模型的表达能力和学习能力。

# %%
import mindspore
import mindspore.nn as nn
from mindspore import ops
from mindspore import context
import mindspore.dataset as ds
from mindspore.train import Model, LossMonitor, TimeMonitor
from mindspore.train.callback import Callback
from mindspore.nn.metrics import Accuracy

# context.set_context(mode=context.GRAPH_MODE, device_target="GPU")  ## GPU调用

# 定义卷积层
def conv(in_channels, out_channels, kernel_size, stride=1, padding=0, pad_mode="pad", has_bias=True):
    """返回一个2D卷积模块"""
    return nn.Conv2d(in_channels, out_channels, kernel_size=kernel_size, stride=stride, padding=padding,
                     has_bias=has_bias, pad_mode=pad_mode)

# 定义全连接层
def fc_with_initialize(input_channels, out_channels, has_bias=True):
    """获得一个全连接层"""
    return nn.Dense(input_channels, out_channels, has_bias=has_bias)

# 定义AlexNet模型
class AlexNet(nn.Cell):
    def __init__(self, num_classes=10, channel=3, dropout_ratio=0.5):
        """AlexNet模型
        Args:
            num_classes: 类别数
            channel    : 输入图像的通道数
        """
        super(AlexNet, self).__init__()
        self.channel = channel
        self.num_classes = num_classes
        self.dropout_ratio = dropout_ratio

        self.conv1 = conv(channel, 96, 11, stride=4, pad_mode='pad', padding=1, has_bias=True)
        self.conv2 = conv(96, 256, 5, pad_mode='pad', padding=2, has_bias=True)
        self.conv3 = conv(256, 384, 3, pad_mode='pad', padding=1, has_bias=True)
        self.conv4 = conv(384, 384, 3, pad_mode='pad', padding=1, has_bias=True)
        self.conv5 = conv(384, 256, 3, pad_mode='pad', padding=1, has_bias=True)
        self.conv6 = conv(256, 256, 3, pad_mode='pad', padding=1, has_bias=True)  # 新增卷积层
        self.conv7 = conv(256, 256, 3, pad_mode='pad', padding=1, has_bias=True)  # 新增卷积层

        self.relu = nn.ReLU()
        self.max_pool2d = nn.MaxPool2d(kernel_size=3, stride=2)
        self.flatten = nn.Flatten()

        self.fc1 = fc_with_initialize(6400, 4096)
        self.fc2 = fc_with_initialize(4096, 4096)
        self.fc3 = fc_with_initialize(4096, 4096)  # 新增全连接层
        self.fc4 = fc_with_initialize(4096, num_classes)

        self.dropout = nn.Dropout(dropout_ratio)

    def construct(self, x):
        x = self.conv1(x)
        x = self.relu(x)
        x = self.max_pool2d(x)
        x = self.conv2(x)
        x = self.relu(x)
        x = self.max_pool2d(x)
        x = self.conv3(x)
        x = self.relu(x)
        x = self.conv4(x)
        x = self.relu(x)
        x = self.conv5(x)
        x = self.relu(x)
        x = self.conv6(x)  # 新增卷积层
        x = self.relu(x)
        x = self.conv7(x)  # 新增卷积层
        x = self.relu(x)
        x = self.max_pool2d(x)
        x = self.flatten(x)
        x = self.fc1(x)
        x = self.relu(x)
        x = self.dropout(x)
        x = self.fc2(x)
        x = self.relu(x)
        x = self.dropout(x)
        x = self.fc3(x)  # 新增全连接层
        x = self.relu(x)
        x = self.dropout(x)
        x = self.fc4(x)
        return x

# %% [markdown]
# #### **2.4 训练和测试函数的定义**
#
# 在模型训练中，一个完整的训练过程（step）需要实现以下三步：
#
# 1. 正向计算：模型预测结果（logits），并与正确标签（label）求预测损失（loss）。
#
# 2. 反向传播：利用自动微分机制，自动求模型参数（parameters）对于loss的梯度（gradients）。
#
# 3. 参数优化：将梯度更新到参数上。
#
# MindSpore使用函数式自动微分机制，因此针对上述步骤需要实现：
#
# 1. 正向计算函数定义：定义一个函数forward_fn，该函数接受数据和标签作为输入，返回模型的预测结果和损失值。
#
# 2. 通过函数变换获得梯度计算函数：使用ops.value_and_grad函数，将forward_fn转换为一个能够同时计算损失和梯度的函数grad_fn。
#
# 3. 训练函数定义：定义一个训练步骤函数train_step，在该函数中执行正向计算、反向传播和参数优化。

# %%
# 定义训练函数
def model_train(model, dataset, loss_fn, optimizer):
    """训练模型
    Args:
        model    : 模型
        dataset  : 数据集
        loss_fn  : 损失函数
        optimizer: 优化器
    """
    # 前向传播函数
    def forward_fn(data, label):
        logits = model(data)
        loss = loss_fn(logits, label)
        return loss, logits

    # 获得梯度函数
    grad_fn = ops.value_and_grad(forward_fn, None, optimizer.parameters, has_aux=True)

    # 进行每一步训练
    def train_step(data, label):
        (loss, _), grads = grad_fn(data, label)
        loss = ops.depend(loss, optimizer(grads))
        return loss

    size = dataset.get_dataset_size()
    model.set_train()

    for batch, (data, label) in enumerate(dataset.create_tuple_iterator()):
        loss = train_step(data, label)
        if batch % 100 == 0:
            loss, current = loss.asnumpy(), batch
            print(f"loss: {loss:>7f}  [{current:>3d}/{size:>3d}]")

# %% [markdown]
# ##### **测试模型函数**
#
# **1. 评估模型性能：**
#
# **准确率（Accuracy）：** 计算模型在测试数据集上预测正确的样本比例，反映模型的分类能力。
#
# **平均损失（Avg loss）：** 计算模型在测试数据集上的平均损失值，反映模型预测结果与真实标签之间的差异。
#
# **2. 模型验证：**
#
# 通过在测试数据集上评估模型，验证模型的泛化能力，即模型在未见过的数据上的表现。
#
# 帮助判断模型是否存在过拟合或欠拟合问题。

# %%
# 定义测试函数
def model_test(model, dataset, loss_fn):
    """测试模型
    Args:
        model  : 模型
        dataset: 数据集
        loss_fn: 损失函数
    """
    num_batches = dataset.get_dataset_size()
    model.set_train(False)
    total, test_loss, correct = 0, 0, 0

    # 计算预测正确的样本个数
    for data, label in dataset.create_tuple_iterator():
        pred = model(data)
        total += len(data)
        test_loss += loss_fn(pred, label).asnumpy()
        correct += (pred.argmax(1) == label).asnumpy().sum()
    test_loss /= num_batches
    correct /= total
    
    print(f"Test: \n Accuracy: {(100 * correct):>0.1f}%, Avg loss: {test_loss:>8f} \n")

# %% [markdown]
# #### **2.5 模型训练及评估**
#
# 在模型训练过程中，我们通过多次迭代数据集来优化模型参数，一次完整的迭代称为一个epoch。每个epoch包括训练和评估两个阶段：在训练阶段，模型在训练数据集上进行学习，更新参数以最小化损失函数；在评估阶段，模型在测试数据集上进行预测，评估其泛化能力和性能。训练过程中，我们会观察损失值（loss）和预测准确率（Accuracy）的变化趋势，理想情况下，随着训练的进行，loss应逐渐下降，而Accuracy则逐步提高。
#
# 这里TRAIN_EPOCH设置为20，IS_FIRST_TRAIN为True表示当前训练轮次为0，此时会从零开始训练，如果IS_FIRST_TRAIN为False则会导入模型参数，在之前训练过的模型的基础上继续训练。每一轮训练结束以后会保存一次模型。

# %%
# 本次训练的 epoch 数
TRAIN_EPOCH = 20

# 是否是第一次训练
IS_FIRST_TRAIN = True


def main():
    model = AlexNet(num_classes=10, channel=3)

    # 使用交叉熵作为损失函数
    loss_fn = nn.CrossEntropyLoss()

    # 使用随机梯度下降作为优化器，学习率设置为 0.01
    optimizer = nn.SGD(model.trainable_params(), 1e-2)

    # 如果不是第一次训练，那么导入之前保存的模型和之前累积训练的 epoch 数量
    if not IS_FIRST_TRAIN:
        param_dict = mindspore.load_checkpoint("model.ckpt")
        prev_epoch = param_dict['epoch']
        
        # 导入权重
        mindspore.load_param_into_net(model, param_dict)
    else:
        prev_epoch = 0

    # 开始训练
    for t in range(TRAIN_EPOCH):
        cur_epoch = t + prev_epoch + 1
        print(f"Epoch {cur_epoch}\n-------------------------------")

        model_train(model, train_dataset, loss_fn, optimizer)

        # 每次训练完一个 epoch 保存模型
        mindspore.save_checkpoint(model, "model.ckpt", append_dict={'epoch': cur_epoch})
        model_test(model, test_dataset, loss_fn)

# %% [markdown]
# 训练模型

# %%
main()
# Out:
# [WARNING] ME(226634:140282554931008,MainProcess):2025-03-28-17:56:36.513.000 [mindspore/nn/layer/basic.py:176] For Dropout, this parameter `keep_prob` will be deprecated, please use `p` instead.
# Epoch 1
# -------------------------------
# loss: 2.304216  [  0/391]
# loss: 2.302114  [100/391]
# loss: 2.302338  [200/391]
# loss: 2.302460  [300/391]
# Test:
#  Accuracy: 10.0%, Avg loss: 2.302620
#
# Epoch 2
# -------------------------------
# loss: 2.302340  [  0/391]
# loss: 2.302163  [100/391]
# loss: 2.302531  [200/391]
# loss: 2.302202  [300/391]
# Test:
#  Accuracy: 10.0%, Avg loss: 2.302576
#
# Epoch 3
# -------------------------------
# loss: 2.303273  [  0/391]
# loss: 2.303527  [100/391]
# loss: 2.302502  [200/391]
# loss: 2.301282  [300/391]
# Test:
#  Accuracy: 10.0%, Avg loss: 2.302588
#
# Epoch 4
# -------------------------------
# loss: 2.302807  [  0/391]
# loss: 2.302426  [100/391]
# loss: 2.302949  [200/391]
# loss: 2.302301  [300/391]
# Test:
#  Accuracy: 10.0%, Avg loss: 2.302592
#
# Epoch 5
# -------------------------------
# loss: 2.303339  [  0/391]
# loss: 2.303160  [100/391]
# loss: 2.303053  [200/391]
# loss: 2.302971  [300/391]
# Test:
#  Accuracy: 10.0%, Avg loss: 2.302578
#
# Epoch 6
# -------------------------------
# loss: 2.301785  [  0/391]
# loss: 2.301677  [100/391]
# loss: 2.302166  [200/391]
# loss: 2.303436  [300/391]
# Test:
#  Accuracy: 10.0%, Avg loss: 2.302581
#
# Epoch 7
# -------------------------------
# loss: 2.302742  [  0/391]
# loss: 2.302466  [100/391]
# loss: 2.302860  [200/391]
# loss: 2.302035  [300/391]
# Test:
#  Accuracy: 10.0%, Avg loss: 2.302586
#
# Epoch 8
# -------------------------------
# loss: 2.302260  [  0/391]
# loss: 2.302710  [100/391]
# loss: 2.302405  [200/391]
# loss: 2.303422  [300/391]
# Test:
#  Accuracy: 10.0%, Avg loss: 2.302584
#
# Epoch 9
# -------------------------------
# loss: 2.303429  [  0/391]
# loss: 2.303162  [100/391]
# loss: 2.303094  [200/391]
# loss: 2.302846  [300/391]
# Test:
#  Accuracy: 10.0%, Avg loss: 2.302568
#
# Epoch 10
# -------------------------------
# loss: 2.303247  [  0/391]
# loss: 2.302198  [100/391]
# loss: 2.303789  [200/391]
# loss: 2.302422  [300/391]

# %% [markdown]
# #### **2.6 模型预测**
#
# 加载后的模型可以直接用于预测推理。

# %%
import matplotlib.pyplot as plt
import numpy as np
import mindspore

def predict(model, test_set):
    """预测
    Args:
        model   : 模型 
        test_set: 待预测的样本
    """
    model.set_train(False)
    for data, label in test_set.create_tuple_iterator():
        pred = model(data)
        predicted = pred.argmax(1)
        
        # 可视化预测结果
        plt.figure(figsize=(10, 5))
        for i in range(10):
            plt.subplot(2, 5, i + 1)
            # 反归一化并转换为图像格式
            image = data[i].asnumpy().transpose(1, 2, 0)
            image = np.clip(image, 0, 1)
            plt.imshow(image)
            plt.title(f'P:{predicted[i].item()}/A:{label[i].item()}')
            plt.axis('off')
        plt.tight_layout()
        plt.show()
        break

# 加载模型
model = AlexNet(num_classes=10, channel=3)
param_dict = mindspore.load_checkpoint("model.ckpt")
mindspore.load_param_into_net(model, param_dict)

# 进行预测并展示图片
predict(model, test_dataset)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 31
#      28         break
#      30 # 加载模型
# ---> 31 model = AlexNet(num_classes=10, channel=3)
#      32 param_dict = mindspore.load_checkpoint("model.ckpt")
#      33 mindspore.load_param_into_net(model, param_dict)
#
# NameError: name 'AlexNet' is not defined

# %% [markdown]
# ### **3 总结**
#
# 本案例基于MindSpore框架，使用CASIA-WebFace数据集进行训练，LFW数据集进行测试，完成了人脸识别任务。我们对AlexNet模型进行了调整和优化，包括通道数的合并和新增卷积层与全连接层，以适应单GPU训练环境并提升模型性能。通过训练和评估，模型在测试集上表现良好，最终实现了准确的人脸识别预测。这一过程加深了对AlexNet模型结构和特性的理解，同时掌握了MindSpore框架的使用方法，为未来实际应用提供了支持。
