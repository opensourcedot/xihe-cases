# %% [markdown]
# # FCN图像语义分割
#
# 全卷积网络（Fully Convolutional Networks，FCN）是UC Berkeley的Jonathan Long等人于2015年在Fully Convolutional Networks for Semantic Segmentation<sup>[1]</sup>一文中提出的用于图像语义分割的一种框架。
#
# FCN是首个端到端（end to end）进行像素级（pixel level）预测的全卷积网络。
#
# ![fcn-1](https://mindspore-website.obs.cn-north-4.myhuaweicloud.com/website-images/r2.4.10/tutorials/source_zh_cn/cv/images/fcn_1.png)
#
# ## 语义分割
#
# 在具体介绍FCN之前，首先介绍何为语义分割：
#
# 图像语义分割（semantic segmentation）是图像处理和机器视觉技术中关于图像理解的重要一环，AI领域中一个重要分支，常被应用于人脸识别、物体检测、医学影像、卫星图像分析、自动驾驶感知等领域。
#
# 语义分割的目的是对图像中每个像素点进行分类。与普通的分类任务只输出某个类别不同，语义分割任务输出与输入大小相同的图像，输出图像的每个像素对应了输入图像每个像素的类别。语义在图像领域指的是图像的内容，对图片意思的理解，下图是一些语义分割的实例：
#
# ![fcn-2](https://mindspore-website.obs.cn-north-4.myhuaweicloud.com/website-images/r2.4.10/tutorials/source_zh_cn/cv/images/fcn_2.png)
#
# ## 模型简介
#
# FCN主要用于图像分割领域，是一种端到端的分割方法，是深度学习应用在图像语义分割的开山之作。通过进行像素级的预测直接得出与原图大小相等的label map。因FCN丢弃全连接层替换为全卷积层，网络所有层均为卷积层，故称为全卷积网络。
#
# 全卷积神经网络主要使用以下三种技术：
#
# 1. 卷积化（Convolutional）
#
#     使用VGG-16作为FCN的backbone。VGG-16的输入为224*224的RGB图像，输出为1000个预测值。VGG-16只能接受固定大小的输入，丢弃了空间坐标，产生非空间输出。VGG-16中共有三个全连接层，全连接层也可视为带有覆盖整个区域的卷积。将全连接层转换为卷积层能使网络输出由一维非空间输出变为二维矩阵，利用输出能生成输入图片映射的heatmap。
#
#    ![fcn-3](https://mindspore-website.obs.cn-north-4.myhuaweicloud.com/website-images/r2.4.10/tutorials/source_zh_cn/cv/images/fcn_3.png)
#
# 2. 上采样（Upsample）
#
#     在卷积过程的卷积操作和池化操作会使得特征图的尺寸变小，为得到原图的大小的稠密图像预测，需要对得到的特征图进行上采样操作。使用双线性插值的参数来初始化上采样逆卷积的参数，后通过反向传播来学习非线性上采样。在网络中执行上采样，以通过像素损失的反向传播进行端到端的学习。
#
#     ![fcn-4](https://mindspore-website.obs.cn-north-4.myhuaweicloud.com/website-images/r2.4.10/tutorials/source_zh_cn/cv/images/fcn_4.png)
#
# 3. 跳跃结构（Skip Layer）
#
#     利用上采样技巧对最后一层的特征图进行上采样得到原图大小的分割是步长为32像素的预测，称之为FCN-32s。由于最后一层的特征图太小，损失过多细节，采用skips结构将更具有全局信息的最后一层预测和更浅层的预测结合，使预测结果获取更多的局部细节。将底层（stride 32）的预测（FCN-32s）进行2倍的上采样得到原尺寸的图像，并与从pool4层（stride 16）进行的预测融合起来（相加），这一部分的网络被称为FCN-16s。随后将这一部分的预测再进行一次2倍的上采样并与从pool3层得到的预测融合起来，这一部分的网络被称为FCN-8s。 Skips结构将深层的全局信息与浅层的局部信息相结合。
#
#     ![fcn-5](https://mindspore-website.obs.cn-north-4.myhuaweicloud.com/website-images/r2.4.10/tutorials/source_zh_cn/cv/images/fcn_5.png)
#
# ## 网络特点
#
# 1. 不含全连接层(fc)的全卷积(fully conv)网络，可适应任意尺寸输入。
# 2. 增大数据尺寸的反卷积(deconv)层，能够输出精细的结果。
# 3. 结合不同深度层结果的跳级(skip)结构，同时确保鲁棒性和精确性。

# %% [markdown]
# ## 数据处理
#
# 开始实验前，需确保本地已经安装Python环境及MindSpore。

# %%
# %%capture captured_output
# 实验环境已经预装了mindspore==2.4.10，如需更换mindspore版本，可更改下面 MINDSPORE_VERSION 变量
# !pip uninstall mindspore -y
# %env MINDSPORE_VERSION=2.4.10
# !pip install https://ms-release.obs.cn-north-4.myhuaweicloud.com/${MINDSPORE_VERSION}/MindSpore/unified/aarch64/mindspore-${MINDSPORE_VERSION}-cp39-cp39-linux_aarch64.whl --trusted-host ms-release.obs.cn-north-4.myhuaweicloud.com -i https://pypi.tuna.tsinghua.edu.cn/simple

# %%
# 查看当前 mindspore 版本
# !pip show mindspore
# Out:
# Name: mindspore
# Version: 2.4.10
# Summary: MindSpore is a new open source deep learning training/inference framework that could be used for mobile, edge and cloud scenarios.
# Home-page: https://www.mindspore.cn
# Author: The MindSpore Authors
# Author-email: contact@mindspore.cn
# License: Apache 2.0
# Location: /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages
# Requires: asttokens, astunparse, numpy, packaging, pillow, protobuf, psutil, safetensors, scipy
# Required-by:

# %%
from download import download

url = "https://mindspore-website.obs.cn-north-4.myhuaweicloud.com/notebook/datasets/dataset_fcn8s.tar"

download(url, "./dataset", kind="tar", replace=True)
# Out:
# Creating data folder...
# Downloading data from https://mindspore-website.obs.cn-north-4.myhuaweicloud.com/notebook/datasets/dataset_fcn8s.tar (537.2 MB)
#
# file_sizes: 100%|█████████████████████████████| 563M/563M [00:03<00:00, 164MB/s]
# Extracting tar file...
# Successfully downloaded / unzipped to ./dataset
# './dataset'

# %% [markdown]
# ### 数据预处理
#
# 由于PASCAL VOC 2012数据集中图像的分辨率大多不一致，无法放在一个tensor中，故输入前需做标准化处理。

# %% [markdown]
# ### 数据加载
#
# 将PASCAL VOC 2012数据集与SDB数据集进行混合。

# %%
import numpy as np
import cv2
import mindspore.dataset as ds

class SegDataset:
    def __init__(self,
                 image_mean,
                 image_std,
                 data_file='',
                 batch_size=32,
                 crop_size=512,
                 max_scale=2.0,
                 min_scale=0.5,
                 ignore_label=255,
                 num_classes=21,
                 num_readers=2,
                 num_parallel_calls=4):

        self.data_file = data_file
        self.batch_size = batch_size
        self.crop_size = crop_size
        self.image_mean = np.array(image_mean, dtype=np.float32)
        self.image_std = np.array(image_std, dtype=np.float32)
        self.max_scale = max_scale
        self.min_scale = min_scale
        self.ignore_label = ignore_label
        self.num_classes = num_classes
        self.num_readers = num_readers
        self.num_parallel_calls = num_parallel_calls
        max_scale > min_scale

    def preprocess_dataset(self, image, label):
        image_out = cv2.imdecode(np.frombuffer(image, dtype=np.uint8), cv2.IMREAD_COLOR)
        label_out = cv2.imdecode(np.frombuffer(label, dtype=np.uint8), cv2.IMREAD_GRAYSCALE)
        sc = np.random.uniform(self.min_scale, self.max_scale)
        new_h, new_w = int(sc * image_out.shape[0]), int(sc * image_out.shape[1])
        image_out = cv2.resize(image_out, (new_w, new_h), interpolation=cv2.INTER_CUBIC)
        label_out = cv2.resize(label_out, (new_w, new_h), interpolation=cv2.INTER_NEAREST)

        image_out = (image_out - self.image_mean) / self.image_std
        out_h, out_w = max(new_h, self.crop_size), max(new_w, self.crop_size)
        pad_h, pad_w = out_h - new_h, out_w - new_w
        if pad_h > 0 or pad_w > 0:
            image_out = cv2.copyMakeBorder(image_out, 0, pad_h, 0, pad_w, cv2.BORDER_CONSTANT, value=0)
            label_out = cv2.copyMakeBorder(label_out, 0, pad_h, 0, pad_w, cv2.BORDER_CONSTANT, value=self.ignore_label)
        offset_h = np.random.randint(0, out_h - self.crop_size + 1)
        offset_w = np.random.randint(0, out_w - self.crop_size + 1)
        image_out = image_out[offset_h: offset_h + self.crop_size, offset_w: offset_w + self.crop_size, :]
        label_out = label_out[offset_h: offset_h + self.crop_size, offset_w: offset_w+self.crop_size]
        if np.random.uniform(0.0, 1.0) > 0.5:
            image_out = image_out[:, ::-1, :]
            label_out = label_out[:, ::-1]
        image_out = image_out.transpose((2, 0, 1))
        image_out = image_out.copy()
        label_out = label_out.copy()
        label_out = label_out.astype("int32")
        return image_out, label_out

    def get_dataset(self):
        ds.config.set_numa_enable(True)
        dataset = ds.MindDataset(self.data_file, columns_list=["data", "label"],
                                 shuffle=True, num_parallel_workers=self.num_readers)
        transforms_list = self.preprocess_dataset
        dataset = dataset.map(operations=transforms_list, input_columns=["data", "label"],
                              output_columns=["data", "label"],
                              num_parallel_workers=self.num_parallel_calls)
        dataset = dataset.shuffle(buffer_size=self.batch_size * 10)
        dataset = dataset.batch(self.batch_size, drop_remainder=True)
        return dataset


# 定义创建数据集的参数
IMAGE_MEAN = [103.53, 116.28, 123.675]
IMAGE_STD = [57.375, 57.120, 58.395]
DATA_FILE = "dataset/dataset_fcn8s/mindname.mindrecord"

# 定义模型训练参数
train_batch_size = 4
crop_size = 512
min_scale = 0.5
max_scale = 2.0
ignore_label = 255
num_classes = 21

# 实例化Dataset
dataset = SegDataset(image_mean=IMAGE_MEAN,
                     image_std=IMAGE_STD,
                     data_file=DATA_FILE,
                     batch_size=train_batch_size,
                     crop_size=crop_size,
                     max_scale=max_scale,
                     min_scale=min_scale,
                     ignore_label=ignore_label,
                     num_classes=num_classes,
                     num_readers=2,
                     num_parallel_calls=4)

dataset = dataset.get_dataset()
# Out:
# /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages/numpy/core/getlimits.py:549: UserWarning: The value of the smallest subnormal for <class 'numpy.float64'> type is zero.
#   setattr(self, word, getattr(machar, word).flat[0])
# /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages/numpy/core/getlimits.py:89: UserWarning: The value of the smallest subnormal for <class 'numpy.float64'> type is zero.
#   return self._float_to_str(self.smallest_subnormal)
# /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages/numpy/core/getlimits.py:549: UserWarning: The value of the smallest subnormal for <class 'numpy.float32'> type is zero.
#   setattr(self, word, getattr(machar, word).flat[0])
# /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages/numpy/core/getlimits.py:89: UserWarning: The value of the smallest subnormal for <class 'numpy.float32'> type is zero.
#   return self._float_to_str(self.smallest_subnormal)

# %% [markdown]
# ### 训练集可视化
#
# 运行以下代码观察载入的数据集图片（数据处理过程中已做归一化处理）。

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(16, 8))

# 对训练集中的数据进行展示
for i in range(1, 9):
    plt.subplot(2, 4, i)
    show_data = next(dataset.create_dict_iterator())
    show_images = show_data["data"].asnumpy()
    show_images = np.clip(show_images, 0, 1)
# 将图片转换HWC格式后进行展示
    plt.imshow(show_images[0].transpose(1, 2, 0))
    plt.axis("off")
    plt.subplots_adjust(wspace=0.05, hspace=0)
plt.show()

# %% [markdown]
# ## 网络构建
#
# ### 网络流程
#
# FCN网络的流程如下图所示：
#
# 1. 输入图像image，经过pool1池化后，尺寸变为原始尺寸的1/2。
# 2. 经过pool2池化，尺寸变为原始尺寸的1/4。
# 3. 接着经过pool3、pool4、pool5池化，大小分别变为原始尺寸的1/8、1/16、1/32。
# 4. 经过conv6-7卷积，输出的尺寸依然是原图的1/32。
# 5. FCN-32s是最后使用反卷积，使得输出图像大小与输入图像相同。
# 6. FCN-16s是将conv7的输出进行反卷积，使其尺寸扩大两倍至原图的1/16，并将其与pool4输出的特征图进行融合，后通过反卷积扩大到原始尺寸。
# 7. FCN-8s是将conv7的输出进行反卷积扩大4倍，将pool4输出的特征图反卷积扩大2倍，并将pool3输出特征图拿出，三者融合后通反卷积扩大到原始尺寸。
#
# ![fcn-6](https://mindspore-website.obs.cn-north-4.myhuaweicloud.com/website-images/r2.4.10/tutorials/source_zh_cn/cv/images/fcn_6.png)
#
# 使用以下代码构建FCN-8s网络。

# %%
import mindspore.nn as nn

class FCN8s(nn.Cell):
    def __init__(self, n_class):
        super().__init__()
        self.n_class = n_class
        self.conv1 = nn.SequentialCell(
            nn.Conv2d(in_channels=3, out_channels=64,
                      kernel_size=3, weight_init='xavier_uniform'),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.Conv2d(in_channels=64, out_channels=64,
                      kernel_size=3, weight_init='xavier_uniform'),
            nn.BatchNorm2d(64),
            nn.ReLU()
        )
        self.pool1 = nn.MaxPool2d(kernel_size=2, stride=2)
        self.conv2 = nn.SequentialCell(
            nn.Conv2d(in_channels=64, out_channels=128,
                      kernel_size=3, weight_init='xavier_uniform'),
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.Conv2d(in_channels=128, out_channels=128,
                      kernel_size=3, weight_init='xavier_uniform'),
            nn.BatchNorm2d(128),
            nn.ReLU()
        )
        self.pool2 = nn.MaxPool2d(kernel_size=2, stride=2)
        self.conv3 = nn.SequentialCell(
            nn.Conv2d(in_channels=128, out_channels=256,
                      kernel_size=3, weight_init='xavier_uniform'),
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.Conv2d(in_channels=256, out_channels=256,
                      kernel_size=3, weight_init='xavier_uniform'),
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.Conv2d(in_channels=256, out_channels=256,
                      kernel_size=3, weight_init='xavier_uniform'),
            nn.BatchNorm2d(256),
            nn.ReLU()
        )
        self.pool3 = nn.MaxPool2d(kernel_size=2, stride=2)
        self.conv4 = nn.SequentialCell(
            nn.Conv2d(in_channels=256, out_channels=512,
                      kernel_size=3, weight_init='xavier_uniform'),
            nn.BatchNorm2d(512),
            nn.ReLU(),
            nn.Conv2d(in_channels=512, out_channels=512,
                      kernel_size=3, weight_init='xavier_uniform'),
            nn.BatchNorm2d(512),
            nn.ReLU(),
            nn.Conv2d(in_channels=512, out_channels=512,
                      kernel_size=3, weight_init='xavier_uniform'),
            nn.BatchNorm2d(512),
            nn.ReLU()
        )
        self.pool4 = nn.MaxPool2d(kernel_size=2, stride=2)
        self.conv5 = nn.SequentialCell(
            nn.Conv2d(in_channels=512, out_channels=512,
                      kernel_size=3, weight_init='xavier_uniform'),
            nn.BatchNorm2d(512),
            nn.ReLU(),
            nn.Conv2d(in_channels=512, out_channels=512,
                      kernel_size=3, weight_init='xavier_uniform'),
            nn.BatchNorm2d(512),
            nn.ReLU(),
            nn.Conv2d(in_channels=512, out_channels=512,
                      kernel_size=3, weight_init='xavier_uniform'),
            nn.BatchNorm2d(512),
            nn.ReLU()
        )
        self.pool5 = nn.MaxPool2d(kernel_size=2, stride=2)
        self.conv6 = nn.SequentialCell(
            nn.Conv2d(in_channels=512, out_channels=4096,
                      kernel_size=7, weight_init='xavier_uniform'),
            nn.BatchNorm2d(4096),
            nn.ReLU(),
        )
        self.conv7 = nn.SequentialCell(
            nn.Conv2d(in_channels=4096, out_channels=4096,
                      kernel_size=1, weight_init='xavier_uniform'),
            nn.BatchNorm2d(4096),
            nn.ReLU(),
        )
        self.score_fr = nn.Conv2d(in_channels=4096, out_channels=self.n_class,
                                  kernel_size=1, weight_init='xavier_uniform')
        self.upscore2 = nn.Conv2dTranspose(in_channels=self.n_class, out_channels=self.n_class,
                                           kernel_size=4, stride=2, weight_init='xavier_uniform')
        self.score_pool4 = nn.Conv2d(in_channels=512, out_channels=self.n_class,
                                     kernel_size=1, weight_init='xavier_uniform')
        self.upscore_pool4 = nn.Conv2dTranspose(in_channels=self.n_class, out_channels=self.n_class,
                                                kernel_size=4, stride=2, weight_init='xavier_uniform')
        self.score_pool3 = nn.Conv2d(in_channels=256, out_channels=self.n_class,
                                     kernel_size=1, weight_init='xavier_uniform')
        self.upscore8 = nn.Conv2dTranspose(in_channels=self.n_class, out_channels=self.n_class,
                                           kernel_size=16, stride=8, weight_init='xavier_uniform')

    def construct(self, x):
        x1 = self.conv1(x)
        p1 = self.pool1(x1)
        x2 = self.conv2(p1)
        p2 = self.pool2(x2)
        x3 = self.conv3(p2)
        p3 = self.pool3(x3)
        x4 = self.conv4(p3)
        p4 = self.pool4(x4)
        x5 = self.conv5(p4)
        p5 = self.pool5(x5)
        x6 = self.conv6(p5)
        x7 = self.conv7(x6)
        sf = self.score_fr(x7)
        u2 = self.upscore2(sf)
        s4 = self.score_pool4(p4)
        f4 = s4 + u2
        u4 = self.upscore_pool4(f4)
        s3 = self.score_pool3(p3)
        f3 = s3 + u4
        out = self.upscore8(f3)
        return out

# %% [markdown]
# ## 训练准备
#
# ### 导入VGG-16部分预训练权重
#
# FCN使用VGG-16作为骨干网络，用于实现图像编码。使用下面代码导入VGG-16预训练模型的部分预训练权重。

# %%
from download import download
from mindspore import load_checkpoint, load_param_into_net

url = "https://mindspore-website.obs.cn-north-4.myhuaweicloud.com/notebook/datasets/fcn8s_vgg16_pretrain.ckpt"
download(url, "fcn8s_vgg16_pretrain.ckpt", replace=True)
def load_vgg16():
    ckpt_vgg16 = "fcn8s_vgg16_pretrain.ckpt"
    param_vgg = load_checkpoint(ckpt_vgg16)
    load_param_into_net(net, param_vgg)
# Out:
# Downloading data from https://mindspore-website.obs.cn-north-4.myhuaweicloud.com/notebook/datasets/fcn8s_vgg16_pretrain.ckpt (513.2 MB)
#
# file_sizes: 100%|█████████████████████████████| 538M/538M [00:03<00:00, 163MB/s]
# Successfully downloaded file to fcn8s_vgg16_pretrain.ckpt

# %% [markdown]
# ### 损失函数
#
# 语义分割是对图像中每个像素点进行分类，仍是分类问题，故损失函数选择交叉熵损失函数来计算FCN网络输出与mask之间的交叉熵损失。这里我们使用的是mindspore.nn.CrossEntropyLoss()作为损失函数。

# %% [markdown]
# ### 自定义评价指标 Metrics
#
# 这一部分主要对训练出来的模型效果进行评估，为了便于解释，假设如下：共有 $k+1$ 个类（从 $L_0$ 到 $L_k$, 其中包含一个空类或背景）， $p_{i j}$ 表示本属于$i$类但被预测为$j$类的像素数量。即, $p_{i i}$ 表示真正的数量, 而 $p_{i j} p_{j i}$ 则分别被解释为假正和假负, 尽管两者都是假正与假负之和。
#
# - Pixel Accuracy(PA, 像素精度)：这是最简单的度量，为标记正确的像素占总像素的比例。
#
# $$ P A=\frac{\sum_{i=0}^k p_{i i}}{\sum_{i=0}^k \sum_{j=0}^k p_{i j}} $$
#
# - Mean Pixel Accuracy(MPA, 均像素精度)：是PA的一种简单提升，计算每个类内被正确分类像素数的比例，之后求所有类的平均。
#
# $$ M P A=\frac{1}{k+1} \sum_{i=0}^k \frac{p_{i i}}{\sum_{j=0}^k p_{i j}} $$
#
# - Mean Intersection over Union(MloU, 均交并比)：为语义分割的标准度量。其计算两个集合的交集和并集之，在语义分割的问题中，这两个集合为真实值（ground truth) 和预测值（predicted segmentation）。这个比例可以变形为正真数 (intersection) 比上真正、假负、假正（并集）之和。在每个类上计算loU，之后平均。
#
# $$ M I o U=\frac{1}{k+1} \sum_{i=0}^k \frac{p_{i i}}{\sum_{j=0}^k p_{i j}+\sum_{j=0}^k p_{j i}-p_{i i}} $$
#
# - Frequency Weighted Intersection over Union(FWIoU, 频权交井比)：为MloU的一种提升，这种方法根据每个类出现的频率为其设置权重。
#
# $$ F W I o U=\frac{1}{\sum_{i=0}^k \sum_{j=0}^k p_{i j}} \sum_{i=0}^k \frac{p_{i i}}{\sum_{j=0}^k p_{i j}+\sum_{j=0}^k p_{j i}-p_{i i}} $$

# %%
import numpy as np
import mindspore as ms
import mindspore.nn as nn
import mindspore.train as train

class PixelAccuracy(train.Metric):
    def __init__(self, num_class=21):
        super(PixelAccuracy, self).__init__()
        self.num_class = num_class

    def _generate_matrix(self, gt_image, pre_image):
        mask = (gt_image >= 0) & (gt_image < self.num_class)
        label = self.num_class * gt_image[mask].astype('int') + pre_image[mask]
        count = np.bincount(label, minlength=self.num_class**2)
        confusion_matrix = count.reshape(self.num_class, self.num_class)
        return confusion_matrix

    def clear(self):
        self.confusion_matrix = np.zeros((self.num_class,) * 2)

    def update(self, *inputs):
        y_pred = inputs[0].asnumpy().argmax(axis=1)
        y = inputs[1].asnumpy().reshape(4, 512, 512)
        self.confusion_matrix += self._generate_matrix(y, y_pred)

    def eval(self):
        pixel_accuracy = np.diag(self.confusion_matrix).sum() / self.confusion_matrix.sum()
        return pixel_accuracy


class PixelAccuracyClass(train.Metric):
    def __init__(self, num_class=21):
        super(PixelAccuracyClass, self).__init__()
        self.num_class = num_class

    def _generate_matrix(self, gt_image, pre_image):
        mask = (gt_image >= 0) & (gt_image < self.num_class)
        label = self.num_class * gt_image[mask].astype('int') + pre_image[mask]
        count = np.bincount(label, minlength=self.num_class**2)
        confusion_matrix = count.reshape(self.num_class, self.num_class)
        return confusion_matrix

    def update(self, *inputs):
        y_pred = inputs[0].asnumpy().argmax(axis=1)
        y = inputs[1].asnumpy().reshape(4, 512, 512)
        self.confusion_matrix += self._generate_matrix(y, y_pred)

    def clear(self):
        self.confusion_matrix = np.zeros((self.num_class,) * 2)

    def eval(self):
        mean_pixel_accuracy = np.diag(self.confusion_matrix) / self.confusion_matrix.sum(axis=1)
        mean_pixel_accuracy = np.nanmean(mean_pixel_accuracy)
        return mean_pixel_accuracy


class MeanIntersectionOverUnion(train.Metric):
    def __init__(self, num_class=21):
        super(MeanIntersectionOverUnion, self).__init__()
        self.num_class = num_class

    def _generate_matrix(self, gt_image, pre_image):
        mask = (gt_image >= 0) & (gt_image < self.num_class)
        label = self.num_class * gt_image[mask].astype('int') + pre_image[mask]
        count = np.bincount(label, minlength=self.num_class**2)
        confusion_matrix = count.reshape(self.num_class, self.num_class)
        return confusion_matrix

    def update(self, *inputs):
        y_pred = inputs[0].asnumpy().argmax(axis=1)
        y = inputs[1].asnumpy().reshape(4, 512, 512)
        self.confusion_matrix += self._generate_matrix(y, y_pred)

    def clear(self):
        self.confusion_matrix = np.zeros((self.num_class,) * 2)

    def eval(self):
        mean_iou = np.diag(self.confusion_matrix) / (
            np.sum(self.confusion_matrix, axis=1) + np.sum(self.confusion_matrix, axis=0) -
            np.diag(self.confusion_matrix))
        mean_iou = np.nanmean(mean_iou)
        return mean_iou


class FrequencyWeightedIntersectionOverUnion(train.Metric):
    def __init__(self, num_class=21):
        super(FrequencyWeightedIntersectionOverUnion, self).__init__()
        self.num_class = num_class

    def _generate_matrix(self, gt_image, pre_image):
        mask = (gt_image >= 0) & (gt_image < self.num_class)
        label = self.num_class * gt_image[mask].astype('int') + pre_image[mask]
        count = np.bincount(label, minlength=self.num_class**2)
        confusion_matrix = count.reshape(self.num_class, self.num_class)
        return confusion_matrix

    def update(self, *inputs):
        y_pred = inputs[0].asnumpy().argmax(axis=1)
        y = inputs[1].asnumpy().reshape(4, 512, 512)
        self.confusion_matrix += self._generate_matrix(y, y_pred)

    def clear(self):
        self.confusion_matrix = np.zeros((self.num_class,) * 2)

    def eval(self):
        freq = np.sum(self.confusion_matrix, axis=1) / np.sum(self.confusion_matrix)
        iu = np.diag(self.confusion_matrix) / (
            np.sum(self.confusion_matrix, axis=1) + np.sum(self.confusion_matrix, axis=0) -
            np.diag(self.confusion_matrix))

        frequency_weighted_iou = (freq[freq > 0] * iu[freq > 0]).sum()
        return frequency_weighted_iou

# %% [markdown]
# ## 模型训练
#
# 导入VGG-16预训练参数后，实例化损失函数、优化器，使用Model接口编译网络，训练FCN-8s网络。

# %%
# %%time
import mindspore
from mindspore import Tensor
import mindspore.nn as nn
from mindspore.train import ModelCheckpoint, CheckpointConfig, LossMonitor, TimeMonitor, Model

device_target = "Ascend"
mindspore.set_context(mode=mindspore.PYNATIVE_MODE, device_target=device_target)

train_batch_size = 4
num_classes = 21
# 初始化模型结构
net = FCN8s(n_class=21)
# 导入vgg16预训练参数
load_vgg16()
# 计算学习率
min_lr = 0.0005
base_lr = 0.05
train_epochs = 1
iters_per_epoch = dataset.get_dataset_size()
total_step = iters_per_epoch * train_epochs

lr_scheduler = mindspore.nn.cosine_decay_lr(min_lr,
                                            base_lr,
                                            total_step,
                                            iters_per_epoch,
                                            decay_epoch=2)
lr = Tensor(lr_scheduler[-1])

# 定义损失函数
loss = nn.CrossEntropyLoss(ignore_index=255)
# 定义优化器
optimizer = nn.Momentum(params=net.trainable_params(), learning_rate=lr, momentum=0.9, weight_decay=0.0001)
# 定义loss_scale
scale_factor = 4
scale_window = 3000
loss_scale_manager = ms.amp.DynamicLossScaleManager(scale_factor, scale_window)
# 初始化模型
if device_target == "Ascend":
    model = Model(net, loss_fn=loss, optimizer=optimizer, loss_scale_manager=loss_scale_manager, metrics={"pixel accuracy": PixelAccuracy(), "mean pixel accuracy": PixelAccuracyClass(), "mean IoU": MeanIntersectionOverUnion(), "frequency weighted IoU": FrequencyWeightedIntersectionOverUnion()})
else:
    model = Model(net, loss_fn=loss, optimizer=optimizer, metrics={"pixel accuracy": PixelAccuracy(), "mean pixel accuracy": PixelAccuracyClass(), "mean IoU": MeanIntersectionOverUnion(), "frequency weighted IoU": FrequencyWeightedIntersectionOverUnion()})

# 设置ckpt文件保存的参数
time_callback = TimeMonitor(data_size=iters_per_epoch)
loss_callback = LossMonitor()
callbacks = [time_callback, loss_callback]
save_steps = 330
keep_checkpoint_max = 5
config_ckpt = CheckpointConfig(save_checkpoint_steps=10,
                               keep_checkpoint_max=keep_checkpoint_max)
ckpt_callback = ModelCheckpoint(prefix="FCN8s",
                                directory="./ckpt",
                                config=config_ckpt)
callbacks.append(ckpt_callback)
model.train(train_epochs, dataset, callbacks=callbacks)
# Out:
# ......epoch: 1 step: 1, loss is 3.0624585
# epoch: 1 step: 2, loss is 3.039152
# epoch: 1 step: 3, loss is 2.990367
# epoch: 1 step: 4, loss is 2.9009624
# epoch: 1 step: 5, loss is 2.7719457
# epoch: 1 step: 6, loss is 2.600556
# epoch: 1 step: 7, loss is 2.5072045
# epoch: 1 step: 8, loss is 2.018839
# epoch: 1 step: 9, loss is 2.0708628
# epoch: 1 step: 10, loss is 1.8985227
# epoch: 1 step: 11, loss is 1.0964789
# epoch: 1 step: 12, loss is 0.84872645
# epoch: 1 step: 13, loss is 1.8177383
# epoch: 1 step: 14, loss is 2.4545865
# epoch: 1 step: 15, loss is 1.8367769
# epoch: 1 step: 16, loss is 1.2761513
# epoch: 1 step: 17, loss is 0.9515115
# epoch: 1 step: 18, loss is 1.9658419
# epoch: 1 step: 19, loss is 1.5449764
# epoch: 1 step: 20, loss is 1.9486855
# epoch: 1 step: 21, loss is 1.4713769
# epoch: 1 step: 22, loss is 1.8194681
# epoch: 1 step: 23, loss is 2.1037433
# epoch: 1 step: 24, loss is 1.4251195
# epoch: 1 step: 25, loss is 1.9875073
# epoch: 1 step: 26, loss is 1.4622266
# epoch: 1 step: 27, loss is 1.6357771
# epoch: 1 step: 28, loss is 1.1997794
# epoch: 1 step: 29, loss is 1.0681642
# epoch: 1 step: 30, loss is 1.369167
# epoch: 1 step: 31, loss is 0.86811167
# epoch: 1 step: 32, loss is 2.4338672
# epoch: 1 step: 33, loss is 0.71847343
# epoch: 1 step: 34, loss is 3.093392
# epoch: 1 step: 35, loss is 2.0534785
# epoch: 1 step: 36, loss is 1.4052354
# epoch: 1 step: 37, loss is 1.3522993
# epoch: 1 step: 38, loss is 1.3387904
# epoch: 1 step: 39, loss is 1.2253131
# epoch: 1 step: 40, loss is 0.8569067
# epoch: 1 step: 41, loss is 1.6016963
# epoch: 1 step: 42, loss is 2.1019351
# epoch: 1 step: 43, loss is 1.6455472
# epoch: 1 step: 44, loss is 2.6123097
# epoch: 1 step: 45, loss is 1.4946167
# epoch: 1 step: 46, loss is 1.3536413
# epoch: 1 step: 47, loss is 1.3827292
# epoch: 1 step: 48, loss is 1.8134352
# epoch: 1 step: 49, loss is 1.3698697
# epoch: 1 step: 50, loss is 1.6048062
# epoch: 1 step: 51, loss is 1.2950085
# epoch: 1 step: 52, loss is 1.9409747
# epoch: 1 step: 53, loss is 1.1595238
# epoch: 1 step: 54, loss is 1.0600269
# epoch: 1 step: 55, loss is 1.8105905
# epoch: 1 step: 56, loss is 1.2805817
# epoch: 1 step: 57, loss is 2.896566
# epoch: 1 step: 58, loss is 1.2671953
# epoch: 1 step: 59, loss is 1.1896751
# epoch: 1 step: 60, loss is 2.1413422
# epoch: 1 step: 61, loss is 1.2955871
# epoch: 1 step: 62, loss is 1.7450702
# epoch: 1 step: 63, loss is 1.1606226
# epoch: 1 step: 64, loss is 1.853097
# epoch: 1 step: 65, loss is 2.0170817
# epoch: 1 step: 66, loss is 1.3388888
# epoch: 1 step: 67, loss is 1.7351354
# epoch: 1 step: 68, loss is 1.5153431
# epoch: 1 step: 69, loss is 1.6008953
# epoch: 1 step: 70, loss is 0.8670312
# epoch: 1 step: 71, loss is 1.4331948
# epoch: 1 step: 72, loss is 0.8973814
# epoch: 1 step: 73, loss is 1.5250474
# epoch: 1 step: 74, loss is 1.0350566
# epoch: 1 step: 75, loss is 1.2868415
# epoch: 1 step: 76, loss is 0.8919135
# epoch: 1 step: 77, loss is 3.0229661
# epoch: 1 step: 78, loss is 1.0111822
# epoch: 1 step: 79, loss is 1.7636245
# epoch: 1 step: 80, loss is 1.5013032
# epoch: 1 step: 81, loss is 2.157614
# epoch: 1 step: 82, loss is 1.6509582
# epoch: 1 step: 83, loss is 2.2437525
# epoch: 1 step: 84, loss is 2.1289759
# epoch: 1 step: 85, loss is 1.4664444
# epoch: 1 step: 86, loss is 1.3713803
# epoch: 1 step: 87, loss is 1.244981
# epoch: 1 step: 88, loss is 1.413044
# epoch: 1 step: 89, loss is 2.1924727
# epoch: 1 step: 90, loss is 1.3626603
# epoch: 1 step: 91, loss is 1.343577
# epoch: 1 step: 92, loss is 2.281608
# epoch: 1 step: 93, loss is 1.3060704
# epoch: 1 step: 94, loss is 1.8983096
# epoch: 1 step: 95, loss is 2.0541744
# epoch: 1 step: 96, loss is 1.8503162
# epoch: 1 step: 97, loss is 1.0993842
# epoch: 1 step: 98, loss is 1.2635704
# epoch: 1 step: 99, loss is 1.8891175
# epoch: 1 step: 100, loss is 2.1235645
# epoch: 1 step: 101, loss is 1.0456827
# epoch: 1 step: 102, loss is 1.8529756
# epoch: 1 step: 103, loss is 1.4971452
# epoch: 1 step: 104, loss is 2.137962
# epoch: 1 step: 105, loss is 1.014613
# epoch: 1 step: 106, loss is 2.0650132
# epoch: 1 step: 107, loss is 1.3571641
# epoch: 1 step: 108, loss is 1.1449028
# epoch: 1 step: 109, loss is 1.9688226
# epoch: 1 step: 110, loss is 0.9947148
# epoch: 1 step: 111, loss is 1.980463
# epoch: 1 step: 112, loss is 1.3095045
# epoch: 1 step: 113, loss is 1.4563422
# epoch: 1 step: 114, loss is 1.6759155
# epoch: 1 step: 115, loss is 1.2392724
# epoch: 1 step: 116, loss is 0.9179873
# epoch: 1 step: 117, loss is 2.2287297
# epoch: 1 step: 118, loss is 1.8381734
# epoch: 1 step: 119, loss is 1.4304943
# epoch: 1 step: 120, loss is 1.6909529
# epoch: 1 step: 121, loss is 1.2840636
# epoch: 1 step: 122, loss is 0.88162404
# epoch: 1 step: 123, loss is 2.6727076
# epoch: 1 step: 124, loss is 1.8209156
# epoch: 1 step: 125, loss is 2.822517
# epoch: 1 step: 126, loss is 1.4357138
# epoch: 1 step: 127, loss is 1.9928741
# epoch: 1 step: 128, loss is 1.1123323
# epoch: 1 step: 129, loss is 1.8151621
# epoch: 1 step: 130, loss is 1.4350089
# epoch: 1 step: 131, loss is 1.661666
# epoch: 1 step: 132, loss is 1.6825023
# epoch: 1 step: 133, loss is 1.9994575
# epoch: 1 step: 134, loss is 1.8515822
# epoch: 1 step: 135, loss is 0.8487874
# epoch: 1 step: 136, loss is 1.5687535
# epoch: 1 step: 137, loss is 1.0407009
# epoch: 1 step: 138, loss is 1.3818226
# epoch: 1 step: 139, loss is 1.7211428
# epoch: 1 step: 140, loss is 0.7880168
# epoch: 1 step: 141, loss is 2.8543894
# epoch: 1 step: 142, loss is 0.95434076
# epoch: 1 step: 143, loss is 0.92969465
# epoch: 1 step: 144, loss is 1.4758196
# epoch: 1 step: 145, loss is 1.286819
# epoch: 1 step: 146, loss is 1.5912461
# epoch: 1 step: 147, loss is 1.6800022
# epoch: 1 step: 148, loss is 1.9981676
# epoch: 1 step: 149, loss is 1.5028137
# epoch: 1 step: 150, loss is 1.7629261
# epoch: 1 step: 151, loss is 1.0398206
# epoch: 1 step: 152, loss is 1.8810889
# epoch: 1 step: 153, loss is 1.3902754
# epoch: 1 step: 154, loss is 1.651892
# epoch: 1 step: 155, loss is 1.2234733
# epoch: 1 step: 156, loss is 2.0288618
# epoch: 1 step: 157, loss is 0.8781912
# epoch: 1 step: 158, loss is 0.7047884
# epoch: 1 step: 159, loss is 0.41464114
# epoch: 1 step: 160, loss is 0.61810005
# epoch: 1 step: 161, loss is 2.1667042
# epoch: 1 step: 162, loss is 1.236587
# epoch: 1 step: 163, loss is 0.8419875
# epoch: 1 step: 164, loss is 0.78955144
# epoch: 1 step: 165, loss is 1.110953
# epoch: 1 step: 166, loss is 1.5644468
# epoch: 1 step: 167, loss is 1.2369109
# epoch: 1 step: 168, loss is 1.4781182
# epoch: 1 step: 169, loss is 1.9892032
# epoch: 1 step: 170, loss is 0.97628385
# epoch: 1 step: 171, loss is 1.4128846
# epoch: 1 step: 172, loss is 1.3324102
# epoch: 1 step: 173, loss is 2.4492526
# epoch: 1 step: 174, loss is 1.379925
# epoch: 1 step: 175, loss is 1.6202666
# epoch: 1 step: 176, loss is 1.2591295
# epoch: 1 step: 177, loss is 1.5809984
# epoch: 1 step: 178, loss is 1.4559133
# epoch: 1 step: 179, loss is 1.5574625
# epoch: 1 step: 180, loss is 1.1937839
# epoch: 1 step: 181, loss is 2.139303
# epoch: 1 step: 182, loss is 0.8560091
# epoch: 1 step: 183, loss is 1.6244776
# epoch: 1 step: 184, loss is 2.7721493
# epoch: 1 step: 185, loss is 2.0836747
# epoch: 1 step: 186, loss is 1.7704397
# epoch: 1 step: 187, loss is 2.0726
# epoch: 1 step: 188, loss is 1.6956648
# epoch: 1 step: 189, loss is 1.5245078
# epoch: 1 step: 190, loss is 0.9959222
# epoch: 1 step: 191, loss is 1.7116975
# epoch: 1 step: 192, loss is 1.4898475
# epoch: 1 step: 193, loss is 2.1741621
# epoch: 1 step: 194, loss is 1.450163
# epoch: 1 step: 195, loss is 1.1106371
# epoch: 1 step: 196, loss is 0.9014375
# epoch: 1 step: 197, loss is 1.5578715
# epoch: 1 step: 198, loss is 1.9942724
# epoch: 1 step: 199, loss is 2.1108599
# epoch: 1 step: 200, loss is 1.7253184
# epoch: 1 step: 201, loss is 1.6158272
# epoch: 1 step: 202, loss is 1.6566976
# epoch: 1 step: 203, loss is 1.1605437
# epoch: 1 step: 204, loss is 1.2540694
# epoch: 1 step: 205, loss is 2.462833
# epoch: 1 step: 206, loss is 1.1870502
# epoch: 1 step: 207, loss is 1.2736261
# epoch: 1 step: 208, loss is 1.2693716
# epoch: 1 step: 209, loss is 1.1338611
# epoch: 1 step: 210, loss is 1.6610653
# epoch: 1 step: 211, loss is 1.9874483
# epoch: 1 step: 212, loss is 1.1971109
# epoch: 1 step: 213, loss is 1.0622306
# epoch: 1 step: 214, loss is 2.0402591
# epoch: 1 step: 215, loss is 3.378859
# epoch: 1 step: 216, loss is 2.26203
# epoch: 1 step: 217, loss is 1.8352858
# epoch: 1 step: 218, loss is 1.9343342
# epoch: 1 step: 219, loss is 1.9113437
# epoch: 1 step: 220, loss is 2.5771568
# epoch: 1 step: 221, loss is 1.6811591
# epoch: 1 step: 222, loss is 1.2664697
# epoch: 1 step: 223, loss is 1.4958805
# epoch: 1 step: 224, loss is 2.038511
# epoch: 1 step: 225, loss is 1.3371398
# epoch: 1 step: 226, loss is 0.958658
# epoch: 1 step: 227, loss is 1.1453974
# epoch: 1 step: 228, loss is 2.241105
# epoch: 1 step: 229, loss is 1.1495719
# epoch: 1 step: 230, loss is 1.8556021
# epoch: 1 step: 231, loss is 0.57944405
# epoch: 1 step: 232, loss is 1.5240965
# epoch: 1 step: 233, loss is 1.1546404
# epoch: 1 step: 234, loss is 1.5263864
# epoch: 1 step: 235, loss is 1.3797193
# epoch: 1 step: 236, loss is 1.2326174
# epoch: 1 step: 237, loss is 1.5385004
# epoch: 1 step: 238, loss is 1.8687003
# epoch: 1 step: 239, loss is 2.113118
# epoch: 1 step: 240, loss is 1.8401014
# epoch: 1 step: 241, loss is 1.2746384
# epoch: 1 step: 242, loss is 1.2599045
# epoch: 1 step: 243, loss is 0.77000034
# epoch: 1 step: 244, loss is 1.7323143
# epoch: 1 step: 245, loss is 1.3053011
# epoch: 1 step: 246, loss is 0.587897
# epoch: 1 step: 247, loss is 1.8409325
# epoch: 1 step: 248, loss is 1.5922186
# epoch: 1 step: 249, loss is 1.9486451
# epoch: 1 step: 250, loss is 0.8340744
# epoch: 1 step: 251, loss is 1.2214754
# epoch: 1 step: 252, loss is 1.9314387
# epoch: 1 step: 253, loss is 1.5851127
# epoch: 1 step: 254, loss is 1.3170798
# epoch: 1 step: 255, loss is 1.1042997
# epoch: 1 step: 256, loss is 2.1124094
# epoch: 1 step: 257, loss is 0.8210116
# epoch: 1 step: 258, loss is 1.1984701
# epoch: 1 step: 259, loss is 1.5910444
# epoch: 1 step: 260, loss is 1.5743002
# epoch: 1 step: 261, loss is 1.233602
# epoch: 1 step: 262, loss is 2.0705187
# epoch: 1 step: 263, loss is 1.5624658
# epoch: 1 step: 264, loss is 0.7299195
# epoch: 1 step: 265, loss is 1.3895663
# epoch: 1 step: 266, loss is 1.678746
# epoch: 1 step: 267, loss is 1.9954684
# epoch: 1 step: 268, loss is 1.3853419
# epoch: 1 step: 269, loss is 1.7446837
# epoch: 1 step: 270, loss is 1.4852421
# epoch: 1 step: 271, loss is 0.9326066
# epoch: 1 step: 272, loss is 1.1949983
# epoch: 1 step: 273, loss is 1.937663
# epoch: 1 step: 274, loss is 1.2390121
# epoch: 1 step: 275, loss is 2.3304322
# epoch: 1 step: 276, loss is 2.664047
# epoch: 1 step: 277, loss is 1.2946247
# epoch: 1 step: 278, loss is 1.7234491
# epoch: 1 step: 279, loss is 1.4093901
# epoch: 1 step: 280, loss is 1.7059562
# epoch: 1 step: 281, loss is 2.68426
# epoch: 1 step: 282, loss is 1.3454059
# epoch: 1 step: 283, loss is 1.806056
# epoch: 1 step: 284, loss is 1.9209304
# epoch: 1 step: 285, loss is 1.5650352
# epoch: 1 step: 286, loss is 1.0861859
# epoch: 1 step: 287, loss is 2.060105
# epoch: 1 step: 288, loss is 1.6028599
# epoch: 1 step: 289, loss is 0.8278801
# epoch: 1 step: 290, loss is 1.4973726
# epoch: 1 step: 291, loss is 2.0716038
# epoch: 1 step: 292, loss is 1.9487327
# epoch: 1 step: 293, loss is 1.3708771
# epoch: 1 step: 294, loss is 1.1203555
# epoch: 1 step: 295, loss is 1.0603414
# epoch: 1 step: 296, loss is 2.3021097
# epoch: 1 step: 297, loss is 1.0209073
# epoch: 1 step: 298, loss is 0.7971536
# epoch: 1 step: 299, loss is 1.0348907
# epoch: 1 step: 300, loss is 0.9248847
# epoch: 1 step: 301, loss is 1.0562054
# epoch: 1 step: 302, loss is 2.1563191
# epoch: 1 step: 303, loss is 2.2770267
# epoch: 1 step: 304, loss is 1.1778913
# epoch: 1 step: 305, loss is 1.987299
# epoch: 1 step: 306, loss is 1.2477816
# epoch: 1 step: 307, loss is 1.2426721
# epoch: 1 step: 308, loss is 1.9178183
# epoch: 1 step: 309, loss is 1.5833946
# epoch: 1 step: 310, loss is 1.5330313
# epoch: 1 step: 311, loss is 1.7007645
# epoch: 1 step: 312, loss is 1.8363153
# epoch: 1 step: 313, loss is 1.1928247
# epoch: 1 step: 314, loss is 1.1286267
# epoch: 1 step: 315, loss is 1.542225
# epoch: 1 step: 316, loss is 2.8737373
# epoch: 1 step: 317, loss is 1.3941844
# epoch: 1 step: 318, loss is 1.4710103
# epoch: 1 step: 319, loss is 1.7591852
# epoch: 1 step: 320, loss is 0.8942059
# epoch: 1 step: 321, loss is 1.9991027
# epoch: 1 step: 322, loss is 1.1954676
# epoch: 1 step: 323, loss is 1.5141307
# epoch: 1 step: 324, loss is 1.6650879
# epoch: 1 step: 325, loss is 1.7885985
# epoch: 1 step: 326, loss is 1.7360172
# epoch: 1 step: 327, loss is 1.7300606
# epoch: 1 step: 328, loss is 1.0959249
# epoch: 1 step: 329, loss is 1.7132994
# epoch: 1 step: 330, loss is 1.4758588
# epoch: 1 step: 331, loss is 1.2830478
# epoch: 1 step: 332, loss is 2.042423
# epoch: 1 step: 333, loss is 2.071842
# epoch: 1 step: 334, loss is 0.9920114
# epoch: 1 step: 335, loss is 1.3769026
# epoch: 1 step: 336, loss is 1.2798442
# epoch: 1 step: 337, loss is 1.3410527
# epoch: 1 step: 338, loss is 1.5878677
# epoch: 1 step: 339, loss is 1.0385991
# epoch: 1 step: 340, loss is 2.0833356
# epoch: 1 step: 341, loss is 1.2981517
# epoch: 1 step: 342, loss is 1.132826
# epoch: 1 step: 343, loss is 1.5458857
# epoch: 1 step: 344, loss is 2.1373672
# epoch: 1 step: 345, loss is 1.7218467
# epoch: 1 step: 346, loss is 2.4236863
# epoch: 1 step: 347, loss is 1.3011249
# epoch: 1 step: 348, loss is 1.7223673
# epoch: 1 step: 349, loss is 1.4905051
# epoch: 1 step: 350, loss is 1.4652839
# epoch: 1 step: 351, loss is 1.8141955
# epoch: 1 step: 352, loss is 1.0956308
# epoch: 1 step: 353, loss is 1.318897
# epoch: 1 step: 354, loss is 1.5854766
# epoch: 1 step: 355, loss is 1.8577597
# epoch: 1 step: 356, loss is 0.74583805
# epoch: 1 step: 357, loss is 1.1849554
# epoch: 1 step: 358, loss is 1.103523
# epoch: 1 step: 359, loss is 0.8013661
# epoch: 1 step: 360, loss is 0.7574434
# epoch: 1 step: 361, loss is 1.9558719
# epoch: 1 step: 362, loss is 1.308042
# epoch: 1 step: 363, loss is 1.4016052
# epoch: 1 step: 364, loss is 2.2265363
# epoch: 1 step: 365, loss is 1.3868225
# epoch: 1 step: 366, loss is 1.7889003
# epoch: 1 step: 367, loss is 1.2260202
# epoch: 1 step: 368, loss is 2.1652594
# epoch: 1 step: 369, loss is 1.018429
# epoch: 1 step: 370, loss is 2.2458687
# epoch: 1 step: 371, loss is 0.941826
# epoch: 1 step: 372, loss is 1.2290707
# epoch: 1 step: 373, loss is 1.4258242
# epoch: 1 step: 374, loss is 1.6637982
# epoch: 1 step: 375, loss is 1.9233809
# epoch: 1 step: 376, loss is 1.0412698
# epoch: 1 step: 377, loss is 0.9247024
# epoch: 1 step: 378, loss is 1.2410512
# epoch: 1 step: 379, loss is 2.2087448
# epoch: 1 step: 380, loss is 0.7328959
# epoch: 1 step: 381, loss is 1.1116295
# epoch: 1 step: 382, loss is 1.445832
# epoch: 1 step: 383, loss is 1.313537
# epoch: 1 step: 384, loss is 1.3352782
# epoch: 1 step: 385, loss is 1.5822498
# epoch: 1 step: 386, loss is 1.6000267
# epoch: 1 step: 387, loss is 1.9076669
# epoch: 1 step: 388, loss is 1.5835235
# epoch: 1 step: 389, loss is 0.9142811
# epoch: 1 step: 390, loss is 1.5254412
# epoch: 1 step: 391, loss is 1.8477011
# epoch: 1 step: 392, loss is 1.948134
# epoch: 1 step: 393, loss is 1.2354821
# epoch: 1 step: 394, loss is 0.9957573
# epoch: 1 step: 395, loss is 1.2284371
# epoch: 1 step: 396, loss is 1.0635126
# epoch: 1 step: 397, loss is 1.5527458
# epoch: 1 step: 398, loss is 2.4370353
# epoch: 1 step: 399, loss is 2.5879204
# epoch: 1 step: 400, loss is 1.4274639
# epoch: 1 step: 401, loss is 1.4231445
# epoch: 1 step: 402, loss is 1.8888873
# epoch: 1 step: 403, loss is 1.4024808
# epoch: 1 step: 404, loss is 1.7340935
# epoch: 1 step: 405, loss is 1.1101987
# epoch: 1 step: 406, loss is 2.5688965
# epoch: 1 step: 407, loss is 1.9036407
# epoch: 1 step: 408, loss is 1.0170014
# epoch: 1 step: 409, loss is 0.85084444
# epoch: 1 step: 410, loss is 1.0693889
# epoch: 1 step: 411, loss is 1.0997338
# epoch: 1 step: 412, loss is 1.716538
# epoch: 1 step: 413, loss is 1.8753316
# epoch: 1 step: 414, loss is 1.7404574
# epoch: 1 step: 415, loss is 1.610131
# epoch: 1 step: 416, loss is 0.9620383
# epoch: 1 step: 417, loss is 1.2672434
# epoch: 1 step: 418, loss is 1.3795328
# epoch: 1 step: 419, loss is 1.5679599
# epoch: 1 step: 420, loss is 1.2408686
# epoch: 1 step: 421, loss is 1.2752552
# epoch: 1 step: 422, loss is 1.1060841
# epoch: 1 step: 423, loss is 1.3582149
# epoch: 1 step: 424, loss is 1.4455581
# epoch: 1 step: 425, loss is 1.7094206
# epoch: 1 step: 426, loss is 1.132612
# epoch: 1 step: 427, loss is 1.2446395
# epoch: 1 step: 428, loss is 1.063408
# epoch: 1 step: 429, loss is 2.1510131
# epoch: 1 step: 430, loss is 1.4567684
# epoch: 1 step: 431, loss is 1.339819
# epoch: 1 step: 432, loss is 1.8465695
# epoch: 1 step: 433, loss is 1.7635487
# epoch: 1 step: 434, loss is 1.6327169
# epoch: 1 step: 435, loss is 1.7300773
# epoch: 1 step: 436, loss is 0.913731
# epoch: 1 step: 437, loss is 1.9742144
# epoch: 1 step: 438, loss is 1.0358552
# epoch: 1 step: 439, loss is 2.639979
# epoch: 1 step: 440, loss is 1.565113
# epoch: 1 step: 441, loss is 1.4425532
# epoch: 1 step: 442, loss is 1.4824536
# epoch: 1 step: 443, loss is 1.7946457
# epoch: 1 step: 444, loss is 2.8387778
# epoch: 1 step: 445, loss is 0.63560206
# epoch: 1 step: 446, loss is 1.7378876
# epoch: 1 step: 447, loss is 1.0767735
# epoch: 1 step: 448, loss is 2.0879266
# epoch: 1 step: 449, loss is 1.5104481
# epoch: 1 step: 450, loss is 1.5077786
# epoch: 1 step: 451, loss is 2.0625668
# epoch: 1 step: 452, loss is 2.3039203
# epoch: 1 step: 453, loss is 1.3084216
# epoch: 1 step: 454, loss is 1.6242607
# epoch: 1 step: 455, loss is 1.8108045
# epoch: 1 step: 456, loss is 1.8255689
# epoch: 1 step: 457, loss is 1.4245358
# epoch: 1 step: 458, loss is 2.1090827
# epoch: 1 step: 459, loss is 1.5425949
# epoch: 1 step: 460, loss is 1.1902771
# epoch: 1 step: 461, loss is 1.3838341
# epoch: 1 step: 462, loss is 1.5212672
# epoch: 1 step: 463, loss is 1.590676
# epoch: 1 step: 464, loss is 1.0308414
# epoch: 1 step: 465, loss is 1.586709
# epoch: 1 step: 466, loss is 0.90875167
# epoch: 1 step: 467, loss is 1.0077002
# epoch: 1 step: 468, loss is 1.2472099
# epoch: 1 step: 469, loss is 1.6239686
# epoch: 1 step: 470, loss is 1.7093426
# epoch: 1 step: 471, loss is 2.0803192
# epoch: 1 step: 472, loss is 2.2457223
# epoch: 1 step: 473, loss is 1.9069071
# epoch: 1 step: 474, loss is 1.620191
# epoch: 1 step: 475, loss is 1.7452818
# epoch: 1 step: 476, loss is 1.1382767
# epoch: 1 step: 477, loss is 1.815863
# epoch: 1 step: 478, loss is 1.2106223
# epoch: 1 step: 479, loss is 0.936922
# epoch: 1 step: 480, loss is 1.1306139
# epoch: 1 step: 481, loss is 1.3599908
# epoch: 1 step: 482, loss is 2.0294847
# epoch: 1 step: 483, loss is 1.386905
# epoch: 1 step: 484, loss is 1.3919551
# epoch: 1 step: 485, loss is 1.9387065
# epoch: 1 step: 486, loss is 1.2162956
# epoch: 1 step: 487, loss is 1.5146277
# epoch: 1 step: 488, loss is 1.2395535
# epoch: 1 step: 489, loss is 1.4750794
# epoch: 1 step: 490, loss is 1.2648641
# epoch: 1 step: 491, loss is 2.1821773
# epoch: 1 step: 492, loss is 1.1892427
# epoch: 1 step: 493, loss is 1.6209656
# epoch: 1 step: 494, loss is 1.4380717
# epoch: 1 step: 495, loss is 1.4746121
# epoch: 1 step: 496, loss is 0.95195997
# epoch: 1 step: 497, loss is 1.0640957
# epoch: 1 step: 498, loss is 2.2552924
# epoch: 1 step: 499, loss is 1.0786781
# epoch: 1 step: 500, loss is 2.0554984
# epoch: 1 step: 501, loss is 1.0892892
# epoch: 1 step: 502, loss is 2.0550132
# epoch: 1 step: 503, loss is 0.91103345
# epoch: 1 step: 504, loss is 2.1143868
# epoch: 1 step: 505, loss is 1.0952914
# epoch: 1 step: 506, loss is 0.6666688
# epoch: 1 step: 507, loss is 1.4641277
# epoch: 1 step: 508, loss is 1.2475754
# epoch: 1 step: 509, loss is 2.0710325
# epoch: 1 step: 510, loss is 1.3117552
# epoch: 1 step: 511, loss is 2.3045518
# epoch: 1 step: 512, loss is 1.737609
# epoch: 1 step: 513, loss is 0.92866683
# epoch: 1 step: 514, loss is 1.0087187
# epoch: 1 step: 515, loss is 2.4910755
# epoch: 1 step: 516, loss is 1.6886109
# epoch: 1 step: 517, loss is 0.99884635
# epoch: 1 step: 518, loss is 1.5184568
# epoch: 1 step: 519, loss is 1.1961249
# epoch: 1 step: 520, loss is 1.8326496
# epoch: 1 step: 521, loss is 1.7536647
# epoch: 1 step: 522, loss is 1.3382577
# epoch: 1 step: 523, loss is 1.0382409
# epoch: 1 step: 524, loss is 1.5338681
# epoch: 1 step: 525, loss is 1.5322326
# epoch: 1 step: 526, loss is 0.76114464
# epoch: 1 step: 527, loss is 0.76843333
# epoch: 1 step: 528, loss is 1.3406154
# epoch: 1 step: 529, loss is 1.8920934
# epoch: 1 step: 530, loss is 1.8758721
# epoch: 1 step: 531, loss is 0.7055465
# epoch: 1 step: 532, loss is 1.1245338
# epoch: 1 step: 533, loss is 1.9139239
# epoch: 1 step: 534, loss is 1.0956714
# epoch: 1 step: 535, loss is 2.560975
# epoch: 1 step: 536, loss is 1.3559549
# epoch: 1 step: 537, loss is 1.9270667
# epoch: 1 step: 538, loss is 1.3847598
# epoch: 1 step: 539, loss is 1.0709893
# epoch: 1 step: 540, loss is 1.209909
# epoch: 1 step: 541, loss is 1.0319433
# epoch: 1 step: 542, loss is 1.0667533
# epoch: 1 step: 543, loss is 1.4375757
# epoch: 1 step: 544, loss is 1.7170163
# epoch: 1 step: 545, loss is 1.3668438
# epoch: 1 step: 546, loss is 1.9486972
# epoch: 1 step: 547, loss is 0.77231485
# epoch: 1 step: 548, loss is 1.3353825
# epoch: 1 step: 549, loss is 1.1192862
# epoch: 1 step: 550, loss is 1.6822715
# epoch: 1 step: 551, loss is 1.4677196
# epoch: 1 step: 552, loss is 0.9413048
# epoch: 1 step: 553, loss is 1.904834
# epoch: 1 step: 554, loss is 1.3196874
# epoch: 1 step: 555, loss is 1.5251694
# epoch: 1 step: 556, loss is 1.379142
# epoch: 1 step: 557, loss is 3.523172
# epoch: 1 step: 558, loss is 1.0008852
# epoch: 1 step: 559, loss is 2.3046873
# epoch: 1 step: 560, loss is 1.2962911
# epoch: 1 step: 561, loss is 1.1020261
# epoch: 1 step: 562, loss is 1.3279613
# epoch: 1 step: 563, loss is 1.7419522
# epoch: 1 step: 564, loss is 1.3116199
# epoch: 1 step: 565, loss is 1.0362442
# epoch: 1 step: 566, loss is 1.7868187
# epoch: 1 step: 567, loss is 1.2538186
# epoch: 1 step: 568, loss is 1.3778642
# epoch: 1 step: 569, loss is 1.1191275
# epoch: 1 step: 570, loss is 0.73970515
# epoch: 1 step: 571, loss is 0.95281816
# epoch: 1 step: 572, loss is 1.73302
# epoch: 1 step: 573, loss is 1.972593
# epoch: 1 step: 574, loss is 2.0420225
# epoch: 1 step: 575, loss is 0.81882244
# epoch: 1 step: 576, loss is 1.1089412
# epoch: 1 step: 577, loss is 1.6637708
# epoch: 1 step: 578, loss is 1.5535136
# epoch: 1 step: 579, loss is 1.3326262
# epoch: 1 step: 580, loss is 0.8053005
# epoch: 1 step: 581, loss is 1.0468158
# epoch: 1 step: 582, loss is 1.7531935
# epoch: 1 step: 583, loss is 0.9371764
# epoch: 1 step: 584, loss is 1.5825409
# epoch: 1 step: 585, loss is 1.2914729
# epoch: 1 step: 586, loss is 2.3164473
# epoch: 1 step: 587, loss is 1.828443
# epoch: 1 step: 588, loss is 1.3597904
# epoch: 1 step: 589, loss is 1.0486209
# epoch: 1 step: 590, loss is 0.9298874
# epoch: 1 step: 591, loss is 1.1960946
# epoch: 1 step: 592, loss is 1.176678
# epoch: 1 step: 593, loss is 1.696447
# epoch: 1 step: 594, loss is 0.802177
# epoch: 1 step: 595, loss is 0.9629202
# epoch: 1 step: 596, loss is 0.32188508
# epoch: 1 step: 597, loss is 1.1873218
# epoch: 1 step: 598, loss is 2.0090742
# epoch: 1 step: 599, loss is 1.538155
# epoch: 1 step: 600, loss is 1.0316839
# epoch: 1 step: 601, loss is 2.9553216
# epoch: 1 step: 602, loss is 0.9886575
# epoch: 1 step: 603, loss is 1.5461138
# epoch: 1 step: 604, loss is 0.98695207
# epoch: 1 step: 605, loss is 1.7344837
# epoch: 1 step: 606, loss is 1.6900105
# epoch: 1 step: 607, loss is 2.1332922
# epoch: 1 step: 608, loss is 1.6295782
# epoch: 1 step: 609, loss is 1.2664893
# epoch: 1 step: 610, loss is 1.2265837
# epoch: 1 step: 611, loss is 1.2819761
# epoch: 1 step: 612, loss is 1.1346314
# epoch: 1 step: 613, loss is 1.9635831
# epoch: 1 step: 614, loss is 1.1478118
# epoch: 1 step: 615, loss is 0.70902526
# epoch: 1 step: 616, loss is 1.9801917
# epoch: 1 step: 617, loss is 1.8173015
# epoch: 1 step: 618, loss is 0.9141841
# epoch: 1 step: 619, loss is 1.9482242
# epoch: 1 step: 620, loss is 1.2846959
# epoch: 1 step: 621, loss is 2.026319
# epoch: 1 step: 622, loss is 1.2782547
# epoch: 1 step: 623, loss is 1.5615569
# epoch: 1 step: 624, loss is 2.2573922
# epoch: 1 step: 625, loss is 1.0118905
# epoch: 1 step: 626, loss is 1.4730891
# epoch: 1 step: 627, loss is 0.8739333
# epoch: 1 step: 628, loss is 1.1440542
# epoch: 1 step: 629, loss is 1.160545
# epoch: 1 step: 630, loss is 2.5343819
# epoch: 1 step: 631, loss is 0.8157446
# epoch: 1 step: 632, loss is 1.4984394
# epoch: 1 step: 633, loss is 1.9786755
# epoch: 1 step: 634, loss is 1.2754388
# epoch: 1 step: 635, loss is 0.7003326
# epoch: 1 step: 636, loss is 1.813125
# epoch: 1 step: 637, loss is 1.5424762
# epoch: 1 step: 638, loss is 1.0368906
# epoch: 1 step: 639, loss is 1.6836318
# epoch: 1 step: 640, loss is 1.2119683
# epoch: 1 step: 641, loss is 1.4762125
# epoch: 1 step: 642, loss is 2.025914
# epoch: 1 step: 643, loss is 1.2397056
# epoch: 1 step: 644, loss is 1.4449261
# epoch: 1 step: 645, loss is 0.9490071
# epoch: 1 step: 646, loss is 1.7847936
# epoch: 1 step: 647, loss is 0.8422969
# epoch: 1 step: 648, loss is 1.508172
# epoch: 1 step: 649, loss is 2.3431418
# epoch: 1 step: 650, loss is 1.862414
# epoch: 1 step: 651, loss is 1.0557597
# epoch: 1 step: 652, loss is 1.5680847
# epoch: 1 step: 653, loss is 1.7502407
# epoch: 1 step: 654, loss is 1.1724029
# epoch: 1 step: 655, loss is 2.3953156
# epoch: 1 step: 656, loss is 1.8229299
# epoch: 1 step: 657, loss is 2.0717497
# epoch: 1 step: 658, loss is 0.953485
# epoch: 1 step: 659, loss is 1.1947378
# epoch: 1 step: 660, loss is 1.7559129
# epoch: 1 step: 661, loss is 1.7019479
# epoch: 1 step: 662, loss is 1.5198362
# epoch: 1 step: 663, loss is 0.3161143
# epoch: 1 step: 664, loss is 1.8671987
# epoch: 1 step: 665, loss is 1.6879032
# epoch: 1 step: 666, loss is 2.176939
# epoch: 1 step: 667, loss is 1.8774629
# epoch: 1 step: 668, loss is 1.6341183
# epoch: 1 step: 669, loss is 1.9718827
# epoch: 1 step: 670, loss is 1.6594346
# epoch: 1 step: 671, loss is 1.9998994
# epoch: 1 step: 672, loss is 2.06532
# epoch: 1 step: 673, loss is 1.2939131
# epoch: 1 step: 674, loss is 1.8903477
# epoch: 1 step: 675, loss is 1.548856
# epoch: 1 step: 676, loss is 0.9545724
# epoch: 1 step: 677, loss is 1.6300222
# epoch: 1 step: 678, loss is 1.7118775
# epoch: 1 step: 679, loss is 0.8535284
# epoch: 1 step: 680, loss is 0.63179874
# epoch: 1 step: 681, loss is 2.0994828
# epoch: 1 step: 682, loss is 1.3722119
# epoch: 1 step: 683, loss is 1.5657363
# epoch: 1 step: 684, loss is 2.2008183
# epoch: 1 step: 685, loss is 1.7107782
# epoch: 1 step: 686, loss is 0.924971
# epoch: 1 step: 687, loss is 1.4311597
# epoch: 1 step: 688, loss is 1.4934964
# epoch: 1 step: 689, loss is 2.0644677
# epoch: 1 step: 690, loss is 1.3171751
# epoch: 1 step: 691, loss is 1.126818
# epoch: 1 step: 692, loss is 2.079288
# epoch: 1 step: 693, loss is 1.2911729
# epoch: 1 step: 694, loss is 0.9611875
# epoch: 1 step: 695, loss is 0.65991676
# epoch: 1 step: 696, loss is 2.3834534
# epoch: 1 step: 697, loss is 1.7662083
# epoch: 1 step: 698, loss is 1.0126857
# epoch: 1 step: 699, loss is 1.0521343
# epoch: 1 step: 700, loss is 1.0669049
# epoch: 1 step: 701, loss is 2.4690402
# epoch: 1 step: 702, loss is 2.3738878
# epoch: 1 step: 703, loss is 2.238657
# epoch: 1 step: 704, loss is 1.2920747
# epoch: 1 step: 705, loss is 1.6601423
# epoch: 1 step: 706, loss is 1.7468362
# epoch: 1 step: 707, loss is 1.6076142
# epoch: 1 step: 708, loss is 1.6268007
# epoch: 1 step: 709, loss is 1.7594513
# epoch: 1 step: 710, loss is 1.2270852
# epoch: 1 step: 711, loss is 1.5326612
# epoch: 1 step: 712, loss is 1.7847258
# epoch: 1 step: 713, loss is 2.791762
# epoch: 1 step: 714, loss is 1.4036062
# epoch: 1 step: 715, loss is 2.084698
# epoch: 1 step: 716, loss is 1.7170213
# epoch: 1 step: 717, loss is 1.2128447
# epoch: 1 step: 718, loss is 1.6202569
# epoch: 1 step: 719, loss is 1.264753
# epoch: 1 step: 720, loss is 1.6165396
# epoch: 1 step: 721, loss is 2.0469308
# epoch: 1 step: 722, loss is 2.4901798
# epoch: 1 step: 723, loss is 0.8685472
# epoch: 1 step: 724, loss is 1.2798688
# epoch: 1 step: 725, loss is 1.5027827
# epoch: 1 step: 726, loss is 1.4686193
# epoch: 1 step: 727, loss is 2.1302352
# epoch: 1 step: 728, loss is 1.3151157
# epoch: 1 step: 729, loss is 1.4133688
# epoch: 1 step: 730, loss is 1.6458306
# epoch: 1 step: 731, loss is 1.0657562
# epoch: 1 step: 732, loss is 1.9479088
# epoch: 1 step: 733, loss is 1.7082529
# epoch: 1 step: 734, loss is 0.8159938
# epoch: 1 step: 735, loss is 1.5400941
# epoch: 1 step: 736, loss is 1.0293559
# epoch: 1 step: 737, loss is 2.4729686
# epoch: 1 step: 738, loss is 1.8659835
# epoch: 1 step: 739, loss is 1.7932405
# epoch: 1 step: 740, loss is 1.4898523
# epoch: 1 step: 741, loss is 1.3852189
# epoch: 1 step: 742, loss is 1.6167002
# epoch: 1 step: 743, loss is 2.2722418
# epoch: 1 step: 744, loss is 1.462794
# epoch: 1 step: 745, loss is 1.7781445
# epoch: 1 step: 746, loss is 1.1989498
# epoch: 1 step: 747, loss is 0.9477492
# epoch: 1 step: 748, loss is 1.5233597
# epoch: 1 step: 749, loss is 1.3464874
# epoch: 1 step: 750, loss is 1.6163187
# epoch: 1 step: 751, loss is 1.7124178
# epoch: 1 step: 752, loss is 1.3048589
# epoch: 1 step: 753, loss is 2.588724
# epoch: 1 step: 754, loss is 1.4724698
# epoch: 1 step: 755, loss is 1.3303113
# epoch: 1 step: 756, loss is 1.3597724
# epoch: 1 step: 757, loss is 1.0615202
# epoch: 1 step: 758, loss is 0.6996793
# epoch: 1 step: 759, loss is 2.3514779
# epoch: 1 step: 760, loss is 2.2681017
# epoch: 1 step: 761, loss is 2.064627
# epoch: 1 step: 762, loss is 0.8929702
# epoch: 1 step: 763, loss is 1.2849934
# epoch: 1 step: 764, loss is 1.435087
# epoch: 1 step: 765, loss is 2.184455
# epoch: 1 step: 766, loss is 1.2496016
# epoch: 1 step: 767, loss is 1.4718003
# epoch: 1 step: 768, loss is 1.9918345
# epoch: 1 step: 769, loss is 1.2119079
# epoch: 1 step: 770, loss is 1.269549
# epoch: 1 step: 771, loss is 1.0034428
# epoch: 1 step: 772, loss is 0.9009123
# epoch: 1 step: 773, loss is 1.3305686
# epoch: 1 step: 774, loss is 1.6949396
# epoch: 1 step: 775, loss is 0.8718981
# epoch: 1 step: 776, loss is 1.3559142
# epoch: 1 step: 777, loss is 1.9639013
# epoch: 1 step: 778, loss is 1.3213581
# epoch: 1 step: 779, loss is 2.2361608
# epoch: 1 step: 780, loss is 1.3361189
# epoch: 1 step: 781, loss is 1.1997887
# epoch: 1 step: 782, loss is 1.3294711
# epoch: 1 step: 783, loss is 0.78962505
# epoch: 1 step: 784, loss is 1.0157884
# epoch: 1 step: 785, loss is 1.0485065
# epoch: 1 step: 786, loss is 1.306622
# epoch: 1 step: 787, loss is 1.8009349
# epoch: 1 step: 788, loss is 0.76971424
# epoch: 1 step: 789, loss is 2.1537929
# epoch: 1 step: 790, loss is 1.9030838
# epoch: 1 step: 791, loss is 1.1930083
# epoch: 1 step: 792, loss is 1.1762329
# epoch: 1 step: 793, loss is 1.1719582
# epoch: 1 step: 794, loss is 0.7591583
# epoch: 1 step: 795, loss is 1.2755278
# epoch: 1 step: 796, loss is 1.7254333
# epoch: 1 step: 797, loss is 1.1372619
# epoch: 1 step: 798, loss is 1.1638128
# epoch: 1 step: 799, loss is 1.5343716
# epoch: 1 step: 800, loss is 1.248997
# epoch: 1 step: 801, loss is 1.8887742
# epoch: 1 step: 802, loss is 1.2396773
# epoch: 1 step: 803, loss is 0.78753877
# epoch: 1 step: 804, loss is 2.5981026
# epoch: 1 step: 805, loss is 1.5970851
# epoch: 1 step: 806, loss is 2.527588
# epoch: 1 step: 807, loss is 1.7830793
# epoch: 1 step: 808, loss is 1.3347356
# epoch: 1 step: 809, loss is 1.3642029
# epoch: 1 step: 810, loss is 1.0563958
# epoch: 1 step: 811, loss is 1.3720865
# epoch: 1 step: 812, loss is 1.2016026
# epoch: 1 step: 813, loss is 1.0897747
# epoch: 1 step: 814, loss is 0.79205203
# epoch: 1 step: 815, loss is 0.58857626
# epoch: 1 step: 816, loss is 1.6978661
# epoch: 1 step: 817, loss is 0.40609568
# epoch: 1 step: 818, loss is 1.3676306
# epoch: 1 step: 819, loss is 2.510613
# epoch: 1 step: 820, loss is 1.4405245
# epoch: 1 step: 821, loss is 1.1356025
# epoch: 1 step: 822, loss is 1.6193427
# epoch: 1 step: 823, loss is 1.3462952
# epoch: 1 step: 824, loss is 1.6296272
# epoch: 1 step: 825, loss is 1.482545
# epoch: 1 step: 826, loss is 1.0520271
# epoch: 1 step: 827, loss is 1.7773577
# epoch: 1 step: 828, loss is 0.7152825
# epoch: 1 step: 829, loss is 2.085778
# epoch: 1 step: 830, loss is 0.9971691
# epoch: 1 step: 831, loss is 2.2525315
# epoch: 1 step: 832, loss is 1.5179845
# epoch: 1 step: 833, loss is 0.928252
# epoch: 1 step: 834, loss is 2.3534813
# epoch: 1 step: 835, loss is 1.4777766
# epoch: 1 step: 836, loss is 1.2141368
# epoch: 1 step: 837, loss is 1.8744919
# epoch: 1 step: 838, loss is 2.5236619
# epoch: 1 step: 839, loss is 1.784162
# epoch: 1 step: 840, loss is 2.0454533
# epoch: 1 step: 841, loss is 1.5408566
# epoch: 1 step: 842, loss is 1.1697619
# epoch: 1 step: 843, loss is 2.1152387
# epoch: 1 step: 844, loss is 1.1442946
# epoch: 1 step: 845, loss is 1.1973189
# epoch: 1 step: 846, loss is 1.5280342
# epoch: 1 step: 847, loss is 2.1908958
# epoch: 1 step: 848, loss is 0.922262
# epoch: 1 step: 849, loss is 1.0723104
# epoch: 1 step: 850, loss is 1.097762
# epoch: 1 step: 851, loss is 0.8159098
# epoch: 1 step: 852, loss is 0.79185766
# epoch: 1 step: 853, loss is 1.7802184
# epoch: 1 step: 854, loss is 2.1219306
# epoch: 1 step: 855, loss is 1.1607608
# epoch: 1 step: 856, loss is 2.3975728
# epoch: 1 step: 857, loss is 0.9792848
# epoch: 1 step: 858, loss is 1.3414812
# epoch: 1 step: 859, loss is 1.3106354
# epoch: 1 step: 860, loss is 0.85836977
# epoch: 1 step: 861, loss is 0.9811545
# epoch: 1 step: 862, loss is 1.0656874
# epoch: 1 step: 863, loss is 1.6175435
# epoch: 1 step: 864, loss is 1.0202935
# epoch: 1 step: 865, loss is 0.95000595
# epoch: 1 step: 866, loss is 1.7780056
# epoch: 1 step: 867, loss is 2.9442914
# epoch: 1 step: 868, loss is 1.6642019
# epoch: 1 step: 869, loss is 1.2855533
# epoch: 1 step: 870, loss is 1.1326591
# epoch: 1 step: 871, loss is 1.3430622
# epoch: 1 step: 872, loss is 0.8714635
# epoch: 1 step: 873, loss is 1.152508
# epoch: 1 step: 874, loss is 0.96203476
# epoch: 1 step: 875, loss is 2.7341568
# epoch: 1 step: 876, loss is 2.1293862
# epoch: 1 step: 877, loss is 1.9098686
# epoch: 1 step: 878, loss is 1.4676943
# epoch: 1 step: 879, loss is 1.9137943
# epoch: 1 step: 880, loss is 2.2088459
# epoch: 1 step: 881, loss is 1.9725151
# epoch: 1 step: 882, loss is 2.26292
# epoch: 1 step: 883, loss is 1.5833251
# epoch: 1 step: 884, loss is 1.2361908
# epoch: 1 step: 885, loss is 1.127405
# epoch: 1 step: 886, loss is 1.7855935
# epoch: 1 step: 887, loss is 1.476029
# epoch: 1 step: 888, loss is 1.4543735
# epoch: 1 step: 889, loss is 0.67791855
# epoch: 1 step: 890, loss is 1.0830917
# epoch: 1 step: 891, loss is 2.3207438
# epoch: 1 step: 892, loss is 0.94103956
# epoch: 1 step: 893, loss is 1.4241868
# epoch: 1 step: 894, loss is 1.2623756
# epoch: 1 step: 895, loss is 1.2870926
# epoch: 1 step: 896, loss is 1.2680298
# epoch: 1 step: 897, loss is 1.7198896
# epoch: 1 step: 898, loss is 0.99046916
# epoch: 1 step: 899, loss is 1.8668718
# epoch: 1 step: 900, loss is 1.2371211
# epoch: 1 step: 901, loss is 1.5625579
# epoch: 1 step: 902, loss is 1.6949095
# epoch: 1 step: 903, loss is 1.324875
# epoch: 1 step: 904, loss is 0.8929617
# epoch: 1 step: 905, loss is 0.8001815
# epoch: 1 step: 906, loss is 1.2729163
# epoch: 1 step: 907, loss is 1.7581606
# epoch: 1 step: 908, loss is 1.9290935
# epoch: 1 step: 909, loss is 2.940459
# epoch: 1 step: 910, loss is 1.7729146
# epoch: 1 step: 911, loss is 1.0075728
# epoch: 1 step: 912, loss is 1.1220982
# epoch: 1 step: 913, loss is 1.9773101
# epoch: 1 step: 914, loss is 1.2083284
# epoch: 1 step: 915, loss is 1.6500279
# epoch: 1 step: 916, loss is 1.1582457
# epoch: 1 step: 917, loss is 1.2336812
# epoch: 1 step: 918, loss is 1.7593004
# epoch: 1 step: 919, loss is 1.0040243
# epoch: 1 step: 920, loss is 1.151289
# epoch: 1 step: 921, loss is 1.6059681
# epoch: 1 step: 922, loss is 1.5187815
# epoch: 1 step: 923, loss is 1.2599208
# epoch: 1 step: 924, loss is 2.2167945
# epoch: 1 step: 925, loss is 0.57554203
# epoch: 1 step: 926, loss is 1.1171564
# epoch: 1 step: 927, loss is 1.7361237
# epoch: 1 step: 928, loss is 1.3540643
# epoch: 1 step: 929, loss is 0.7852069
# epoch: 1 step: 930, loss is 1.2292079
# epoch: 1 step: 931, loss is 1.2476995
# epoch: 1 step: 932, loss is 1.3115844
# epoch: 1 step: 933, loss is 0.977798
# epoch: 1 step: 934, loss is 1.6950641
# epoch: 1 step: 935, loss is 1.308453
# epoch: 1 step: 936, loss is 0.84914774
# epoch: 1 step: 937, loss is 1.9107182
# epoch: 1 step: 938, loss is 1.4977964
# epoch: 1 step: 939, loss is 1.6208137
# epoch: 1 step: 940, loss is 1.2800441
# epoch: 1 step: 941, loss is 1.3259151
# epoch: 1 step: 942, loss is 1.5719937
# epoch: 1 step: 943, loss is 1.1116352
# epoch: 1 step: 944, loss is 0.8321867
# epoch: 1 step: 945, loss is 1.0873759
# epoch: 1 step: 946, loss is 2.5068586
# epoch: 1 step: 947, loss is 0.69852275
# epoch: 1 step: 948, loss is 1.6570631
# epoch: 1 step: 949, loss is 1.9960923
# epoch: 1 step: 950, loss is 0.92595124
# epoch: 1 step: 951, loss is 1.197519
# epoch: 1 step: 952, loss is 1.5626574
# epoch: 1 step: 953, loss is 1.5351475
# epoch: 1 step: 954, loss is 1.4364326
# epoch: 1 step: 955, loss is 2.180224
# epoch: 1 step: 956, loss is 1.0038275
# epoch: 1 step: 957, loss is 2.2085536
# epoch: 1 step: 958, loss is 1.2943135
# epoch: 1 step: 959, loss is 1.176755
# epoch: 1 step: 960, loss is 1.0915365
# epoch: 1 step: 961, loss is 0.75128025
# epoch: 1 step: 962, loss is 1.1159668
# epoch: 1 step: 963, loss is 0.9119248
# epoch: 1 step: 964, loss is 0.9663843
# epoch: 1 step: 965, loss is 0.8448137
# epoch: 1 step: 966, loss is 1.8631399
# epoch: 1 step: 967, loss is 2.1188958
# epoch: 1 step: 968, loss is 2.2770948
# epoch: 1 step: 969, loss is 1.0197463
# epoch: 1 step: 970, loss is 1.6863546
# epoch: 1 step: 971, loss is 1.5532745
# epoch: 1 step: 972, loss is 1.0845559
# epoch: 1 step: 973, loss is 2.2996173
# epoch: 1 step: 974, loss is 1.4565843
# epoch: 1 step: 975, loss is 1.9680654
# epoch: 1 step: 976, loss is 1.9036261
# epoch: 1 step: 977, loss is 2.0291152
# epoch: 1 step: 978, loss is 1.2813292
# epoch: 1 step: 979, loss is 0.89770335
# epoch: 1 step: 980, loss is 1.4189215
# epoch: 1 step: 981, loss is 1.267931
# epoch: 1 step: 982, loss is 2.6820447
# epoch: 1 step: 983, loss is 1.5117075
# epoch: 1 step: 984, loss is 1.8274904
# epoch: 1 step: 985, loss is 0.9523236
# epoch: 1 step: 986, loss is 1.6147321
# epoch: 1 step: 987, loss is 0.6539404
# epoch: 1 step: 988, loss is 3.6475492
# epoch: 1 step: 989, loss is 1.5734857
# epoch: 1 step: 990, loss is 1.3088586
# epoch: 1 step: 991, loss is 1.5736068
# epoch: 1 step: 992, loss is 2.6416385
# epoch: 1 step: 993, loss is 1.5744479
# epoch: 1 step: 994, loss is 1.0768981
# epoch: 1 step: 995, loss is 2.0752513
# epoch: 1 step: 996, loss is 1.1737759
# epoch: 1 step: 997, loss is 1.912667
# epoch: 1 step: 998, loss is 1.9507943
# epoch: 1 step: 999, loss is 1.8798915
# epoch: 1 step: 1000, loss is 1.494334
# epoch: 1 step: 1001, loss is 1.8347636
# epoch: 1 step: 1002, loss is 1.9530593
# epoch: 1 step: 1003, loss is 2.0051177
# epoch: 1 step: 1004, loss is 1.0203353
# epoch: 1 step: 1005, loss is 1.5323124
# epoch: 1 step: 1006, loss is 1.1655221
# epoch: 1 step: 1007, loss is 1.3707734
# epoch: 1 step: 1008, loss is 0.95099264
# epoch: 1 step: 1009, loss is 1.7931572
# epoch: 1 step: 1010, loss is 2.2637002
# epoch: 1 step: 1011, loss is 0.9663309
# epoch: 1 step: 1012, loss is 1.4104706
# epoch: 1 step: 1013, loss is 1.0146003
# epoch: 1 step: 1014, loss is 1.2011957
# epoch: 1 step: 1015, loss is 0.9408639
# epoch: 1 step: 1016, loss is 0.97284114
# epoch: 1 step: 1017, loss is 1.8853773
# epoch: 1 step: 1018, loss is 1.3944443
# epoch: 1 step: 1019, loss is 1.2310575
# epoch: 1 step: 1020, loss is 1.1046271
# epoch: 1 step: 1021, loss is 1.9775168
# epoch: 1 step: 1022, loss is 1.4359499
# epoch: 1 step: 1023, loss is 1.1653538
# epoch: 1 step: 1024, loss is 1.1938479
# epoch: 1 step: 1025, loss is 1.0200602
# epoch: 1 step: 1026, loss is 1.3274735
# epoch: 1 step: 1027, loss is 1.3724147
# epoch: 1 step: 1028, loss is 1.378948
# epoch: 1 step: 1029, loss is 0.8268159
# epoch: 1 step: 1030, loss is 1.8339639
# epoch: 1 step: 1031, loss is 1.2854037
# epoch: 1 step: 1032, loss is 1.4061617
# epoch: 1 step: 1033, loss is 1.6090592
# epoch: 1 step: 1034, loss is 1.3763614
# epoch: 1 step: 1035, loss is 1.069732
# epoch: 1 step: 1036, loss is 1.3933331
# epoch: 1 step: 1037, loss is 1.595968
# epoch: 1 step: 1038, loss is 1.8229111
# epoch: 1 step: 1039, loss is 0.95444703
# epoch: 1 step: 1040, loss is 1.2553655
# epoch: 1 step: 1041, loss is 1.4337271
# epoch: 1 step: 1042, loss is 1.3649819
# epoch: 1 step: 1043, loss is 0.7301635
# epoch: 1 step: 1044, loss is 0.74753606
# epoch: 1 step: 1045, loss is 2.2026334
# epoch: 1 step: 1046, loss is 0.8613633
# epoch: 1 step: 1047, loss is 1.2345282
# epoch: 1 step: 1048, loss is 2.0263376
# epoch: 1 step: 1049, loss is 2.633867
# epoch: 1 step: 1050, loss is 1.5478123
# epoch: 1 step: 1051, loss is 1.3537719
# epoch: 1 step: 1052, loss is 1.5165057
# epoch: 1 step: 1053, loss is 1.7074509
# epoch: 1 step: 1054, loss is 1.2040501
# epoch: 1 step: 1055, loss is 1.9707584
# epoch: 1 step: 1056, loss is 1.56417
# epoch: 1 step: 1057, loss is 1.131876
# epoch: 1 step: 1058, loss is 2.09377
# epoch: 1 step: 1059, loss is 1.2131828
# epoch: 1 step: 1060, loss is 1.4656092
# epoch: 1 step: 1061, loss is 0.5534101
# epoch: 1 step: 1062, loss is 0.8293927
# epoch: 1 step: 1063, loss is 1.983326
# epoch: 1 step: 1064, loss is 1.7259825
# epoch: 1 step: 1065, loss is 0.7221515
# epoch: 1 step: 1066, loss is 0.82597953
# epoch: 1 step: 1067, loss is 1.5535538
# epoch: 1 step: 1068, loss is 1.1054673
# epoch: 1 step: 1069, loss is 1.2984598
# epoch: 1 step: 1070, loss is 1.0844116
# epoch: 1 step: 1071, loss is 1.4243063
# epoch: 1 step: 1072, loss is 1.6618588
# epoch: 1 step: 1073, loss is 1.1779071
# epoch: 1 step: 1074, loss is 1.1648751
# epoch: 1 step: 1075, loss is 1.5509092
# epoch: 1 step: 1076, loss is 2.1439273
# epoch: 1 step: 1077, loss is 0.9731117
# epoch: 1 step: 1078, loss is 1.2275294
# epoch: 1 step: 1079, loss is 0.7600953
# epoch: 1 step: 1080, loss is 0.99485856
# epoch: 1 step: 1081, loss is 0.9726558
# epoch: 1 step: 1082, loss is 1.3829399
# epoch: 1 step: 1083, loss is 1.1773062
# epoch: 1 step: 1084, loss is 2.9535885
# epoch: 1 step: 1085, loss is 0.970381
# epoch: 1 step: 1086, loss is 2.8532593
# epoch: 1 step: 1087, loss is 0.8269313
# epoch: 1 step: 1088, loss is 1.2900716
# epoch: 1 step: 1089, loss is 1.3232168
# epoch: 1 step: 1090, loss is 2.469127
# epoch: 1 step: 1091, loss is 1.5749971
# epoch: 1 step: 1092, loss is 1.2721083
# epoch: 1 step: 1093, loss is 1.5001273
# epoch: 1 step: 1094, loss is 1.8269935
# epoch: 1 step: 1095, loss is 1.3363652
# epoch: 1 step: 1096, loss is 1.3096133
# epoch: 1 step: 1097, loss is 0.91275215
# epoch: 1 step: 1098, loss is 2.4678628
# epoch: 1 step: 1099, loss is 1.1642016
# epoch: 1 step: 1100, loss is 1.8312427
# epoch: 1 step: 1101, loss is 1.7690115
# epoch: 1 step: 1102, loss is 1.2590694
# epoch: 1 step: 1103, loss is 2.1893704
# epoch: 1 step: 1104, loss is 1.0446479
# epoch: 1 step: 1105, loss is 0.8926092
# epoch: 1 step: 1106, loss is 1.0513273
# epoch: 1 step: 1107, loss is 1.0124454
# epoch: 1 step: 1108, loss is 0.90774524
# epoch: 1 step: 1109, loss is 1.12521
# epoch: 1 step: 1110, loss is 1.6417425
# epoch: 1 step: 1111, loss is 1.7367694
# epoch: 1 step: 1112, loss is 1.3345084
# epoch: 1 step: 1113, loss is 1.3916306
# epoch: 1 step: 1114, loss is 1.2670125
# epoch: 1 step: 1115, loss is 2.1571503
# epoch: 1 step: 1116, loss is 1.3873911
# epoch: 1 step: 1117, loss is 1.1907597
# epoch: 1 step: 1118, loss is 1.3895472
# epoch: 1 step: 1119, loss is 2.1973076
# epoch: 1 step: 1120, loss is 1.7736001
# epoch: 1 step: 1121, loss is 2.295851
# epoch: 1 step: 1122, loss is 1.3388172
# epoch: 1 step: 1123, loss is 1.0257853
# epoch: 1 step: 1124, loss is 2.0527174
# epoch: 1 step: 1125, loss is 1.8834695
# epoch: 1 step: 1126, loss is 2.770579
# epoch: 1 step: 1127, loss is 1.5344111
# epoch: 1 step: 1128, loss is 1.7122024
# epoch: 1 step: 1129, loss is 1.1885473
# epoch: 1 step: 1130, loss is 1.3365824
# epoch: 1 step: 1131, loss is 1.5864005
# epoch: 1 step: 1132, loss is 1.8081659
# epoch: 1 step: 1133, loss is 1.3361638
# epoch: 1 step: 1134, loss is 1.1013336
# epoch: 1 step: 1135, loss is 1.4321166
# epoch: 1 step: 1136, loss is 1.377095
# epoch: 1 step: 1137, loss is 0.8530007
# epoch: 1 step: 1138, loss is 1.5371076
# epoch: 1 step: 1139, loss is 0.8524234
# epoch: 1 step: 1140, loss is 0.974152
# epoch: 1 step: 1141, loss is 2.1531682
# epoch: 1 step: 1142, loss is 1.1552101
# epoch: 1 step: 1143, loss is 2.0993047
# Train epoch time: 512902.577 ms, per step time: 448.734 ms
# CPU times: user 39min 6s, sys: 5min 12s, total: 44min 18s
# Wall time: 8min 45s

# %% [markdown]
# > 因为FCN网络在训练的过程中需要大量的训练数据和训练轮数，这里只提供了小数据单个epoch的训练来演示loss收敛的过程，下文中使用已训练好的权重文件进行模型评估和推理效果的展示。

# %% [markdown]
# ## 模型评估

# %%
IMAGE_MEAN = [103.53, 116.28, 123.675]
IMAGE_STD = [57.375, 57.120, 58.395]
DATA_FILE = "dataset/dataset_fcn8s/mindname.mindrecord"

# 下载已训练好的权重文件
url = "https://mindspore-website.obs.cn-north-4.myhuaweicloud.com/notebook/datasets/FCN8s.ckpt"
download(url, "FCN8s.ckpt", replace=True)
net = FCN8s(n_class=num_classes)

ckpt_file = "FCN8s.ckpt"
param_dict = load_checkpoint(ckpt_file)
load_param_into_net(net, param_dict)

if device_target == "Ascend":
    model = Model(net, loss_fn=loss, optimizer=optimizer, loss_scale_manager=loss_scale_manager, metrics={"pixel accuracy": PixelAccuracy(), "mean pixel accuracy": PixelAccuracyClass(), "mean IoU": MeanIntersectionOverUnion(), "frequency weighted IoU": FrequencyWeightedIntersectionOverUnion()})
else:
    model = Model(net, loss_fn=loss, optimizer=optimizer, metrics={"pixel accuracy": PixelAccuracy(), "mean pixel accuracy": PixelAccuracyClass(), "mean IoU": MeanIntersectionOverUnion(), "frequency weighted IoU": FrequencyWeightedIntersectionOverUnion()})

# 实例化Dataset
dataset = SegDataset(image_mean=IMAGE_MEAN,
                     image_std=IMAGE_STD,
                     data_file=DATA_FILE,
                     batch_size=train_batch_size,
                     crop_size=crop_size,
                     max_scale=max_scale,
                     min_scale=min_scale,
                     ignore_label=ignore_label,
                     num_classes=num_classes,
                     num_readers=2,
                     num_parallel_calls=4)
dataset_eval = dataset.get_dataset()
model.eval(dataset_eval)
# Out:
# Downloading data from https://mindspore-website.obs.cn-north-4.myhuaweicloud.com/notebook/datasets/FCN8s.ckpt (1.00 GB)
#
# file_sizes: 100%|███████████████████████████| 1.08G/1.08G [00:04<00:00, 233MB/s]
# Successfully downloaded file to FCN8s.ckpt
# .
# {'pixel accuracy': 0.9730130611531161,
#  'mean pixel accuracy': 0.9411324489749456,
#  'mean IoU': 0.8934207872363524,
#  'frequency weighted IoU': 0.9480086377542214}

# %% [markdown]
# ## 模型推理
#
# 使用训练的网络对模型推理结果进行展示。

# %%
import cv2
import matplotlib.pyplot as plt

net = FCN8s(n_class=num_classes)
# 设置超参
ckpt_file = "FCN8s.ckpt"
param_dict = load_checkpoint(ckpt_file)
load_param_into_net(net, param_dict)
eval_batch_size = 4
img_lst = []
mask_lst = []
res_lst = []
# 推理效果展示(上方为输入图片，下方为推理效果图片)
plt.figure(figsize=(8, 5))
show_data = next(dataset_eval.create_dict_iterator())
show_images = show_data["data"].asnumpy()
mask_images = show_data["label"].reshape([4, 512, 512])
show_images = np.clip(show_images, 0, 1)
for i in range(eval_batch_size):
    img_lst.append(show_images[i])
    mask_lst.append(mask_images[i])
res = net(show_data["data"]).asnumpy().argmax(axis=1)
for i in range(eval_batch_size):
    plt.subplot(2, 4, i + 1)
    plt.imshow(img_lst[i].transpose(1, 2, 0))
    plt.axis("off")
    plt.subplots_adjust(wspace=0.05, hspace=0.02)
    plt.subplot(2, 4, i + 5)
    plt.imshow(res[i])
    plt.axis("off")
    plt.subplots_adjust(wspace=0.05, hspace=0.02)
plt.show()

# %% [markdown]
# ## 总结
#
# FCN的核心贡献在于提出使用全卷积层，通过学习让图片实现端到端分割。与传统使用CNN进行图像分割的方法相比，FCN有两大明显的优点：一是可以接受任意大小的输入图像，无需要求所有的训练图像和测试图像具有固定的尺寸。二是更加高效，避免了由于使用像素块而带来的重复存储和计算卷积的问题。
#
# 同时FCN网络也存在待改进之处：
#
# 一是得到的结果仍不够精细。进行8倍上采样虽然比32倍的效果好了很多，但是上采样的结果仍比较模糊和平滑，尤其是边界处，网络对图像中的细节不敏感。
# 二是对各个像素进行分类，没有充分考虑像素与像素之间的关系（如不连续性和相似性）。忽略了在通常的基于像素分类的分割方法中使用的空间规整（spatial regularization）步骤，缺乏空间一致性。
#
# ## 引用
#
# [1]Long, Jonathan, Evan Shelhamer, and Trevor Darrell. "Fully convolutional networks for Semantic Segmentation." Proceedings of the IEEE Conference on Computer Vision and Pattern Recognition. 2015.
