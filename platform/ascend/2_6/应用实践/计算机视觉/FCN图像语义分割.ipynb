# %% [markdown]
# # FCN图像语义分割
#
# 全卷积网络（Fully Convolutional Networks，FCN）是UC Berkeley的Jonathan Long等人于2015年在Fully Convolutional Networks for Semantic Segmentation<sup>[1]</sup>一文中提出的用于图像语义分割的一种框架。
#
# FCN是首个端到端（end to end）进行像素级（pixel level）预测的全卷积网络。
#
# ![fcn-1](https://mindspore-website.obs.cn-north-4.myhuaweicloud.com/website-images/r2.6.0rc1/tutorials/source_zh_cn/cv/images/fcn_1.png)
#
# ## 语义分割
#
# 在具体介绍FCN之前，首先介绍何为语义分割：
#
# 图像语义分割（semantic segmentation）是图像处理和机器视觉技术中关于图像理解的重要一环，AI领域中一个重要分支，常被应用于人脸识别、物体检测、医学影像、卫星图像分析、自动驾驶感知等领域。
#
# 语义分割的目的是对图像中每个像素点进行分类。与普通的分类任务只输出某个类别不同，语义分割任务输出与输入大小相同的图像，输出图像的每个像素对应了输入图像每个像素的类别。语义在图像领域指的是图像的内容，对图片意思的理解，下图是一些语义分割的实例：
#
# ![fcn-2](https://mindspore-website.obs.cn-north-4.myhuaweicloud.com/website-images/r2.6.0rc1/tutorials/source_zh_cn/cv/images/fcn_2.png)
#
# ## 模型简介
#
# FCN主要用于图像分割领域，是一种端到端的分割方法，是深度学习应用在图像语义分割的开山之作。通过进行像素级的预测直接得出与原图大小相等的label map。因FCN丢弃全连接层替换为全卷积层，网络所有层均为卷积层，故称为全卷积网络。
#
# 全卷积神经网络主要使用以下三种技术：
#
# 1. 卷积化（Convolutional）
#
#     使用VGG-16作为FCN的backbone。VGG-16的输入为224*224的RGB图像，输出为1000个预测值。VGG-16只能接受固定大小的输入，丢弃了空间坐标，产生非空间输出。VGG-16中共有三个全连接层，全连接层也可视为带有覆盖整个区域的卷积。将全连接层转换为卷积层能使网络输出由一维非空间输出变为二维矩阵，利用输出能生成输入图片映射的heatmap。
#
#    ![fcn-3](https://mindspore-website.obs.cn-north-4.myhuaweicloud.com/website-images/r2.6.0rc1/tutorials/source_zh_cn/cv/images/fcn_3.png)
#
# 2. 上采样（Upsample）
#
#     在卷积过程的卷积操作和池化操作会使得特征图的尺寸变小，为得到原图的大小的稠密图像预测，需要对得到的特征图进行上采样操作。使用双线性插值的参数来初始化上采样逆卷积的参数，后通过反向传播来学习非线性上采样。在网络中执行上采样，以通过像素损失的反向传播进行端到端的学习。
#
#     ![fcn-4](https://mindspore-website.obs.cn-north-4.myhuaweicloud.com/website-images/r2.6.0rc1/tutorials/source_zh_cn/cv/images/fcn_4.png)
#
# 3. 跳跃结构（Skip Layer）
#
#     利用上采样技巧对最后一层的特征图进行上采样得到原图大小的分割是步长为32像素的预测，称之为FCN-32s。由于最后一层的特征图太小，损失过多细节，采用skips结构将更具有全局信息的最后一层预测和更浅层的预测结合，使预测结果获取更多的局部细节。将底层（stride 32）的预测（FCN-32s）进行2倍的上采样得到原尺寸的图像，并与从pool4层（stride 16）进行的预测融合起来（相加），这一部分的网络被称为FCN-16s。随后将这一部分的预测再进行一次2倍的上采样并与从pool3层得到的预测融合起来，这一部分的网络被称为FCN-8s。 Skips结构将深层的全局信息与浅层的局部信息相结合。
#
#     ![fcn-5](https://mindspore-website.obs.cn-north-4.myhuaweicloud.com/website-images/r2.6.0rc1/tutorials/source_zh_cn/cv/images/fcn_5.png)
#
# ## 网络特点
#
# 1. 不含全连接层(fc)的全卷积(fully conv)网络，可适应任意尺寸输入。
# 2. 增大数据尺寸的反卷积(deconv)层，能够输出精细的结果。
# 3. 结合不同深度层结果的跳级(skip)结构，同时确保鲁棒性和精确性。

# %% [markdown]
# ## 数据处理
#
# 开始实验前，需确保本地已经安装Python环境及MindSpore。

# %%
# %%capture captured_output
# 实验环境已经预装了mindspore==2.6.0rc1，如需更换mindspore版本，可更改下面 MINDSPORE_VERSION 变量
# !pip uninstall mindspore -y
# %env MINDSPORE_VERSION=2.6.0rc1
# !pip install https://ms-release.obs.cn-north-4.myhuaweicloud.com/${MINDSPORE_VERSION}/MindSpore/unified/aarch64/mindspore-${MINDSPORE_VERSION}-cp39-cp39-linux_aarch64.whl --trusted-host ms-release.obs.cn-north-4.myhuaweicloud.com -i https://pypi.tuna.tsinghua.edu.cn/simple

# %%
# 查看当前 mindspore 版本
# !pip show mindspore
# Out:
# Name: mindspore
# Version: 2.6.0rc1
# Summary: MindSpore is a new open source deep learning training/inference framework that could be used for mobile, edge and cloud scenarios.
# Home-page: https://www.mindspore.cn
# Author: The MindSpore Authors
# Author-email: contact@mindspore.cn
# License: Apache 2.0
# Location: /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages
# Requires: asttokens, astunparse, dill, numpy, packaging, pillow, protobuf, psutil, safetensors, scipy
# Required-by:

# %%
from download import download

url = "https://mindspore-website.obs.cn-north-4.myhuaweicloud.com/notebook/datasets/dataset_fcn8s.tar"

download(url, "./dataset", kind="tar", replace=True)
# Out:
# Creating data folder...
# Downloading data from https://mindspore-website.obs.cn-north-4.myhuaweicloud.com/notebook/datasets/dataset_fcn8s.tar (537.2 MB)
#
# file_sizes: 100%|█████████████████████████████| 563M/563M [00:02<00:00, 209MB/s]
# Extracting tar file...
# Successfully downloaded / unzipped to ./dataset
# './dataset'

# %% [markdown]
# ### 数据预处理
#
# 由于PASCAL VOC 2012数据集中图像的分辨率大多不一致，无法放在一个tensor中，故输入前需做标准化处理。

# %% [markdown]
# ### 数据加载
#
# 将PASCAL VOC 2012数据集与SDB数据集进行混合。

# %%
import numpy as np
import cv2
import mindspore.dataset as ds

class SegDataset:
    def __init__(self,
                 image_mean,
                 image_std,
                 data_file='',
                 batch_size=32,
                 crop_size=512,
                 max_scale=2.0,
                 min_scale=0.5,
                 ignore_label=255,
                 num_classes=21,
                 num_readers=2,
                 num_parallel_calls=4):

        self.data_file = data_file
        self.batch_size = batch_size
        self.crop_size = crop_size
        self.image_mean = np.array(image_mean, dtype=np.float32)
        self.image_std = np.array(image_std, dtype=np.float32)
        self.max_scale = max_scale
        self.min_scale = min_scale
        self.ignore_label = ignore_label
        self.num_classes = num_classes
        self.num_readers = num_readers
        self.num_parallel_calls = num_parallel_calls
        max_scale > min_scale

    def preprocess_dataset(self, image, label):
        image_out = cv2.imdecode(np.frombuffer(image, dtype=np.uint8), cv2.IMREAD_COLOR)
        label_out = cv2.imdecode(np.frombuffer(label, dtype=np.uint8), cv2.IMREAD_GRAYSCALE)
        sc = np.random.uniform(self.min_scale, self.max_scale)
        new_h, new_w = int(sc * image_out.shape[0]), int(sc * image_out.shape[1])
        image_out = cv2.resize(image_out, (new_w, new_h), interpolation=cv2.INTER_CUBIC)
        label_out = cv2.resize(label_out, (new_w, new_h), interpolation=cv2.INTER_NEAREST)

        image_out = (image_out - self.image_mean) / self.image_std
        out_h, out_w = max(new_h, self.crop_size), max(new_w, self.crop_size)
        pad_h, pad_w = out_h - new_h, out_w - new_w
        if pad_h > 0 or pad_w > 0:
            image_out = cv2.copyMakeBorder(image_out, 0, pad_h, 0, pad_w, cv2.BORDER_CONSTANT, value=0)
            label_out = cv2.copyMakeBorder(label_out, 0, pad_h, 0, pad_w, cv2.BORDER_CONSTANT, value=self.ignore_label)
        offset_h = np.random.randint(0, out_h - self.crop_size + 1)
        offset_w = np.random.randint(0, out_w - self.crop_size + 1)
        image_out = image_out[offset_h: offset_h + self.crop_size, offset_w: offset_w + self.crop_size, :]
        label_out = label_out[offset_h: offset_h + self.crop_size, offset_w: offset_w+self.crop_size]
        if np.random.uniform(0.0, 1.0) > 0.5:
            image_out = image_out[:, ::-1, :]
            label_out = label_out[:, ::-1]
        image_out = image_out.transpose((2, 0, 1))
        image_out = image_out.copy()
        label_out = label_out.copy()
        label_out = label_out.astype("int32")
        return image_out, label_out

    def get_dataset(self):
        ds.config.set_numa_enable(True)
        dataset = ds.MindDataset(self.data_file, columns_list=["data", "label"],
                                 shuffle=True, num_parallel_workers=self.num_readers)
        transforms_list = self.preprocess_dataset
        dataset = dataset.map(operations=transforms_list, input_columns=["data", "label"],
                              output_columns=["data", "label"],
                              num_parallel_workers=self.num_parallel_calls)
        dataset = dataset.shuffle(buffer_size=self.batch_size * 10)
        dataset = dataset.batch(self.batch_size, drop_remainder=True)
        return dataset


# 定义创建数据集的参数
IMAGE_MEAN = [103.53, 116.28, 123.675]
IMAGE_STD = [57.375, 57.120, 58.395]
DATA_FILE = "dataset/dataset_fcn8s/mindname.mindrecord"

# 定义模型训练参数
train_batch_size = 4
crop_size = 512
min_scale = 0.5
max_scale = 2.0
ignore_label = 255
num_classes = 21

# 实例化Dataset
dataset = SegDataset(image_mean=IMAGE_MEAN,
                     image_std=IMAGE_STD,
                     data_file=DATA_FILE,
                     batch_size=train_batch_size,
                     crop_size=crop_size,
                     max_scale=max_scale,
                     min_scale=min_scale,
                     ignore_label=ignore_label,
                     num_classes=num_classes,
                     num_readers=2,
                     num_parallel_calls=4)

dataset = dataset.get_dataset()
# Out:
# /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages/numpy/core/getlimits.py:549: UserWarning: The value of the smallest subnormal for <class 'numpy.float64'> type is zero.
#   setattr(self, word, getattr(machar, word).flat[0])
# /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages/numpy/core/getlimits.py:89: UserWarning: The value of the smallest subnormal for <class 'numpy.float64'> type is zero.
#   return self._float_to_str(self.smallest_subnormal)
# /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages/numpy/core/getlimits.py:549: UserWarning: The value of the smallest subnormal for <class 'numpy.float32'> type is zero.
#   setattr(self, word, getattr(machar, word).flat[0])
# /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages/numpy/core/getlimits.py:89: UserWarning: The value of the smallest subnormal for <class 'numpy.float32'> type is zero.
#   return self._float_to_str(self.smallest_subnormal)

# %% [markdown]
# ### 训练集可视化
#
# 运行以下代码观察载入的数据集图片（数据处理过程中已做归一化处理）。

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(16, 8))

# 对训练集中的数据进行展示
for i in range(1, 9):
    plt.subplot(2, 4, i)
    show_data = next(dataset.create_dict_iterator())
    show_images = show_data["data"].asnumpy()
    show_images = np.clip(show_images, 0, 1)
# 将图片转换HWC格式后进行展示
    plt.imshow(show_images[0].transpose(1, 2, 0))
    plt.axis("off")
    plt.subplots_adjust(wspace=0.05, hspace=0)
plt.show()

# %% [markdown]
# ## 网络构建
#
# ### 网络流程
#
# FCN网络的流程如下图所示：
#
# 1. 输入图像image，经过pool1池化后，尺寸变为原始尺寸的1/2。
# 2. 经过pool2池化，尺寸变为原始尺寸的1/4。
# 3. 接着经过pool3、pool4、pool5池化，大小分别变为原始尺寸的1/8、1/16、1/32。
# 4. 经过conv6-7卷积，输出的尺寸依然是原图的1/32。
# 5. FCN-32s是最后使用反卷积，使得输出图像大小与输入图像相同。
# 6. FCN-16s是将conv7的输出进行反卷积，使其尺寸扩大两倍至原图的1/16，并将其与pool4输出的特征图进行融合，后通过反卷积扩大到原始尺寸。
# 7. FCN-8s是将conv7的输出进行反卷积扩大4倍，将pool4输出的特征图反卷积扩大2倍，并将pool3输出特征图拿出，三者融合后通反卷积扩大到原始尺寸。
#
# ![fcn-6](https://mindspore-website.obs.cn-north-4.myhuaweicloud.com/website-images/r2.6.0rc1/tutorials/source_zh_cn/cv/images/fcn_6.png)
#
# 使用以下代码构建FCN-8s网络。

# %%
import mindspore.nn as nn

class FCN8s(nn.Cell):
    def __init__(self, n_class):
        super().__init__()
        self.n_class = n_class
        self.conv1 = nn.SequentialCell(
            nn.Conv2d(in_channels=3, out_channels=64,
                      kernel_size=3, weight_init='xavier_uniform'),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.Conv2d(in_channels=64, out_channels=64,
                      kernel_size=3, weight_init='xavier_uniform'),
            nn.BatchNorm2d(64),
            nn.ReLU()
        )
        self.pool1 = nn.MaxPool2d(kernel_size=2, stride=2)
        self.conv2 = nn.SequentialCell(
            nn.Conv2d(in_channels=64, out_channels=128,
                      kernel_size=3, weight_init='xavier_uniform'),
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.Conv2d(in_channels=128, out_channels=128,
                      kernel_size=3, weight_init='xavier_uniform'),
            nn.BatchNorm2d(128),
            nn.ReLU()
        )
        self.pool2 = nn.MaxPool2d(kernel_size=2, stride=2)
        self.conv3 = nn.SequentialCell(
            nn.Conv2d(in_channels=128, out_channels=256,
                      kernel_size=3, weight_init='xavier_uniform'),
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.Conv2d(in_channels=256, out_channels=256,
                      kernel_size=3, weight_init='xavier_uniform'),
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.Conv2d(in_channels=256, out_channels=256,
                      kernel_size=3, weight_init='xavier_uniform'),
            nn.BatchNorm2d(256),
            nn.ReLU()
        )
        self.pool3 = nn.MaxPool2d(kernel_size=2, stride=2)
        self.conv4 = nn.SequentialCell(
            nn.Conv2d(in_channels=256, out_channels=512,
                      kernel_size=3, weight_init='xavier_uniform'),
            nn.BatchNorm2d(512),
            nn.ReLU(),
            nn.Conv2d(in_channels=512, out_channels=512,
                      kernel_size=3, weight_init='xavier_uniform'),
            nn.BatchNorm2d(512),
            nn.ReLU(),
            nn.Conv2d(in_channels=512, out_channels=512,
                      kernel_size=3, weight_init='xavier_uniform'),
            nn.BatchNorm2d(512),
            nn.ReLU()
        )
        self.pool4 = nn.MaxPool2d(kernel_size=2, stride=2)
        self.conv5 = nn.SequentialCell(
            nn.Conv2d(in_channels=512, out_channels=512,
                      kernel_size=3, weight_init='xavier_uniform'),
            nn.BatchNorm2d(512),
            nn.ReLU(),
            nn.Conv2d(in_channels=512, out_channels=512,
                      kernel_size=3, weight_init='xavier_uniform'),
            nn.BatchNorm2d(512),
            nn.ReLU(),
            nn.Conv2d(in_channels=512, out_channels=512,
                      kernel_size=3, weight_init='xavier_uniform'),
            nn.BatchNorm2d(512),
            nn.ReLU()
        )
        self.pool5 = nn.MaxPool2d(kernel_size=2, stride=2)
        self.conv6 = nn.SequentialCell(
            nn.Conv2d(in_channels=512, out_channels=4096,
                      kernel_size=7, weight_init='xavier_uniform'),
            nn.BatchNorm2d(4096),
            nn.ReLU(),
        )
        self.conv7 = nn.SequentialCell(
            nn.Conv2d(in_channels=4096, out_channels=4096,
                      kernel_size=1, weight_init='xavier_uniform'),
            nn.BatchNorm2d(4096),
            nn.ReLU(),
        )
        self.score_fr = nn.Conv2d(in_channels=4096, out_channels=self.n_class,
                                  kernel_size=1, weight_init='xavier_uniform')
        self.upscore2 = nn.Conv2dTranspose(in_channels=self.n_class, out_channels=self.n_class,
                                           kernel_size=4, stride=2, weight_init='xavier_uniform')
        self.score_pool4 = nn.Conv2d(in_channels=512, out_channels=self.n_class,
                                     kernel_size=1, weight_init='xavier_uniform')
        self.upscore_pool4 = nn.Conv2dTranspose(in_channels=self.n_class, out_channels=self.n_class,
                                                kernel_size=4, stride=2, weight_init='xavier_uniform')
        self.score_pool3 = nn.Conv2d(in_channels=256, out_channels=self.n_class,
                                     kernel_size=1, weight_init='xavier_uniform')
        self.upscore8 = nn.Conv2dTranspose(in_channels=self.n_class, out_channels=self.n_class,
                                           kernel_size=16, stride=8, weight_init='xavier_uniform')

    def construct(self, x):
        x1 = self.conv1(x)
        p1 = self.pool1(x1)
        x2 = self.conv2(p1)
        p2 = self.pool2(x2)
        x3 = self.conv3(p2)
        p3 = self.pool3(x3)
        x4 = self.conv4(p3)
        p4 = self.pool4(x4)
        x5 = self.conv5(p4)
        p5 = self.pool5(x5)
        x6 = self.conv6(p5)
        x7 = self.conv7(x6)
        sf = self.score_fr(x7)
        u2 = self.upscore2(sf)
        s4 = self.score_pool4(p4)
        f4 = s4 + u2
        u4 = self.upscore_pool4(f4)
        s3 = self.score_pool3(p3)
        f3 = s3 + u4
        out = self.upscore8(f3)
        return out

# %% [markdown]
# ## 训练准备
#
# ### 导入VGG-16部分预训练权重
#
# FCN使用VGG-16作为骨干网络，用于实现图像编码。使用下面代码导入VGG-16预训练模型的部分预训练权重。

# %%
from download import download
from mindspore import load_checkpoint, load_param_into_net

url = "https://mindspore-website.obs.cn-north-4.myhuaweicloud.com/notebook/datasets/fcn8s_vgg16_pretrain.ckpt"
download(url, "fcn8s_vgg16_pretrain.ckpt", replace=True)
def load_vgg16():
    ckpt_vgg16 = "fcn8s_vgg16_pretrain.ckpt"
    param_vgg = load_checkpoint(ckpt_vgg16)
    load_param_into_net(net, param_vgg)
# Out:
# Downloading data from https://mindspore-website.obs.cn-north-4.myhuaweicloud.com/notebook/datasets/fcn8s_vgg16_pretrain.ckpt (513.2 MB)
#
# file_sizes: 100%|█████████████████████████████| 538M/538M [00:03<00:00, 144MB/s]
# Successfully downloaded file to fcn8s_vgg16_pretrain.ckpt

# %% [markdown]
# ### 损失函数
#
# 语义分割是对图像中每个像素点进行分类，仍是分类问题，故损失函数选择交叉熵损失函数来计算FCN网络输出与mask之间的交叉熵损失。这里我们使用的是mindspore.nn.CrossEntropyLoss()作为损失函数。

# %% [markdown]
# ### 自定义评价指标 Metrics
#
# 这一部分主要对训练出来的模型效果进行评估，为了便于解释，假设如下：共有 $k+1$ 个类（从 $L_0$ 到 $L_k$, 其中包含一个空类或背景）， $p_{i j}$ 表示本属于$i$类但被预测为$j$类的像素数量。即, $p_{i i}$ 表示真正的数量, 而 $p_{i j} p_{j i}$ 则分别被解释为假正和假负, 尽管两者都是假正与假负之和。
#
# - Pixel Accuracy(PA, 像素精度)：这是最简单的度量，为标记正确的像素占总像素的比例。
#
# $$ P A=\frac{\sum_{i=0}^k p_{i i}}{\sum_{i=0}^k \sum_{j=0}^k p_{i j}} $$
#
# - Mean Pixel Accuracy(MPA, 均像素精度)：是PA的一种简单提升，计算每个类内被正确分类像素数的比例，之后求所有类的平均。
#
# $$ M P A=\frac{1}{k+1} \sum_{i=0}^k \frac{p_{i i}}{\sum_{j=0}^k p_{i j}} $$
#
# - Mean Intersection over Union(MloU, 均交并比)：为语义分割的标准度量。其计算两个集合的交集和并集之，在语义分割的问题中，这两个集合为真实值（ground truth) 和预测值（predicted segmentation）。这个比例可以变形为正真数 (intersection) 比上真正、假负、假正（并集）之和。在每个类上计算loU，之后平均。
#
# $$ M I o U=\frac{1}{k+1} \sum_{i=0}^k \frac{p_{i i}}{\sum_{j=0}^k p_{i j}+\sum_{j=0}^k p_{j i}-p_{i i}} $$
#
# - Frequency Weighted Intersection over Union(FWIoU, 频权交井比)：为MloU的一种提升，这种方法根据每个类出现的频率为其设置权重。
#
# $$ F W I o U=\frac{1}{\sum_{i=0}^k \sum_{j=0}^k p_{i j}} \sum_{i=0}^k \frac{p_{i i}}{\sum_{j=0}^k p_{i j}+\sum_{j=0}^k p_{j i}-p_{i i}} $$

# %%
import numpy as np
import mindspore as ms
import mindspore.nn as nn
import mindspore.train as train

class PixelAccuracy(train.Metric):
    def __init__(self, num_class=21):
        super(PixelAccuracy, self).__init__()
        self.num_class = num_class

    def _generate_matrix(self, gt_image, pre_image):
        mask = (gt_image >= 0) & (gt_image < self.num_class)
        label = self.num_class * gt_image[mask].astype('int') + pre_image[mask]
        count = np.bincount(label, minlength=self.num_class**2)
        confusion_matrix = count.reshape(self.num_class, self.num_class)
        return confusion_matrix

    def clear(self):
        self.confusion_matrix = np.zeros((self.num_class,) * 2)

    def update(self, *inputs):
        y_pred = inputs[0].asnumpy().argmax(axis=1)
        y = inputs[1].asnumpy().reshape(4, 512, 512)
        self.confusion_matrix += self._generate_matrix(y, y_pred)

    def eval(self):
        pixel_accuracy = np.diag(self.confusion_matrix).sum() / self.confusion_matrix.sum()
        return pixel_accuracy


class PixelAccuracyClass(train.Metric):
    def __init__(self, num_class=21):
        super(PixelAccuracyClass, self).__init__()
        self.num_class = num_class

    def _generate_matrix(self, gt_image, pre_image):
        mask = (gt_image >= 0) & (gt_image < self.num_class)
        label = self.num_class * gt_image[mask].astype('int') + pre_image[mask]
        count = np.bincount(label, minlength=self.num_class**2)
        confusion_matrix = count.reshape(self.num_class, self.num_class)
        return confusion_matrix

    def update(self, *inputs):
        y_pred = inputs[0].asnumpy().argmax(axis=1)
        y = inputs[1].asnumpy().reshape(4, 512, 512)
        self.confusion_matrix += self._generate_matrix(y, y_pred)

    def clear(self):
        self.confusion_matrix = np.zeros((self.num_class,) * 2)

    def eval(self):
        mean_pixel_accuracy = np.diag(self.confusion_matrix) / self.confusion_matrix.sum(axis=1)
        mean_pixel_accuracy = np.nanmean(mean_pixel_accuracy)
        return mean_pixel_accuracy


class MeanIntersectionOverUnion(train.Metric):
    def __init__(self, num_class=21):
        super(MeanIntersectionOverUnion, self).__init__()
        self.num_class = num_class

    def _generate_matrix(self, gt_image, pre_image):
        mask = (gt_image >= 0) & (gt_image < self.num_class)
        label = self.num_class * gt_image[mask].astype('int') + pre_image[mask]
        count = np.bincount(label, minlength=self.num_class**2)
        confusion_matrix = count.reshape(self.num_class, self.num_class)
        return confusion_matrix

    def update(self, *inputs):
        y_pred = inputs[0].asnumpy().argmax(axis=1)
        y = inputs[1].asnumpy().reshape(4, 512, 512)
        self.confusion_matrix += self._generate_matrix(y, y_pred)

    def clear(self):
        self.confusion_matrix = np.zeros((self.num_class,) * 2)

    def eval(self):
        mean_iou = np.diag(self.confusion_matrix) / (
            np.sum(self.confusion_matrix, axis=1) + np.sum(self.confusion_matrix, axis=0) -
            np.diag(self.confusion_matrix))
        mean_iou = np.nanmean(mean_iou)
        return mean_iou


class FrequencyWeightedIntersectionOverUnion(train.Metric):
    def __init__(self, num_class=21):
        super(FrequencyWeightedIntersectionOverUnion, self).__init__()
        self.num_class = num_class

    def _generate_matrix(self, gt_image, pre_image):
        mask = (gt_image >= 0) & (gt_image < self.num_class)
        label = self.num_class * gt_image[mask].astype('int') + pre_image[mask]
        count = np.bincount(label, minlength=self.num_class**2)
        confusion_matrix = count.reshape(self.num_class, self.num_class)
        return confusion_matrix

    def update(self, *inputs):
        y_pred = inputs[0].asnumpy().argmax(axis=1)
        y = inputs[1].asnumpy().reshape(4, 512, 512)
        self.confusion_matrix += self._generate_matrix(y, y_pred)

    def clear(self):
        self.confusion_matrix = np.zeros((self.num_class,) * 2)

    def eval(self):
        freq = np.sum(self.confusion_matrix, axis=1) / np.sum(self.confusion_matrix)
        iu = np.diag(self.confusion_matrix) / (
            np.sum(self.confusion_matrix, axis=1) + np.sum(self.confusion_matrix, axis=0) -
            np.diag(self.confusion_matrix))

        frequency_weighted_iou = (freq[freq > 0] * iu[freq > 0]).sum()
        return frequency_weighted_iou

# %% [markdown]
# ## 模型训练
#
# 导入VGG-16预训练参数后，实例化损失函数、优化器，使用Model接口编译网络，训练FCN-8s网络。

# %%
# %%time
import mindspore
from mindspore import Tensor
import mindspore.nn as nn
from mindspore.train import ModelCheckpoint, CheckpointConfig, LossMonitor, TimeMonitor, Model

train_batch_size = 4
num_classes = 21
# 初始化模型结构
net = FCN8s(n_class=21)
# 导入vgg16预训练参数
load_vgg16()
# 计算学习率
min_lr = 0.0005
base_lr = 0.05
train_epochs = 1
iters_per_epoch = dataset.get_dataset_size()
total_step = iters_per_epoch * train_epochs

lr_scheduler = mindspore.nn.cosine_decay_lr(min_lr,
                                            base_lr,
                                            total_step,
                                            iters_per_epoch,
                                            decay_epoch=2)
lr = Tensor(lr_scheduler[-1])

# 定义损失函数
loss = nn.CrossEntropyLoss(ignore_index=255)
# 定义优化器
optimizer = nn.Momentum(params=net.trainable_params(), learning_rate=lr, momentum=0.9, weight_decay=0.0001)
# 定义loss_scale
scale_factor = 4
scale_window = 3000
loss_scale_manager = ms.amp.DynamicLossScaleManager(scale_factor, scale_window)
# 初始化模型
model = Model(net, loss_fn=loss, optimizer=optimizer, loss_scale_manager=loss_scale_manager, metrics={"pixel accuracy": PixelAccuracy(), "mean pixel accuracy": PixelAccuracyClass(), "mean IoU": MeanIntersectionOverUnion(), "frequency weighted IoU": FrequencyWeightedIntersectionOverUnion()})

# 设置ckpt文件保存的参数
time_callback = TimeMonitor(data_size=iters_per_epoch)
loss_callback = LossMonitor()
callbacks = [time_callback, loss_callback]
save_steps = 330
keep_checkpoint_max = 5
config_ckpt = CheckpointConfig(save_checkpoint_steps=10,
                               keep_checkpoint_max=keep_checkpoint_max)
ckpt_callback = ModelCheckpoint(prefix="FCN8s",
                                directory="./ckpt",
                                config=config_ckpt)
callbacks.append(ckpt_callback)
model.train(train_epochs, dataset, callbacks=callbacks)
# Out:
# ........epoch: 1 step: 1, loss is 3.0639586
# epoch: 1 step: 2, loss is 3.0385919
# epoch: 1 step: 3, loss is 3.0050805
# epoch: 1 step: 4, loss is 2.9249494
# epoch: 1 step: 5, loss is 2.9114347
# epoch: 1 step: 6, loss is 2.7956936
# epoch: 1 step: 7, loss is 2.3535068
# epoch: 1 step: 8, loss is 2.2011006
# epoch: 1 step: 9, loss is 2.0910468
# epoch: 1 step: 10, loss is 1.7680229
# epoch: 1 step: 11, loss is 0.8661309
# epoch: 1 step: 12, loss is 2.8358116
# epoch: 1 step: 13, loss is 1.3945665
# epoch: 1 step: 14, loss is 1.0100142
# epoch: 1 step: 15, loss is 1.1516399
# epoch: 1 step: 16, loss is 1.8795301
# epoch: 1 step: 17, loss is 1.8779986
# epoch: 1 step: 18, loss is 2.5182986
# epoch: 1 step: 19, loss is 1.5238909
# epoch: 1 step: 20, loss is 2.5061657
# epoch: 1 step: 21, loss is 1.6985563
# epoch: 1 step: 22, loss is 1.5799328
# epoch: 1 step: 23, loss is 1.6579473
# epoch: 1 step: 24, loss is 1.9476333
# epoch: 1 step: 25, loss is 1.7488427
# epoch: 1 step: 26, loss is 1.3338234
# epoch: 1 step: 27, loss is 1.9120005
# epoch: 1 step: 28, loss is 1.274393
# epoch: 1 step: 29, loss is 1.7100189
# epoch: 1 step: 30, loss is 1.0353637
# epoch: 1 step: 31, loss is 1.5776377
# epoch: 1 step: 32, loss is 1.444527
# epoch: 1 step: 33, loss is 1.6711609
# epoch: 1 step: 34, loss is 1.0790027
# epoch: 1 step: 35, loss is 1.6401471
# epoch: 1 step: 36, loss is 1.1345323
# epoch: 1 step: 37, loss is 2.2198255
# epoch: 1 step: 38, loss is 1.5684487
# epoch: 1 step: 39, loss is 1.1570073
# epoch: 1 step: 40, loss is 1.0589416
# epoch: 1 step: 41, loss is 1.8273455
# epoch: 1 step: 42, loss is 1.7309109
# epoch: 1 step: 43, loss is 1.5633501
# epoch: 1 step: 44, loss is 1.0158108
# epoch: 1 step: 45, loss is 1.7061067
# epoch: 1 step: 46, loss is 2.3513188
# epoch: 1 step: 47, loss is 1.5822328
# epoch: 1 step: 48, loss is 1.5140635
# epoch: 1 step: 49, loss is 1.1321319
# epoch: 1 step: 50, loss is 1.4692556
# epoch: 1 step: 51, loss is 1.0710384
# epoch: 1 step: 52, loss is 1.4755937
# epoch: 1 step: 53, loss is 3.482217
# epoch: 1 step: 54, loss is 1.3442868
# epoch: 1 step: 55, loss is 1.6351265
# epoch: 1 step: 56, loss is 2.2366407
# epoch: 1 step: 57, loss is 1.1334753
# epoch: 1 step: 58, loss is 1.1413395
# epoch: 1 step: 59, loss is 2.5985174
# epoch: 1 step: 60, loss is 0.8295023
# epoch: 1 step: 61, loss is 1.6933104
# epoch: 1 step: 62, loss is 1.986222
# epoch: 1 step: 63, loss is 1.2620974
# epoch: 1 step: 64, loss is 1.3752466
# epoch: 1 step: 65, loss is 2.5412636
# epoch: 1 step: 66, loss is 0.77343524
# epoch: 1 step: 67, loss is 0.98402107
# epoch: 1 step: 68, loss is 1.2156929
# epoch: 1 step: 69, loss is 1.3654445
# epoch: 1 step: 70, loss is 1.5907439
# epoch: 1 step: 71, loss is 1.3455143
# epoch: 1 step: 72, loss is 2.1308904
# epoch: 1 step: 73, loss is 1.810645
# epoch: 1 step: 74, loss is 1.8514365
# epoch: 1 step: 75, loss is 1.9072146
# epoch: 1 step: 76, loss is 1.5144925
# epoch: 1 step: 77, loss is 2.071519
# epoch: 1 step: 78, loss is 2.2925746
# epoch: 1 step: 79, loss is 1.5808254
# epoch: 1 step: 80, loss is 1.8526943
# epoch: 1 step: 81, loss is 1.1752613
# epoch: 1 step: 82, loss is 1.5883602
# epoch: 1 step: 83, loss is 1.8034275
# epoch: 1 step: 84, loss is 1.0107725
# epoch: 1 step: 85, loss is 1.0256699
# epoch: 1 step: 86, loss is 1.2857723
# epoch: 1 step: 87, loss is 1.6729571
# epoch: 1 step: 88, loss is 2.2756014
# epoch: 1 step: 89, loss is 1.9528983
# epoch: 1 step: 90, loss is 1.8349342
# epoch: 1 step: 91, loss is 2.3621619
# epoch: 1 step: 92, loss is 1.3115444
# epoch: 1 step: 93, loss is 2.3634949
# epoch: 1 step: 94, loss is 2.014733
# epoch: 1 step: 95, loss is 1.8300439
# epoch: 1 step: 96, loss is 1.4423242
# epoch: 1 step: 97, loss is 1.5299033
# epoch: 1 step: 98, loss is 1.9644634
# epoch: 1 step: 99, loss is 1.0758202
# epoch: 1 step: 100, loss is 1.9402076
# epoch: 1 step: 101, loss is 1.853385
# epoch: 1 step: 102, loss is 1.481092
# epoch: 1 step: 103, loss is 1.9779595
# epoch: 1 step: 104, loss is 1.1516732
# epoch: 1 step: 105, loss is 1.1052351
# epoch: 1 step: 106, loss is 1.612695
# epoch: 1 step: 107, loss is 1.0532961
# epoch: 1 step: 108, loss is 0.50084805
# epoch: 1 step: 109, loss is 2.1635969
# epoch: 1 step: 110, loss is 1.5133772
# epoch: 1 step: 111, loss is 1.214413
# epoch: 1 step: 112, loss is 1.5107106
# epoch: 1 step: 113, loss is 1.4604146
# epoch: 1 step: 114, loss is 1.1464692
# epoch: 1 step: 115, loss is 0.99135745
# epoch: 1 step: 116, loss is 1.1149349
# epoch: 1 step: 117, loss is 1.2494276
# epoch: 1 step: 118, loss is 1.9137256
# epoch: 1 step: 119, loss is 0.9040972
# epoch: 1 step: 120, loss is 2.2646418
# epoch: 1 step: 121, loss is 0.76560235
# epoch: 1 step: 122, loss is 0.6776868
# epoch: 1 step: 123, loss is 2.0139196
# epoch: 1 step: 124, loss is 1.6538429
# epoch: 1 step: 125, loss is 1.1008254
# epoch: 1 step: 126, loss is 1.6396092
# epoch: 1 step: 127, loss is 1.4467617
# epoch: 1 step: 128, loss is 0.8457339
# epoch: 1 step: 129, loss is 1.4705908
# epoch: 1 step: 130, loss is 1.2930276
# epoch: 1 step: 131, loss is 0.6833824
# epoch: 1 step: 132, loss is 1.2085681
# epoch: 1 step: 133, loss is 1.6214435
# epoch: 1 step: 134, loss is 2.0642273
# epoch: 1 step: 135, loss is 2.048523
# epoch: 1 step: 136, loss is 1.2422255
# epoch: 1 step: 137, loss is 1.224389
# epoch: 1 step: 138, loss is 1.518693
# epoch: 1 step: 139, loss is 1.6123646
# epoch: 1 step: 140, loss is 0.91265714
# epoch: 1 step: 141, loss is 1.6501789
# epoch: 1 step: 142, loss is 1.7767153
# epoch: 1 step: 143, loss is 1.381192
# epoch: 1 step: 144, loss is 1.3530986
# epoch: 1 step: 145, loss is 1.1270112
# epoch: 1 step: 146, loss is 1.1835757
# epoch: 1 step: 147, loss is 2.6545196
# epoch: 1 step: 148, loss is 1.8253742
# epoch: 1 step: 149, loss is 2.1010308
# epoch: 1 step: 150, loss is 1.7227583
# epoch: 1 step: 151, loss is 0.97896093
# epoch: 1 step: 152, loss is 2.3186138
# epoch: 1 step: 153, loss is 1.2486094
# epoch: 1 step: 154, loss is 1.870822
# epoch: 1 step: 155, loss is 2.1176157
# epoch: 1 step: 156, loss is 1.5793015
# epoch: 1 step: 157, loss is 0.8847657
# epoch: 1 step: 158, loss is 1.4947747
# epoch: 1 step: 159, loss is 0.9848789
# epoch: 1 step: 160, loss is 1.7727486
# epoch: 1 step: 161, loss is 1.5430793
# epoch: 1 step: 162, loss is 1.4041288
# epoch: 1 step: 163, loss is 0.9485725
# epoch: 1 step: 164, loss is 1.9595145
# epoch: 1 step: 165, loss is 1.0258368
# epoch: 1 step: 166, loss is 1.9698116
# epoch: 1 step: 167, loss is 1.142238
# epoch: 1 step: 168, loss is 1.1892436
# epoch: 1 step: 169, loss is 1.0406806
# epoch: 1 step: 170, loss is 1.842308
# epoch: 1 step: 171, loss is 1.6913031
# epoch: 1 step: 172, loss is 1.8806354
# epoch: 1 step: 173, loss is 1.533879
# epoch: 1 step: 174, loss is 1.738499
# epoch: 1 step: 175, loss is 1.5715686
# epoch: 1 step: 176, loss is 2.053109
# epoch: 1 step: 177, loss is 1.225802
# epoch: 1 step: 178, loss is 1.687828
# epoch: 1 step: 179, loss is 0.96308047
# epoch: 1 step: 180, loss is 1.4777392
# epoch: 1 step: 181, loss is 2.0228145
# epoch: 1 step: 182, loss is 1.9907736
# epoch: 1 step: 183, loss is 1.4441719
# epoch: 1 step: 184, loss is 1.2654415
# epoch: 1 step: 185, loss is 1.0220566
# epoch: 1 step: 186, loss is 1.1587499
# epoch: 1 step: 187, loss is 1.8389316
# epoch: 1 step: 188, loss is 1.1569667
# epoch: 1 step: 189, loss is 1.4761238
# epoch: 1 step: 190, loss is 1.7845348
# epoch: 1 step: 191, loss is 1.4691664
# epoch: 1 step: 192, loss is 2.2321901
# epoch: 1 step: 193, loss is 1.7721711
# epoch: 1 step: 194, loss is 1.8811777
# epoch: 1 step: 195, loss is 1.8348373
# epoch: 1 step: 196, loss is 1.7705182
# epoch: 1 step: 197, loss is 1.6728431
# epoch: 1 step: 198, loss is 1.986082
# epoch: 1 step: 199, loss is 1.3460464
# epoch: 1 step: 200, loss is 1.623386
# epoch: 1 step: 201, loss is 2.0470774
# epoch: 1 step: 202, loss is 1.5366914
# epoch: 1 step: 203, loss is 0.99238944
# epoch: 1 step: 204, loss is 1.0385984
# epoch: 1 step: 205, loss is 1.1085275
# epoch: 1 step: 206, loss is 1.7048686
# epoch: 1 step: 207, loss is 2.2052782
# epoch: 1 step: 208, loss is 2.042808
# epoch: 1 step: 209, loss is 0.96519613
# epoch: 1 step: 210, loss is 0.88033074
# epoch: 1 step: 211, loss is 1.0603122
# epoch: 1 step: 212, loss is 0.9015497
# epoch: 1 step: 213, loss is 1.9912344
# epoch: 1 step: 214, loss is 1.2005711
# epoch: 1 step: 215, loss is 1.7295654
# epoch: 1 step: 216, loss is 1.1948572
# epoch: 1 step: 217, loss is 0.9608404
# epoch: 1 step: 218, loss is 0.91353977
# epoch: 1 step: 219, loss is 1.0508891
# epoch: 1 step: 220, loss is 1.496378
# epoch: 1 step: 221, loss is 1.2808322
# epoch: 1 step: 222, loss is 1.574791
# epoch: 1 step: 223, loss is 1.2372149
# epoch: 1 step: 224, loss is 1.7390332
# epoch: 1 step: 225, loss is 0.8006405
# epoch: 1 step: 226, loss is 1.1131142
# epoch: 1 step: 227, loss is 1.1750575
# epoch: 1 step: 228, loss is 2.1940215
# epoch: 1 step: 229, loss is 1.3885632
# epoch: 1 step: 230, loss is 1.2032317
# epoch: 1 step: 231, loss is 1.2516733
# epoch: 1 step: 232, loss is 0.8720511
# epoch: 1 step: 233, loss is 2.991262
# epoch: 1 step: 234, loss is 1.3620164
# epoch: 1 step: 235, loss is 1.1895462
# epoch: 1 step: 236, loss is 1.4281173
# epoch: 1 step: 237, loss is 1.3559833
# epoch: 1 step: 238, loss is 2.2432692
# epoch: 1 step: 239, loss is 2.198434
# epoch: 1 step: 240, loss is 1.7835146
# epoch: 1 step: 241, loss is 1.6326944
# epoch: 1 step: 242, loss is 1.8153479
# epoch: 1 step: 243, loss is 1.4994669
# epoch: 1 step: 244, loss is 1.7025224
# epoch: 1 step: 245, loss is 1.4273323
# epoch: 1 step: 246, loss is 1.1301339
# epoch: 1 step: 247, loss is 1.635269
# epoch: 1 step: 248, loss is 1.9757528
# epoch: 1 step: 249, loss is 1.0872034
# epoch: 1 step: 250, loss is 1.5600394
# epoch: 1 step: 251, loss is 3.3604698
# epoch: 1 step: 252, loss is 1.346629
# epoch: 1 step: 253, loss is 2.4956026
# epoch: 1 step: 254, loss is 1.7564704
# epoch: 1 step: 255, loss is 1.060215
# epoch: 1 step: 256, loss is 1.1409129
# epoch: 1 step: 257, loss is 1.3428853
# epoch: 1 step: 258, loss is 1.1720247
# epoch: 1 step: 259, loss is 2.2196383
# epoch: 1 step: 260, loss is 1.1700817
# epoch: 1 step: 261, loss is 1.0917579
# epoch: 1 step: 262, loss is 2.014107
# epoch: 1 step: 263, loss is 1.0158908
# epoch: 1 step: 264, loss is 1.1550437
# epoch: 1 step: 265, loss is 1.4864764
# epoch: 1 step: 266, loss is 1.5720918
# epoch: 1 step: 267, loss is 1.60558
# epoch: 1 step: 268, loss is 0.8778412
# epoch: 1 step: 269, loss is 1.8237542
# epoch: 1 step: 270, loss is 1.3945841
# epoch: 1 step: 271, loss is 0.62894
# epoch: 1 step: 272, loss is 1.1281116
# epoch: 1 step: 273, loss is 1.3868622
# epoch: 1 step: 274, loss is 1.5820144
# epoch: 1 step: 275, loss is 1.5819508
# epoch: 1 step: 276, loss is 1.1424904
# epoch: 1 step: 277, loss is 1.5209681
# epoch: 1 step: 278, loss is 1.2088097
# epoch: 1 step: 279, loss is 1.0818598
# epoch: 1 step: 280, loss is 1.2924013
# epoch: 1 step: 281, loss is 0.71182597
# epoch: 1 step: 282, loss is 1.1399317
# epoch: 1 step: 283, loss is 1.8214666
# epoch: 1 step: 284, loss is 1.3328784
# epoch: 1 step: 285, loss is 1.910004
# epoch: 1 step: 286, loss is 2.8511264
# epoch: 1 step: 287, loss is 1.1054866
# epoch: 1 step: 288, loss is 1.0238975
# epoch: 1 step: 289, loss is 1.8538758
# epoch: 1 step: 290, loss is 1.3743501
# epoch: 1 step: 291, loss is 2.7165155
# epoch: 1 step: 292, loss is 1.3520226
# epoch: 1 step: 293, loss is 1.3351023
# epoch: 1 step: 294, loss is 0.7407058
# epoch: 1 step: 295, loss is 1.4575636
# epoch: 1 step: 296, loss is 3.3374028
# epoch: 1 step: 297, loss is 1.1716479
# epoch: 1 step: 298, loss is 1.924317
# epoch: 1 step: 299, loss is 1.166512
# epoch: 1 step: 300, loss is 1.9251935
# epoch: 1 step: 301, loss is 1.6344497
# epoch: 1 step: 302, loss is 1.1865083
# epoch: 1 step: 303, loss is 1.2322799
# epoch: 1 step: 304, loss is 0.94110805
# epoch: 1 step: 305, loss is 1.7380112
# epoch: 1 step: 306, loss is 1.5529999
# epoch: 1 step: 307, loss is 1.5005547
# epoch: 1 step: 308, loss is 1.859476
# epoch: 1 step: 309, loss is 1.0641456
# epoch: 1 step: 310, loss is 0.76987725
# epoch: 1 step: 311, loss is 1.5298777
# epoch: 1 step: 312, loss is 0.87694544
# epoch: 1 step: 313, loss is 1.1480981
# epoch: 1 step: 314, loss is 1.3163607
# epoch: 1 step: 315, loss is 2.057425
# epoch: 1 step: 316, loss is 1.5709745
# epoch: 1 step: 317, loss is 1.2815117
# epoch: 1 step: 318, loss is 1.4716574
# epoch: 1 step: 319, loss is 0.85814196
# epoch: 1 step: 320, loss is 3.2799919
# epoch: 1 step: 321, loss is 2.4954221
# epoch: 1 step: 322, loss is 1.392841
# epoch: 1 step: 323, loss is 1.5270544
# epoch: 1 step: 324, loss is 1.601025
# epoch: 1 step: 325, loss is 1.1075591
# epoch: 1 step: 326, loss is 1.1097919
# epoch: 1 step: 327, loss is 1.5028075
# epoch: 1 step: 328, loss is 1.0516497
# epoch: 1 step: 329, loss is 0.6752512
# epoch: 1 step: 330, loss is 1.5333645
# epoch: 1 step: 331, loss is 1.8413961
# epoch: 1 step: 332, loss is 4.0736284
# epoch: 1 step: 333, loss is 0.9073316
# epoch: 1 step: 334, loss is 1.5667965
# epoch: 1 step: 335, loss is 1.1588794
# epoch: 1 step: 336, loss is 1.8887079
# epoch: 1 step: 337, loss is 1.3922291
# epoch: 1 step: 338, loss is 1.7002525
# epoch: 1 step: 339, loss is 2.5412374
# epoch: 1 step: 340, loss is 1.4146112
# epoch: 1 step: 341, loss is 1.5008485
# epoch: 1 step: 342, loss is 2.3102243
# epoch: 1 step: 343, loss is 1.0155171
# epoch: 1 step: 344, loss is 1.9599069
# epoch: 1 step: 345, loss is 1.0416986
# epoch: 1 step: 346, loss is 1.3512651
# epoch: 1 step: 347, loss is 1.0515598
# epoch: 1 step: 348, loss is 1.6143517
# epoch: 1 step: 349, loss is 0.8716878
# epoch: 1 step: 350, loss is 1.2412044
# epoch: 1 step: 351, loss is 1.1820236
# epoch: 1 step: 352, loss is 1.5509969
# epoch: 1 step: 353, loss is 1.446329
# epoch: 1 step: 354, loss is 1.4625485
# epoch: 1 step: 355, loss is 0.8322699
# epoch: 1 step: 356, loss is 1.7641579
# epoch: 1 step: 357, loss is 1.7968909
# epoch: 1 step: 358, loss is 1.4201084
# epoch: 1 step: 359, loss is 1.129017
# epoch: 1 step: 360, loss is 1.5925441
# epoch: 1 step: 361, loss is 1.5154024
# epoch: 1 step: 362, loss is 0.8125419
# epoch: 1 step: 363, loss is 2.4520028
# epoch: 1 step: 364, loss is 2.1557474
# epoch: 1 step: 365, loss is 1.2782216
# epoch: 1 step: 366, loss is 0.995209
# epoch: 1 step: 367, loss is 1.8933544
# epoch: 1 step: 368, loss is 1.0768635
# epoch: 1 step: 369, loss is 0.6680992
# epoch: 1 step: 370, loss is 1.6239388
# epoch: 1 step: 371, loss is 1.453488
# epoch: 1 step: 372, loss is 1.5467377
# epoch: 1 step: 373, loss is 1.6143969
# epoch: 1 step: 374, loss is 1.8343879
# epoch: 1 step: 375, loss is 1.1357336
# epoch: 1 step: 376, loss is 0.88183
# epoch: 1 step: 377, loss is 1.0967727
# epoch: 1 step: 378, loss is 2.0982394
# epoch: 1 step: 379, loss is 1.0788997
# epoch: 1 step: 380, loss is 0.96746385
# epoch: 1 step: 381, loss is 1.9060831
# epoch: 1 step: 382, loss is 2.140119
# epoch: 1 step: 383, loss is 2.0709226
# epoch: 1 step: 384, loss is 1.2513496
# epoch: 1 step: 385, loss is 1.1691098
# epoch: 1 step: 386, loss is 1.2745459
# epoch: 1 step: 387, loss is 0.99254
# epoch: 1 step: 388, loss is 1.2991987
# epoch: 1 step: 389, loss is 1.7358146
# epoch: 1 step: 390, loss is 1.2424428
# epoch: 1 step: 391, loss is 1.757353
# epoch: 1 step: 392, loss is 2.4803631
# epoch: 1 step: 393, loss is 1.2653353
# epoch: 1 step: 394, loss is 1.3030022
# epoch: 1 step: 395, loss is 1.2226534
# epoch: 1 step: 396, loss is 2.738407
# epoch: 1 step: 397, loss is 1.1538633
# epoch: 1 step: 398, loss is 1.4747616
# epoch: 1 step: 399, loss is 1.4582112
# epoch: 1 step: 400, loss is 2.6459055
# epoch: 1 step: 401, loss is 1.3775721
# epoch: 1 step: 402, loss is 1.6163694
# epoch: 1 step: 403, loss is 1.2549276
# epoch: 1 step: 404, loss is 1.2030731
# epoch: 1 step: 405, loss is 1.2938997
# epoch: 1 step: 406, loss is 2.0053518
# epoch: 1 step: 407, loss is 2.4769034
# epoch: 1 step: 408, loss is 2.8676896
# epoch: 1 step: 409, loss is 1.0206344
# epoch: 1 step: 410, loss is 1.3351555
# epoch: 1 step: 411, loss is 1.532044
# epoch: 1 step: 412, loss is 1.5674883
# epoch: 1 step: 413, loss is 1.389395
# epoch: 1 step: 414, loss is 1.704294
# epoch: 1 step: 415, loss is 1.3903817
# epoch: 1 step: 416, loss is 1.2217487
# epoch: 1 step: 417, loss is 1.1005639
# epoch: 1 step: 418, loss is 2.0474021
# epoch: 1 step: 419, loss is 2.192687
# epoch: 1 step: 420, loss is 3.0743713
# epoch: 1 step: 421, loss is 1.1117091
# epoch: 1 step: 422, loss is 1.3644838
# epoch: 1 step: 423, loss is 1.1149124
# epoch: 1 step: 424, loss is 1.253748
# epoch: 1 step: 425, loss is 1.1601342
# epoch: 1 step: 426, loss is 1.3686769
# epoch: 1 step: 427, loss is 1.0539595
# epoch: 1 step: 428, loss is 2.4365857
# epoch: 1 step: 429, loss is 1.8807272
# epoch: 1 step: 430, loss is 1.4735625
# epoch: 1 step: 431, loss is 0.7768449
# epoch: 1 step: 432, loss is 2.1064
# epoch: 1 step: 433, loss is 1.8318429
# epoch: 1 step: 434, loss is 1.0395834
# epoch: 1 step: 435, loss is 2.7567387
# epoch: 1 step: 436, loss is 1.9495667
# epoch: 1 step: 437, loss is 0.9965211
# epoch: 1 step: 438, loss is 1.7295113
# epoch: 1 step: 439, loss is 0.846324
# epoch: 1 step: 440, loss is 2.2085736
# epoch: 1 step: 441, loss is 1.5783478
# epoch: 1 step: 442, loss is 1.8468798
# epoch: 1 step: 443, loss is 2.0527253
# epoch: 1 step: 444, loss is 1.0248163
# epoch: 1 step: 445, loss is 1.5164099
# epoch: 1 step: 446, loss is 2.2396386
# epoch: 1 step: 447, loss is 1.7859194
# epoch: 1 step: 448, loss is 0.8177687
# epoch: 1 step: 449, loss is 1.7000592
# epoch: 1 step: 450, loss is 1.2813011
# epoch: 1 step: 451, loss is 1.182716
# epoch: 1 step: 452, loss is 1.9014207
# epoch: 1 step: 453, loss is 1.5307364
# epoch: 1 step: 454, loss is 1.1773614
# epoch: 1 step: 455, loss is 1.6074537
# epoch: 1 step: 456, loss is 0.89882034
# epoch: 1 step: 457, loss is 1.6989653
# epoch: 1 step: 458, loss is 1.8045076
# epoch: 1 step: 459, loss is 2.0967112
# epoch: 1 step: 460, loss is 1.0828689
# epoch: 1 step: 461, loss is 1.2885429
# epoch: 1 step: 462, loss is 1.8188318
# epoch: 1 step: 463, loss is 1.2802821
# epoch: 1 step: 464, loss is 1.0431775
# epoch: 1 step: 465, loss is 1.2991111
# epoch: 1 step: 466, loss is 1.0030326
# epoch: 1 step: 467, loss is 1.3751906
# epoch: 1 step: 468, loss is 1.9970251
# epoch: 1 step: 469, loss is 1.1686809
# epoch: 1 step: 470, loss is 0.950574
# epoch: 1 step: 471, loss is 2.1509924
# epoch: 1 step: 472, loss is 1.0005985
# epoch: 1 step: 473, loss is 1.5289274
# epoch: 1 step: 474, loss is 1.5124077
# epoch: 1 step: 475, loss is 1.729956
# epoch: 1 step: 476, loss is 1.1073931
# epoch: 1 step: 477, loss is 2.1392703
# epoch: 1 step: 478, loss is 1.4524488
# epoch: 1 step: 479, loss is 0.8675407
# epoch: 1 step: 480, loss is 1.2811638
# epoch: 1 step: 481, loss is 1.031025
# epoch: 1 step: 482, loss is 1.1029696
# epoch: 1 step: 483, loss is 0.7045729
# epoch: 1 step: 484, loss is 1.5370339
# epoch: 1 step: 485, loss is 1.5438846
# epoch: 1 step: 486, loss is 2.2114012
# epoch: 1 step: 487, loss is 1.840688
# epoch: 1 step: 488, loss is 0.9605833
# epoch: 1 step: 489, loss is 1.6703433
# epoch: 1 step: 490, loss is 3.252023
# epoch: 1 step: 491, loss is 1.4111545
# epoch: 1 step: 492, loss is 1.7059903
# epoch: 1 step: 493, loss is 1.6289685
# epoch: 1 step: 494, loss is 2.006728
# epoch: 1 step: 495, loss is 1.4824373
# epoch: 1 step: 496, loss is 2.337525
# epoch: 1 step: 497, loss is 1.3941826
# epoch: 1 step: 498, loss is 1.411692
# epoch: 1 step: 499, loss is 1.3766879
# epoch: 1 step: 500, loss is 1.2266284
# epoch: 1 step: 501, loss is 0.4332476
# epoch: 1 step: 502, loss is 1.5977544
# epoch: 1 step: 503, loss is 0.7507447
# epoch: 1 step: 504, loss is 2.3987882
# epoch: 1 step: 505, loss is 1.8120931
# epoch: 1 step: 506, loss is 1.5108131
# epoch: 1 step: 507, loss is 1.1411626
# epoch: 1 step: 508, loss is 1.9334164
# epoch: 1 step: 509, loss is 1.173221
# epoch: 1 step: 510, loss is 1.3928925
# epoch: 1 step: 511, loss is 1.9263568
# epoch: 1 step: 512, loss is 2.0210788
# epoch: 1 step: 513, loss is 1.4909272
# epoch: 1 step: 514, loss is 1.2658777
# epoch: 1 step: 515, loss is 1.2943034
# epoch: 1 step: 516, loss is 1.8905787
# epoch: 1 step: 517, loss is 1.1703838
# epoch: 1 step: 518, loss is 1.0776762
# epoch: 1 step: 519, loss is 2.0109255
# epoch: 1 step: 520, loss is 1.742516
# epoch: 1 step: 521, loss is 1.0862013
# epoch: 1 step: 522, loss is 1.8674306
# epoch: 1 step: 523, loss is 1.2796845
# epoch: 1 step: 524, loss is 1.5044844
# epoch: 1 step: 525, loss is 3.2551327
# epoch: 1 step: 526, loss is 1.9711459
# epoch: 1 step: 527, loss is 1.2144915
# epoch: 1 step: 528, loss is 1.5631913
# epoch: 1 step: 529, loss is 1.8954436
# epoch: 1 step: 530, loss is 1.4825604
# epoch: 1 step: 531, loss is 1.4592963
# epoch: 1 step: 532, loss is 1.4655006
# epoch: 1 step: 533, loss is 1.0599735
# epoch: 1 step: 534, loss is 1.7935425
# epoch: 1 step: 535, loss is 1.3789175
# epoch: 1 step: 536, loss is 0.7305851
# epoch: 1 step: 537, loss is 1.9457537
# epoch: 1 step: 538, loss is 1.5739028
# epoch: 1 step: 539, loss is 1.5103542
# epoch: 1 step: 540, loss is 1.2638865
# epoch: 1 step: 541, loss is 1.5976921
# epoch: 1 step: 542, loss is 1.5953169
# epoch: 1 step: 543, loss is 1.4511932
# epoch: 1 step: 544, loss is 0.9295845
# epoch: 1 step: 545, loss is 1.9443969
# epoch: 1 step: 546, loss is 1.8524746
# epoch: 1 step: 547, loss is 1.2416089
# epoch: 1 step: 548, loss is 1.1856998
# epoch: 1 step: 549, loss is 1.9517869
# epoch: 1 step: 550, loss is 0.93715507
# epoch: 1 step: 551, loss is 1.3744619
# epoch: 1 step: 552, loss is 1.3504506
# epoch: 1 step: 553, loss is 1.9622126
# epoch: 1 step: 554, loss is 1.5473511
# epoch: 1 step: 555, loss is 2.5148447
# epoch: 1 step: 556, loss is 1.7737867
# epoch: 1 step: 557, loss is 0.8738571
# epoch: 1 step: 558, loss is 1.3669624
# epoch: 1 step: 559, loss is 1.3331934
# epoch: 1 step: 560, loss is 0.9383316
# epoch: 1 step: 561, loss is 1.123955
# epoch: 1 step: 562, loss is 1.3210149
# epoch: 1 step: 563, loss is 1.0606508
# epoch: 1 step: 564, loss is 2.3589945
# epoch: 1 step: 565, loss is 0.90551466
# epoch: 1 step: 566, loss is 1.5669248
# epoch: 1 step: 567, loss is 0.9364672
# epoch: 1 step: 568, loss is 1.9989308
# epoch: 1 step: 569, loss is 1.0784677
# epoch: 1 step: 570, loss is 1.8232135
# epoch: 1 step: 571, loss is 1.4922128
# epoch: 1 step: 572, loss is 1.1410986
# epoch: 1 step: 573, loss is 1.3117974
# epoch: 1 step: 574, loss is 1.2148538
# epoch: 1 step: 575, loss is 1.0589975
# epoch: 1 step: 576, loss is 1.281104
# epoch: 1 step: 577, loss is 1.0978736
# epoch: 1 step: 578, loss is 2.1145883
# epoch: 1 step: 579, loss is 1.6543044
# epoch: 1 step: 580, loss is 1.7460563
# epoch: 1 step: 581, loss is 2.1896007
# epoch: 1 step: 582, loss is 1.393424
# epoch: 1 step: 583, loss is 1.0558826
# epoch: 1 step: 584, loss is 1.0933049
# epoch: 1 step: 585, loss is 1.0894147
# epoch: 1 step: 586, loss is 1.4869397
# epoch: 1 step: 587, loss is 1.7851763
# epoch: 1 step: 588, loss is 1.6508052
# epoch: 1 step: 589, loss is 0.9841131
# epoch: 1 step: 590, loss is 1.9156321
# epoch: 1 step: 591, loss is 1.3226963
# epoch: 1 step: 592, loss is 1.0537014
# epoch: 1 step: 593, loss is 2.4213264
# epoch: 1 step: 594, loss is 1.2353076
# epoch: 1 step: 595, loss is 0.5620032
# epoch: 1 step: 596, loss is 0.9296675
# epoch: 1 step: 597, loss is 0.92117494
# epoch: 1 step: 598, loss is 0.7734861
# epoch: 1 step: 599, loss is 0.9433968
# epoch: 1 step: 600, loss is 0.70443463
# epoch: 1 step: 601, loss is 3.5364006
# epoch: 1 step: 602, loss is 1.1570004
# epoch: 1 step: 603, loss is 1.8686748
# epoch: 1 step: 604, loss is 1.7261684
# epoch: 1 step: 605, loss is 1.6289771
# epoch: 1 step: 606, loss is 1.89284
# epoch: 1 step: 607, loss is 2.3665524
# epoch: 1 step: 608, loss is 2.805249
# epoch: 1 step: 609, loss is 1.9220817
# epoch: 1 step: 610, loss is 2.0532517
# epoch: 1 step: 611, loss is 1.7990406
# epoch: 1 step: 612, loss is 1.5404149
# epoch: 1 step: 613, loss is 1.6670649
# epoch: 1 step: 614, loss is 2.2019322
# epoch: 1 step: 615, loss is 1.5532734
# epoch: 1 step: 616, loss is 1.7901459
# epoch: 1 step: 617, loss is 1.2279147
# epoch: 1 step: 618, loss is 2.335375
# epoch: 1 step: 619, loss is 1.242577
# epoch: 1 step: 620, loss is 1.3533776
# epoch: 1 step: 621, loss is 2.1792037
# epoch: 1 step: 622, loss is 1.3642389
# epoch: 1 step: 623, loss is 1.7298418
# epoch: 1 step: 624, loss is 1.1115078
# epoch: 1 step: 625, loss is 1.3615965
# epoch: 1 step: 626, loss is 1.6499485
# epoch: 1 step: 627, loss is 1.5231253
# epoch: 1 step: 628, loss is 1.3740698
# epoch: 1 step: 629, loss is 1.184236
# epoch: 1 step: 630, loss is 1.3489987
# epoch: 1 step: 631, loss is 2.1557543
# epoch: 1 step: 632, loss is 0.711701
# epoch: 1 step: 633, loss is 1.5394889
# epoch: 1 step: 634, loss is 1.42396
# epoch: 1 step: 635, loss is 0.85410446
# epoch: 1 step: 636, loss is 1.7007118
# epoch: 1 step: 637, loss is 1.6012695
# epoch: 1 step: 638, loss is 1.2406
# epoch: 1 step: 639, loss is 1.1386592
# epoch: 1 step: 640, loss is 1.3098453
# epoch: 1 step: 641, loss is 1.5416594
# epoch: 1 step: 642, loss is 1.1673269
# epoch: 1 step: 643, loss is 0.8614526
# epoch: 1 step: 644, loss is 1.3278754
# epoch: 1 step: 645, loss is 1.8459097
# epoch: 1 step: 646, loss is 2.0682316
# epoch: 1 step: 647, loss is 1.278196
# epoch: 1 step: 648, loss is 2.0479348
# epoch: 1 step: 649, loss is 2.2825072
# epoch: 1 step: 650, loss is 1.4872396
# epoch: 1 step: 651, loss is 0.88567674
# epoch: 1 step: 652, loss is 1.1063833
# epoch: 1 step: 653, loss is 1.1647822
# epoch: 1 step: 654, loss is 1.6463587
# epoch: 1 step: 655, loss is 1.020412
# epoch: 1 step: 656, loss is 1.8333472
# epoch: 1 step: 657, loss is 1.5412093
# epoch: 1 step: 658, loss is 1.0193906
# epoch: 1 step: 659, loss is 0.9195253
# epoch: 1 step: 660, loss is 1.5027682
# epoch: 1 step: 661, loss is 2.0110877
# epoch: 1 step: 662, loss is 1.5459795
# epoch: 1 step: 663, loss is 3.1640165
# epoch: 1 step: 664, loss is 1.4742465
# epoch: 1 step: 665, loss is 1.3128083
# epoch: 1 step: 666, loss is 1.800369
# epoch: 1 step: 667, loss is 1.734479
# epoch: 1 step: 668, loss is 1.4874364
# epoch: 1 step: 669, loss is 1.6886412
# epoch: 1 step: 670, loss is 1.0495113
# epoch: 1 step: 671, loss is 1.3387606
# epoch: 1 step: 672, loss is 2.208342
# epoch: 1 step: 673, loss is 2.0246925
# epoch: 1 step: 674, loss is 1.6361343
# epoch: 1 step: 675, loss is 2.3528886
# epoch: 1 step: 676, loss is 2.9340785
# epoch: 1 step: 677, loss is 1.6873609
# epoch: 1 step: 678, loss is 2.2519386
# epoch: 1 step: 679, loss is 1.3510545
# epoch: 1 step: 680, loss is 1.2633615
# epoch: 1 step: 681, loss is 1.1912043
# epoch: 1 step: 682, loss is 1.6961918
# epoch: 1 step: 683, loss is 1.5035676
# epoch: 1 step: 684, loss is 1.5131687
# epoch: 1 step: 685, loss is 1.2519829
# epoch: 1 step: 686, loss is 1.9208738
# epoch: 1 step: 687, loss is 1.3440335
# epoch: 1 step: 688, loss is 0.58392787
# epoch: 1 step: 689, loss is 1.7048472
# epoch: 1 step: 690, loss is 1.1668185
# epoch: 1 step: 691, loss is 1.6105778
# epoch: 1 step: 692, loss is 0.7423024
# epoch: 1 step: 693, loss is 1.1454164
# epoch: 1 step: 694, loss is 0.7690563
# epoch: 1 step: 695, loss is 1.4199921
# epoch: 1 step: 696, loss is 0.8541748
# epoch: 1 step: 697, loss is 1.1862929
# epoch: 1 step: 698, loss is 2.1285017
# epoch: 1 step: 699, loss is 1.6382279
# epoch: 1 step: 700, loss is 2.2224329
# epoch: 1 step: 701, loss is 2.2137108
# epoch: 1 step: 702, loss is 1.2328722
# epoch: 1 step: 703, loss is 1.571335
# epoch: 1 step: 704, loss is 1.9341671
# epoch: 1 step: 705, loss is 1.8138963
# epoch: 1 step: 706, loss is 1.4982613
# epoch: 1 step: 707, loss is 1.6678503
# epoch: 1 step: 708, loss is 1.3788663
# epoch: 1 step: 709, loss is 1.7853928
# epoch: 1 step: 710, loss is 0.87232935
# epoch: 1 step: 711, loss is 0.9141623
# epoch: 1 step: 712, loss is 1.030629
# epoch: 1 step: 713, loss is 2.2577572
# epoch: 1 step: 714, loss is 1.7000116
# epoch: 1 step: 715, loss is 1.1098583
# epoch: 1 step: 716, loss is 1.066246
# epoch: 1 step: 717, loss is 2.238536
# epoch: 1 step: 718, loss is 1.1651244
# epoch: 1 step: 719, loss is 1.4353092
# epoch: 1 step: 720, loss is 1.648274
# epoch: 1 step: 721, loss is 1.3437718
# epoch: 1 step: 722, loss is 0.9601256
# epoch: 1 step: 723, loss is 1.7248051
# epoch: 1 step: 724, loss is 1.5052189
# epoch: 1 step: 725, loss is 1.673082
# epoch: 1 step: 726, loss is 1.9289918
# epoch: 1 step: 727, loss is 1.672017
# epoch: 1 step: 728, loss is 1.1604389
# epoch: 1 step: 729, loss is 1.2927568
# epoch: 1 step: 730, loss is 1.6860846
# epoch: 1 step: 731, loss is 1.3977252
# epoch: 1 step: 732, loss is 1.0383053
# epoch: 1 step: 733, loss is 1.0851276
# epoch: 1 step: 734, loss is 1.121893
# epoch: 1 step: 735, loss is 1.9452114
# epoch: 1 step: 736, loss is 1.9914498
# epoch: 1 step: 737, loss is 1.7994573
# epoch: 1 step: 738, loss is 1.7599247
# epoch: 1 step: 739, loss is 1.5206364
# epoch: 1 step: 740, loss is 1.2427986
# epoch: 1 step: 741, loss is 1.4358913
# epoch: 1 step: 742, loss is 2.4219787
# epoch: 1 step: 743, loss is 1.1171666
# epoch: 1 step: 744, loss is 1.7188661
# epoch: 1 step: 745, loss is 0.96428305
# epoch: 1 step: 746, loss is 1.1902206
# epoch: 1 step: 747, loss is 1.0993217
# epoch: 1 step: 748, loss is 1.7140164
# epoch: 1 step: 749, loss is 1.3909211
# epoch: 1 step: 750, loss is 1.2052394
# epoch: 1 step: 751, loss is 1.5456121
# epoch: 1 step: 752, loss is 1.8540272
# epoch: 1 step: 753, loss is 0.9031684
# epoch: 1 step: 754, loss is 1.2068284
# epoch: 1 step: 755, loss is 1.1867354
# epoch: 1 step: 756, loss is 1.018508
# epoch: 1 step: 757, loss is 0.87767607
# epoch: 1 step: 758, loss is 0.6855552
# epoch: 1 step: 759, loss is 0.91062397
# epoch: 1 step: 760, loss is 0.5595814
# epoch: 1 step: 761, loss is 1.8142879
# epoch: 1 step: 762, loss is 2.07336
# epoch: 1 step: 763, loss is 1.4698795
# epoch: 1 step: 764, loss is 1.1495347
# epoch: 1 step: 765, loss is 2.6205797
# epoch: 1 step: 766, loss is 1.8735491
# epoch: 1 step: 767, loss is 0.98328
# epoch: 1 step: 768, loss is 2.7732065
# epoch: 1 step: 769, loss is 1.3986751
# epoch: 1 step: 770, loss is 1.7618917
# epoch: 1 step: 771, loss is 2.0400496
# epoch: 1 step: 772, loss is 1.8024389
# epoch: 1 step: 773, loss is 1.2276837
# epoch: 1 step: 774, loss is 1.4074595
# epoch: 1 step: 775, loss is 1.2052435
# epoch: 1 step: 776, loss is 2.1003492
# epoch: 1 step: 777, loss is 1.167943
# epoch: 1 step: 778, loss is 1.5832089
# epoch: 1 step: 779, loss is 2.7169356
# epoch: 1 step: 780, loss is 1.3517741
# epoch: 1 step: 781, loss is 2.4524884
# epoch: 1 step: 782, loss is 1.5406401
# epoch: 1 step: 783, loss is 1.552963
# epoch: 1 step: 784, loss is 1.4879721
# epoch: 1 step: 785, loss is 1.2695345
# epoch: 1 step: 786, loss is 2.5412967
# epoch: 1 step: 787, loss is 1.5118524
# epoch: 1 step: 788, loss is 1.5241469
# epoch: 1 step: 789, loss is 1.1937888
# epoch: 1 step: 790, loss is 1.0645311
# epoch: 1 step: 791, loss is 1.0466751
# epoch: 1 step: 792, loss is 1.8272562
# epoch: 1 step: 793, loss is 0.9339046
# epoch: 1 step: 794, loss is 1.1916223
# epoch: 1 step: 795, loss is 1.0935711
# epoch: 1 step: 796, loss is 1.6987125
# epoch: 1 step: 797, loss is 1.2043964
# epoch: 1 step: 798, loss is 1.2679788
# epoch: 1 step: 799, loss is 1.2499038
# epoch: 1 step: 800, loss is 1.5836489
# epoch: 1 step: 801, loss is 0.81825113
# epoch: 1 step: 802, loss is 1.4117079
# epoch: 1 step: 803, loss is 2.0347676
# epoch: 1 step: 804, loss is 2.3774078
# epoch: 1 step: 805, loss is 2.5194392
# epoch: 1 step: 806, loss is 1.4399451
# epoch: 1 step: 807, loss is 1.3888595
# epoch: 1 step: 808, loss is 1.6321832
# epoch: 1 step: 809, loss is 1.8514366
# epoch: 1 step: 810, loss is 1.3271753
# epoch: 1 step: 811, loss is 1.1181353
# epoch: 1 step: 812, loss is 0.8070784
# epoch: 1 step: 813, loss is 1.3518265
# epoch: 1 step: 814, loss is 1.1025465
# epoch: 1 step: 815, loss is 2.2168748
# epoch: 1 step: 816, loss is 1.1943662
# epoch: 1 step: 817, loss is 0.7089837
# epoch: 1 step: 818, loss is 2.258632
# epoch: 1 step: 819, loss is 1.2038941
# epoch: 1 step: 820, loss is 1.2727541
# epoch: 1 step: 821, loss is 1.269871
# epoch: 1 step: 822, loss is 1.162325
# epoch: 1 step: 823, loss is 1.3273523
# epoch: 1 step: 824, loss is 1.5605285
# epoch: 1 step: 825, loss is 1.540042
# epoch: 1 step: 826, loss is 1.2471586
# epoch: 1 step: 827, loss is 1.7420797
# epoch: 1 step: 828, loss is 0.8848421
# epoch: 1 step: 829, loss is 1.5626414
# epoch: 1 step: 830, loss is 1.2228491
# epoch: 1 step: 831, loss is 1.4771684
# epoch: 1 step: 832, loss is 0.95991665
# epoch: 1 step: 833, loss is 0.7012614
# epoch: 1 step: 834, loss is 0.6126449
# epoch: 1 step: 835, loss is 1.0498451
# epoch: 1 step: 836, loss is 2.781841
# epoch: 1 step: 837, loss is 1.3741949
# epoch: 1 step: 838, loss is 2.1673844
# epoch: 1 step: 839, loss is 1.3269565
# epoch: 1 step: 840, loss is 1.3192503
# epoch: 1 step: 841, loss is 1.3628561
# epoch: 1 step: 842, loss is 2.1182265
# epoch: 1 step: 843, loss is 1.9947644
# epoch: 1 step: 844, loss is 1.1463588
# epoch: 1 step: 845, loss is 1.1905015
# epoch: 1 step: 846, loss is 1.6804231
# epoch: 1 step: 847, loss is 1.5585151
# epoch: 1 step: 848, loss is 1.080232
# epoch: 1 step: 849, loss is 1.0986222
# epoch: 1 step: 850, loss is 1.810107
# epoch: 1 step: 851, loss is 1.6675406
# epoch: 1 step: 852, loss is 1.39159
# epoch: 1 step: 853, loss is 1.4127276
# epoch: 1 step: 854, loss is 1.5788252
# epoch: 1 step: 855, loss is 1.1110394
# epoch: 1 step: 856, loss is 0.9887749
# epoch: 1 step: 857, loss is 1.4678619
# epoch: 1 step: 858, loss is 0.9777641
# epoch: 1 step: 859, loss is 1.6291494
# epoch: 1 step: 860, loss is 1.8190354
# epoch: 1 step: 861, loss is 1.0370754
# epoch: 1 step: 862, loss is 1.834989
# epoch: 1 step: 863, loss is 0.9261425
# epoch: 1 step: 864, loss is 1.4768436
# epoch: 1 step: 865, loss is 1.796515
# epoch: 1 step: 866, loss is 1.1428801
# epoch: 1 step: 867, loss is 1.3160603
# epoch: 1 step: 868, loss is 1.780253
# epoch: 1 step: 869, loss is 0.9479204
# epoch: 1 step: 870, loss is 2.04141
# epoch: 1 step: 871, loss is 1.3143111
# epoch: 1 step: 872, loss is 1.1262968
# epoch: 1 step: 873, loss is 1.0908232
# epoch: 1 step: 874, loss is 0.89400816
# epoch: 1 step: 875, loss is 0.41206297
# epoch: 1 step: 876, loss is 1.2463301
# epoch: 1 step: 877, loss is 2.1812673
# epoch: 1 step: 878, loss is 2.3145542
# epoch: 1 step: 879, loss is 1.3097135
# epoch: 1 step: 880, loss is 1.233948
# epoch: 1 step: 881, loss is 1.3153545
# epoch: 1 step: 882, loss is 2.0128634
# epoch: 1 step: 883, loss is 1.6118655
# epoch: 1 step: 884, loss is 1.4266944
# epoch: 1 step: 885, loss is 0.9657984
# epoch: 1 step: 886, loss is 1.2815496
# epoch: 1 step: 887, loss is 1.0473585
# epoch: 1 step: 888, loss is 1.0010235
# epoch: 1 step: 889, loss is 1.6970371
# epoch: 1 step: 890, loss is 1.3066823
# epoch: 1 step: 891, loss is 1.2364402
# epoch: 1 step: 892, loss is 1.1385248
# epoch: 1 step: 893, loss is 0.9177872
# epoch: 1 step: 894, loss is 1.1591146
# epoch: 1 step: 895, loss is 0.9106273
# epoch: 1 step: 896, loss is 1.6187125
# epoch: 1 step: 897, loss is 1.9229945
# epoch: 1 step: 898, loss is 1.5655247
# epoch: 1 step: 899, loss is 1.4311674
# epoch: 1 step: 900, loss is 1.4142482
# epoch: 1 step: 901, loss is 1.5247314
# epoch: 1 step: 902, loss is 1.3676823
# epoch: 1 step: 903, loss is 3.2040489
# epoch: 1 step: 904, loss is 1.7395879
# epoch: 1 step: 905, loss is 1.2591822
# epoch: 1 step: 906, loss is 1.6856432
# epoch: 1 step: 907, loss is 2.4759579
# epoch: 1 step: 908, loss is 2.6538687
# epoch: 1 step: 909, loss is 1.9700387
# epoch: 1 step: 910, loss is 1.6484083
# epoch: 1 step: 911, loss is 1.6934195
# epoch: 1 step: 912, loss is 1.5655354
# epoch: 1 step: 913, loss is 1.7893322
# epoch: 1 step: 914, loss is 1.1983904
# epoch: 1 step: 915, loss is 1.2634139
# epoch: 1 step: 916, loss is 1.5610559
# epoch: 1 step: 917, loss is 2.2531235
# epoch: 1 step: 918, loss is 2.167122
# epoch: 1 step: 919, loss is 1.4557128
# epoch: 1 step: 920, loss is 1.4637399
# epoch: 1 step: 921, loss is 1.5107045
# epoch: 1 step: 922, loss is 1.3329408
# epoch: 1 step: 923, loss is 1.9384845
# epoch: 1 step: 924, loss is 1.2568699
# epoch: 1 step: 925, loss is 0.99303275
# epoch: 1 step: 926, loss is 1.0091873
# epoch: 1 step: 927, loss is 0.6656724
# epoch: 1 step: 928, loss is 1.1291411
# epoch: 1 step: 929, loss is 1.7276536
# epoch: 1 step: 930, loss is 0.70765555
# epoch: 1 step: 931, loss is 1.5282125
# epoch: 1 step: 932, loss is 1.3395042
# epoch: 1 step: 933, loss is 1.1545167
# epoch: 1 step: 934, loss is 1.7552595
# epoch: 1 step: 935, loss is 1.0641365
# epoch: 1 step: 936, loss is 1.2190123
# epoch: 1 step: 937, loss is 1.5070943
# epoch: 1 step: 938, loss is 2.4821904
# epoch: 1 step: 939, loss is 1.3086292
# epoch: 1 step: 940, loss is 2.3394446
# epoch: 1 step: 941, loss is 2.2263536
# epoch: 1 step: 942, loss is 1.867672
# epoch: 1 step: 943, loss is 1.4699956
# epoch: 1 step: 944, loss is 1.0645127
# epoch: 1 step: 945, loss is 1.3631804
# epoch: 1 step: 946, loss is 1.5400485
# epoch: 1 step: 947, loss is 2.4118922
# epoch: 1 step: 948, loss is 0.72063905
# epoch: 1 step: 949, loss is 1.8482045
# epoch: 1 step: 950, loss is 2.170557
# epoch: 1 step: 951, loss is 1.692488
# epoch: 1 step: 952, loss is 1.3559054
# epoch: 1 step: 953, loss is 0.8768174
# epoch: 1 step: 954, loss is 2.14306
# epoch: 1 step: 955, loss is 1.690581
# epoch: 1 step: 956, loss is 1.7724787
# epoch: 1 step: 957, loss is 1.1906484
# epoch: 1 step: 958, loss is 1.0246061
# epoch: 1 step: 959, loss is 1.9525268
# epoch: 1 step: 960, loss is 1.3011158
# epoch: 1 step: 961, loss is 0.9844025
# epoch: 1 step: 962, loss is 1.763957
# epoch: 1 step: 963, loss is 1.2179471
# epoch: 1 step: 964, loss is 0.69366693
# epoch: 1 step: 965, loss is 1.5819513
# epoch: 1 step: 966, loss is 1.3021823
# epoch: 1 step: 967, loss is 2.1803937
# epoch: 1 step: 968, loss is 1.1590928
# epoch: 1 step: 969, loss is 1.2100859
# epoch: 1 step: 970, loss is 1.4091609
# epoch: 1 step: 971, loss is 1.0832
# epoch: 1 step: 972, loss is 1.6371828
# epoch: 1 step: 973, loss is 2.5663254
# epoch: 1 step: 974, loss is 1.0810488
# epoch: 1 step: 975, loss is 0.9159443
# epoch: 1 step: 976, loss is 0.87991685
# epoch: 1 step: 977, loss is 1.4458377
# epoch: 1 step: 978, loss is 1.2617476
# epoch: 1 step: 979, loss is 1.5127198
# epoch: 1 step: 980, loss is 0.88638985
# epoch: 1 step: 981, loss is 1.7242854
# epoch: 1 step: 982, loss is 1.56798
# epoch: 1 step: 983, loss is 1.1792315
# epoch: 1 step: 984, loss is 1.2690742
# epoch: 1 step: 985, loss is 0.87213016
# epoch: 1 step: 986, loss is 2.8448896
# epoch: 1 step: 987, loss is 2.3513546
# epoch: 1 step: 988, loss is 1.6031798
# epoch: 1 step: 989, loss is 1.1665213
# epoch: 1 step: 990, loss is 0.9883965
# epoch: 1 step: 991, loss is 1.6153431
# epoch: 1 step: 992, loss is 0.9381603
# epoch: 1 step: 993, loss is 2.1404412
# epoch: 1 step: 994, loss is 0.9743049
# epoch: 1 step: 995, loss is 0.93995845
# epoch: 1 step: 996, loss is 0.9766063
# epoch: 1 step: 997, loss is 2.0882897
# epoch: 1 step: 998, loss is 1.448062
# epoch: 1 step: 999, loss is 1.0321077
# epoch: 1 step: 1000, loss is 1.6017672
# epoch: 1 step: 1001, loss is 1.1631858
# epoch: 1 step: 1002, loss is 1.3996522
# epoch: 1 step: 1003, loss is 1.243048
# epoch: 1 step: 1004, loss is 0.9125181
# epoch: 1 step: 1005, loss is 0.8314029
# epoch: 1 step: 1006, loss is 1.3923901
# epoch: 1 step: 1007, loss is 2.6147492
# epoch: 1 step: 1008, loss is 1.6778294
# epoch: 1 step: 1009, loss is 1.4112616
# epoch: 1 step: 1010, loss is 1.2905835
# epoch: 1 step: 1011, loss is 1.5559571
# epoch: 1 step: 1012, loss is 0.98001975
# epoch: 1 step: 1013, loss is 1.6266143
# epoch: 1 step: 1014, loss is 1.1616497
# epoch: 1 step: 1015, loss is 1.8241208
# epoch: 1 step: 1016, loss is 1.2828238
# epoch: 1 step: 1017, loss is 2.3579254
# epoch: 1 step: 1018, loss is 1.4469067
# epoch: 1 step: 1019, loss is 3.4775314
# epoch: 1 step: 1020, loss is 1.9340653
# epoch: 1 step: 1021, loss is 1.6102386
# epoch: 1 step: 1022, loss is 1.7993473
# epoch: 1 step: 1023, loss is 2.1482954
# epoch: 1 step: 1024, loss is 1.6788089
# epoch: 1 step: 1025, loss is 1.196511
# epoch: 1 step: 1026, loss is 1.2493163
# epoch: 1 step: 1027, loss is 1.1499478
# epoch: 1 step: 1028, loss is 1.14583
# epoch: 1 step: 1029, loss is 2.141902
# epoch: 1 step: 1030, loss is 1.6249655
# epoch: 1 step: 1031, loss is 1.4945064
# epoch: 1 step: 1032, loss is 1.9591917
# epoch: 1 step: 1033, loss is 1.9194399
# epoch: 1 step: 1034, loss is 0.8655796
# epoch: 1 step: 1035, loss is 1.735472
# epoch: 1 step: 1036, loss is 1.2091339
# epoch: 1 step: 1037, loss is 1.192856
# epoch: 1 step: 1038, loss is 1.3360701
# epoch: 1 step: 1039, loss is 1.525861
# epoch: 1 step: 1040, loss is 1.8954278
# epoch: 1 step: 1041, loss is 0.5987902
# epoch: 1 step: 1042, loss is 1.2963498
# epoch: 1 step: 1043, loss is 1.4782714
# epoch: 1 step: 1044, loss is 1.9481611
# epoch: 1 step: 1045, loss is 0.88549215
# epoch: 1 step: 1046, loss is 0.8458901
# epoch: 1 step: 1047, loss is 0.9584905
# epoch: 1 step: 1048, loss is 1.251418
# epoch: 1 step: 1049, loss is 1.5054703
# epoch: 1 step: 1050, loss is 1.2176083
# epoch: 1 step: 1051, loss is 1.0096099
# epoch: 1 step: 1052, loss is 1.4687657
# epoch: 1 step: 1053, loss is 1.3811171
# epoch: 1 step: 1054, loss is 0.9274324
# epoch: 1 step: 1055, loss is 1.9120938
# epoch: 1 step: 1056, loss is 2.3567145
# epoch: 1 step: 1057, loss is 0.902042
# epoch: 1 step: 1058, loss is 1.0727746
# epoch: 1 step: 1059, loss is 1.5851027
# epoch: 1 step: 1060, loss is 1.2294184
# epoch: 1 step: 1061, loss is 2.573242
# epoch: 1 step: 1062, loss is 1.4323072
# epoch: 1 step: 1063, loss is 1.3486518
# epoch: 1 step: 1064, loss is 1.3409407
# epoch: 1 step: 1065, loss is 1.4327403
# epoch: 1 step: 1066, loss is 1.712983
# epoch: 1 step: 1067, loss is 2.788866
# epoch: 1 step: 1068, loss is 1.3350538
# epoch: 1 step: 1069, loss is 1.4466234
# epoch: 1 step: 1070, loss is 1.1653559
# epoch: 1 step: 1071, loss is 1.8428656
# epoch: 1 step: 1072, loss is 0.9131767
# epoch: 1 step: 1073, loss is 2.3357134
# epoch: 1 step: 1074, loss is 0.8961899
# epoch: 1 step: 1075, loss is 1.5931143
# epoch: 1 step: 1076, loss is 1.8975611
# epoch: 1 step: 1077, loss is 0.92762846
# epoch: 1 step: 1078, loss is 1.2843606
# epoch: 1 step: 1079, loss is 1.0413966
# epoch: 1 step: 1080, loss is 2.029648
# epoch: 1 step: 1081, loss is 0.5704524
# epoch: 1 step: 1082, loss is 1.0227505
# epoch: 1 step: 1083, loss is 1.9397067
# epoch: 1 step: 1084, loss is 0.8147212
# epoch: 1 step: 1085, loss is 1.2146033
# epoch: 1 step: 1086, loss is 1.3980991
# epoch: 1 step: 1087, loss is 1.1340199
# epoch: 1 step: 1088, loss is 1.4374418
# epoch: 1 step: 1089, loss is 1.3766793
# epoch: 1 step: 1090, loss is 1.6103015
# epoch: 1 step: 1091, loss is 1.3120158
# epoch: 1 step: 1092, loss is 1.4964631
# epoch: 1 step: 1093, loss is 2.0073526
# epoch: 1 step: 1094, loss is 2.5921788
# epoch: 1 step: 1095, loss is 1.5356925
# epoch: 1 step: 1096, loss is 1.6371377
# epoch: 1 step: 1097, loss is 1.5792373
# epoch: 1 step: 1098, loss is 2.0705276
# epoch: 1 step: 1099, loss is 1.1178305
# epoch: 1 step: 1100, loss is 1.5996292
# epoch: 1 step: 1101, loss is 2.0142982
# epoch: 1 step: 1102, loss is 1.1774317
# epoch: 1 step: 1103, loss is 2.6391037
# epoch: 1 step: 1104, loss is 1.4711894
# epoch: 1 step: 1105, loss is 1.5184011
# epoch: 1 step: 1106, loss is 1.3075215
# epoch: 1 step: 1107, loss is 1.4977323
# epoch: 1 step: 1108, loss is 1.6480515
# epoch: 1 step: 1109, loss is 1.0764489
# epoch: 1 step: 1110, loss is 2.195207
# epoch: 1 step: 1111, loss is 1.5142618
# epoch: 1 step: 1112, loss is 1.952276
# epoch: 1 step: 1113, loss is 0.87727296
# epoch: 1 step: 1114, loss is 0.8478335
# epoch: 1 step: 1115, loss is 1.201063
# epoch: 1 step: 1116, loss is 1.1078484
# epoch: 1 step: 1117, loss is 2.5773666
# epoch: 1 step: 1118, loss is 1.5006875
# epoch: 1 step: 1119, loss is 0.7912025
# epoch: 1 step: 1120, loss is 1.8260268
# epoch: 1 step: 1121, loss is 1.2507548
# epoch: 1 step: 1122, loss is 1.568761
# epoch: 1 step: 1123, loss is 1.0403686
# epoch: 1 step: 1124, loss is 1.0510076
# epoch: 1 step: 1125, loss is 1.7691779
# epoch: 1 step: 1126, loss is 1.495012
# epoch: 1 step: 1127, loss is 1.1899654
# epoch: 1 step: 1128, loss is 2.255723
# epoch: 1 step: 1129, loss is 2.2189426
# epoch: 1 step: 1130, loss is 1.0438601
# epoch: 1 step: 1131, loss is 1.5419925
# epoch: 1 step: 1132, loss is 1.1848749
# epoch: 1 step: 1133, loss is 1.2573973
# epoch: 1 step: 1134, loss is 1.6878625
# epoch: 1 step: 1135, loss is 1.2651044
# epoch: 1 step: 1136, loss is 2.4280283
# epoch: 1 step: 1137, loss is 0.92705834
# epoch: 1 step: 1138, loss is 1.57083
# epoch: 1 step: 1139, loss is 1.5704148
# epoch: 1 step: 1140, loss is 1.1332544
# epoch: 1 step: 1141, loss is 0.9984871
# epoch: 1 step: 1142, loss is 1.1497126
# epoch: 1 step: 1143, loss is 0.9148545
# Train epoch time: 544468.382 ms, per step time: 476.350 ms
# CPU times: user 40min 28s, sys: 4min 39s, total: 45min 7s
# Wall time: 9min 10s

# %% [markdown]
# > 因为FCN网络在训练的过程中需要大量的训练数据和训练轮数，这里只提供了小数据单个epoch的训练来演示loss收敛的过程，下文中使用已训练好的权重文件进行模型评估和推理效果的展示。

# %% [markdown]
# ## 模型评估

# %%
IMAGE_MEAN = [103.53, 116.28, 123.675]
IMAGE_STD = [57.375, 57.120, 58.395]
DATA_FILE = "dataset/dataset_fcn8s/mindname.mindrecord"

# 下载已训练好的权重文件
url = "https://mindspore-website.obs.cn-north-4.myhuaweicloud.com/notebook/datasets/FCN8s.ckpt"
download(url, "FCN8s.ckpt", replace=True)
net = FCN8s(n_class=num_classes)

ckpt_file = "FCN8s.ckpt"
param_dict = load_checkpoint(ckpt_file)
load_param_into_net(net, param_dict)

model = Model(net, loss_fn=loss, optimizer=optimizer, loss_scale_manager=loss_scale_manager, metrics={"pixel accuracy": PixelAccuracy(), "mean pixel accuracy": PixelAccuracyClass(), "mean IoU": MeanIntersectionOverUnion(), "frequency weighted IoU": FrequencyWeightedIntersectionOverUnion()})

# 实例化Dataset
dataset = SegDataset(image_mean=IMAGE_MEAN,
                     image_std=IMAGE_STD,
                     data_file=DATA_FILE,
                     batch_size=train_batch_size,
                     crop_size=crop_size,
                     max_scale=max_scale,
                     min_scale=min_scale,
                     ignore_label=ignore_label,
                     num_classes=num_classes,
                     num_readers=2,
                     num_parallel_calls=4)
dataset_eval = dataset.get_dataset()
model.eval(dataset_eval)
# Out:
# Downloading data from https://mindspore-website.obs.cn-north-4.myhuaweicloud.com/notebook/datasets/FCN8s.ckpt (1.00 GB)
#
# file_sizes: 100%|███████████████████████████| 1.08G/1.08G [00:05<00:00, 198MB/s]
# Successfully downloaded file to FCN8s.ckpt
# .
# {'pixel accuracy': 0.9727971154961689,
#  'mean pixel accuracy': 0.9381533091330537,
#  'mean IoU': 0.8917484742656789,
#  'frequency weighted IoU': 0.9475671117299717}

# %% [markdown]
# ## 模型推理
#
# 使用训练的网络对模型推理结果进行展示。

# %%
import cv2
import matplotlib.pyplot as plt

net = FCN8s(n_class=num_classes)
# 设置超参
ckpt_file = "FCN8s.ckpt"
param_dict = load_checkpoint(ckpt_file)
load_param_into_net(net, param_dict)
eval_batch_size = 4
img_lst = []
mask_lst = []
res_lst = []
# 推理效果展示(上方为输入图片，下方为推理效果图片)
plt.figure(figsize=(8, 5))
show_data = next(dataset_eval.create_dict_iterator())
show_images = show_data["data"].asnumpy()
mask_images = show_data["label"].reshape([4, 512, 512])
show_images = np.clip(show_images, 0, 1)
for i in range(eval_batch_size):
    img_lst.append(show_images[i])
    mask_lst.append(mask_images[i])
res = net(show_data["data"]).asnumpy().argmax(axis=1)
for i in range(eval_batch_size):
    plt.subplot(2, 4, i + 1)
    plt.imshow(img_lst[i].transpose(1, 2, 0))
    plt.axis("off")
    plt.subplots_adjust(wspace=0.05, hspace=0.02)
    plt.subplot(2, 4, i + 5)
    plt.imshow(res[i])
    plt.axis("off")
    plt.subplots_adjust(wspace=0.05, hspace=0.02)
plt.show()

# %% [markdown]
# ## 总结
#
# FCN的核心贡献在于提出使用全卷积层，通过学习让图片实现端到端分割。与传统使用CNN进行图像分割的方法相比，FCN有两大明显的优点：一是可以接受任意大小的输入图像，无需要求所有的训练图像和测试图像具有固定的尺寸。二是更加高效，避免了由于使用像素块而带来的重复存储和计算卷积的问题。
#
# 同时FCN网络也存在待改进之处：
#
# 一是得到的结果仍不够精细。进行8倍上采样虽然比32倍的效果好了很多，但是上采样的结果仍比较模糊和平滑，尤其是边界处，网络对图像中的细节不敏感。
# 二是对各个像素进行分类，没有充分考虑像素与像素之间的关系（如不连续性和相似性）。忽略了在通常的基于像素分类的分割方法中使用的空间规整（spatial regularization）步骤，缺乏空间一致性。
#
# ## 引用
#
# [1]Long, Jonathan, Evan Shelhamer, and Trevor Darrell. "Fully convolutional networks for Semantic Segmentation." Proceedings of the IEEE Conference on Computer Vision and Pattern Recognition. 2015.
